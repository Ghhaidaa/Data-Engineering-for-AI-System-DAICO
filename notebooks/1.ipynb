# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghhaidaa/AI/blob/main/notebooks/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
BASE = '/content/drive/MyDrive/capstone'
for folder in ['bronze', 'silver', 'gold', 'logs', 'vector_store', 'quarantine']:
    os.makedirs(f'{BASE}/{folder}', exist_ok=True)
print("تم:", os.listdir(BASE))
# Out:
# Mounted at /content/drive
# تم: ['bronze', 'silver', 'gold', 'logs', 'vector_store', 'quarantine']
