# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghhaidaa/Data-Engineering-for-AI-System-DAICO/blob/main/notebooks/SDAIA_Books_Platform_v6_FIXED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SDAIA** **Books** **Platform**
#
# A data engineering platform for validating, streaming, and storing book registration data submitted by publishers across Saudi Arabia.
#
#
# The platform receives the data, validates it, streams it through the pipeline, stores it efficiently, and prepares it for downstream analytics and AI applications.

# %% [markdown]
# > **Note:**
# > The dataset is generated programmatically using the Faker library.
# > Running this notebook from the beginning will automatically create:
# > - books_data.csv
# > - valid_books.csv
# > - rejected_books.csv

# %% [markdown]
# # Data Ingestion and Delta Lake
#
# The implementation includes:
#
# - Data validation using **Pydantic**.
# - Real-time data streaming with **Apache Kafka** (Producer & Consumer).
# - Delta Lake **Bronze**, **Silver**, and **Gold** layers.
# - **MERGE (Upsert)** using `book_id` as the business key.
# - **Schema Enforcement** demonstration to validate schema consistency.

# %%
# !apt-get update -qq
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt-get install -y openjdk-17-jdk-headless
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openjdk-17-jdk-headless is already the newest version (17.0.19+10-1~22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 118 not upgraded.

# %%
# !pip install kafka-python pydantic faker
# Out:
# Requirement already satisfied: kafka-python in /usr/local/lib/python3.12/dist-packages (3.0.9)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (2.13.4)
# Requirement already satisfied: faker in /usr/local/lib/python3.12/dist-packages (40.35.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.4.2)

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

# Make results reproducible
Faker.seed(42)
random.seed(42)

# %%
publisher_names = [
    "Jarir Publishing",
    "Obeikan Publishing",
    "King Fahad National Library",
    "Dar Al-Minhaj",
    "Saudi Research Publishing"
]

publisher_cities = [
    "Riyadh",
    "Jeddah",
    "Dammam",
    "Madinah",
    "Abha"
]

categories = [
    "Artificial Intelligence",
    "Data Science",
    "Cybersecurity",
    "Education",
    "Government",
    "Culture",
    "History"
]

languages = ["Arabic", "English"]

records = []

for book_id in range(1, 101):

    isbn = f"978603{random.randint(1000000,9999999)}"

    records.append({
        "book_id": book_id,
        "isbn": isbn,
        "title": fake.sentence(nb_words=4).replace(".", ""),
        "author": fake.name(),
        "publisher_name": random.choice(publisher_names),
        "publisher_city": random.choice(publisher_cities),
        "category": random.choice(categories),
        "language": random.choice(languages),
        "publication_year": random.randint(2015, 2026),
        "submission_date": fake.date_this_year().strftime("%Y-%m-%d")
    })

df = pd.DataFrame(records)

df.head()
# Out:
#    book_id           isbn                                    title  \
# 0        1  9786032867825                              Agent every
# 1        2  9786032719583                          Opportunity all
# 2        3  9786031499914  Information last everything thank serve
# 3        4  9786034335942                       Bill here grow gas
# 4        5  9786035667265                      Bad fall pick those
#
#            author             publisher_name publisher_city      category  \
# 0     Noah Rhodes           Jarir Publishing         Dammam  Data Science
# 1    David Guzman  Saudi Research Publishing         Riyadh    Government
# 2     Jay Ramirez           Jarir Publishing         Jeddah  Data Science
# 3  Andrew Stevens  Saudi Research Publishing        Madinah  Data Science
# 4     Corey Jones           Jarir Publishing         Jeddah       Culture
#
#   language  publication_year submission_date
# 0   Arabic              2017      2026-07-01
# 1  English              2015      2026-04-24
# 2   Arabic              2023      2026-02-13
# 3  English              2024      2026-01-26
# 4  English              2020      2026-05-15

# %%
# Missing ISBN
df.loc[0, "isbn"] = None

# Empty title
df.loc[1, "title"] = ""

# Unsupported language
df.loc[2, "language"] = "French"

# Future publication year
df.loc[3, "publication_year"] = 2050

# Invalid date format
df.loc[4, "submission_date"] = "2026/15/40"

df.head()
# Out:
#    book_id           isbn                                    title  \
# 0        1           None                              Agent every
# 1        2  9786032719583
# 2        3  9786031499914  Information last everything thank serve
# 3        4  9786034335942                       Bill here grow gas
# 4        5  9786035667265                      Bad fall pick those
#
#            author             publisher_name publisher_city      category  \
# 0     Noah Rhodes           Jarir Publishing         Dammam  Data Science
# 1    David Guzman  Saudi Research Publishing         Riyadh    Government
# 2     Jay Ramirez           Jarir Publishing         Jeddah  Data Science
# 3  Andrew Stevens  Saudi Research Publishing        Madinah  Data Science
# 4     Corey Jones           Jarir Publishing         Jeddah       Culture
#
#   language  publication_year submission_date
# 0   Arabic              2017      2026-07-01
# 1  English              2015      2026-04-24
# 2   French              2023      2026-02-13
# 3  English              2050      2026-01-26
# 4  English              2020      2026/15/40

# %%
df.to_csv("books_data.csv", index=False)

print("Dataset created successfully!")
print(f"Total records: {len(df)}")
# Out:
# Dataset created successfully!
# Total records: 100

# %%
from pydantic import BaseModel, Field, ValidationError, field_validator
from datetime import datetime

# %%
class BookRecord(BaseModel):
    book_id: int = Field(gt=0)
    isbn: str
    title: str
    author: str
    publisher_name: str
    publisher_city: str
    category: str
    language: str
    publication_year: int
    submission_date: str

    @field_validator("isbn")
    @classmethod
    def validate_isbn(cls, value):
        if not value:
            raise ValueError("ISBN cannot be empty.")
        return value

    @field_validator("title")
    @classmethod
    def validate_title(cls, value):
        if not value.strip():
            raise ValueError("Title cannot be empty.")
        return value

    @field_validator("language")
    @classmethod
    def validate_language(cls, value):
        if value not in ["Arabic", "English"]:
            raise ValueError("Language must be Arabic or English.")
        return value

    @field_validator("publication_year")
    @classmethod
    def validate_year(cls, value):
        current_year = datetime.now().year
        if value > current_year:
            raise ValueError("Publication year cannot be in the future.")
        return value

    @field_validator("submission_date")
    @classmethod
    def validate_date(cls, value):
        datetime.strptime(value, "%Y-%m-%d")
        return value

# %%
valid_records = []
invalid_records = []

for _, row in df.iterrows():
    try:
        record = BookRecord(**row.to_dict())
        valid_records.append(record.model_dump())
    except ValidationError as e:
        invalid_records.append({
            **row.to_dict(),
            "error": str(e)
        })

valid_df = pd.DataFrame(valid_records)
invalid_df = pd.DataFrame(invalid_records)

print(f"✅ Valid Records: {len(valid_df)}")
print(f"❌ Invalid Records: {len(invalid_df)}")
# Out:
# ✅ Valid Records: 95
# ❌ Invalid Records: 5

# %%
valid_df.to_csv("valid_books.csv", index=False)
invalid_df.to_csv("rejected_books.csv", index=False)

print("Files saved successfully!")

print(f"Valid records: {len(valid_df)}")
print(f"Invalid records: {len(invalid_df)}")
# Out:
# Files saved successfully!
# Valid records: 95
# Invalid records: 5

# %%
# Download and extract Kafka (single clean setup - no duplicate download/format)
# !wget -q https://archive.apache.org/dist/kafka/3.7.0/kafka_2.13-3.7.0.tgz
# !tar -xzf kafka_2.13-3.7.0.tgz

# %%
# %cd kafka_2.13-3.7.0
# Out:
# /content/kafka_2.13-3.7.0

# %%
import os

# Make sure there is no leftover storage from a previous run - this is what
# previously caused: "Invalid cluster.id ... Expected X, but read Y"
# !rm -rf /tmp/kraft-combined-logs

cluster_id = os.popen("bin/kafka-storage.sh random-uuid").read().strip()
print(cluster_id)

# !bin/kafka-storage.sh format -t $cluster_id -c config/kraft/server.properties
# Out:
# Dq17wOrjRl-vZ1SDsK6_xg
# metaPropertiesEnsemble=MetaPropertiesEnsemble(metadataLogDir=Optional.empty, dirs={/tmp/kraft-combined-logs: EMPTY})
# Formatting /tmp/kraft-combined-logs with metadata.version 3.7-IV4.

# %%
import subprocess
import time

# Start the Kafka broker (started only ONCE - starting it twice would try to
# bind the same port and is unnecessary)
broker = subprocess.Popen(
    ["bin/kafka-server-start.sh", "config/kraft/server.properties"]
)

time.sleep(10)

print("Kafka Broker started!")
# Out:
# Kafka Broker started!

# %%
# !bin/kafka-topics.sh \
  --create \
  --topic books \
  --bootstrap-server localhost:9092
# Out:
# Created topic books.

# %%
from kafka import KafkaProducer
import pandas as pd
import json


# Step 1: Create a Kafka Producer
producer = KafkaProducer(
    bootstrap_servers="localhost:9092",
    value_serializer=lambda x: json.dumps(x).encode("utf-8")
)

# Step 2: Load the validated dataset
valid_books = pd.read_csv("/content/valid_books.csv")


# Step 3: Send each record to the Kafka topic
for _, record in valid_books.iterrows():
    producer.send("books", value=record.to_dict())


# Step 4: Ensure all messages are delivered
producer.flush()

print(f"Successfully sent {len(valid_books)} records to the 'books' topic.")
# Out:
# Successfully sent 95 records to the 'books' topic.

# %%
from kafka import KafkaConsumer
import json


# Step 1: Create a Kafka Consumer
# consumer_timeout_ms stops iteration automatically if no new message arrives
# for 10 seconds, instead of hanging forever if the expected count is wrong.
consumer = KafkaConsumer(
    "books",
    bootstrap_servers="localhost:9092",
    auto_offset_reset="earliest",
    enable_auto_commit=True,
    consumer_timeout_ms=10000,
    value_deserializer=lambda x: json.loads(x.decode("utf-8"))
)

print("Reading records from Kafka...\n")

# Step 2: Read records from Kafka
# Stop after reading exactly as many records as were produced (dynamic,
# not hard-coded), so this works even if the number of valid records changes.
expected_count = len(valid_books)
count = 0

for message in consumer:
    print(message.value)
    count += 1

    if count == expected_count:
        break

consumer.close()

print(f"\nSuccessfully consumed {count} / {expected_count} records.")
if count < expected_count:
    print("Warning: consumer timed out before reaching the expected count.")
# Out:
# /tmp/ipykernel_18901/170633921.py:8: DeprecationWarning: value_deserializer does not implement kafka.serializer.Deserializer
#   consumer = KafkaConsumer(
# WARNING:kafka.coordinator.consumer:group_id is None: disabling auto-commit.
# Reading records from Kafka...
#
# {'book_id': 6, 'isbn': 9786035661907, 'title': 'World talk term', 'author': 'Jesse Flowers', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-02-03'}
# {'book_id': 7, 'isbn': 9786032556017, 'title': 'Decide environment view possible', 'author': 'Carolyn Daniel', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Riyadh', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-02-03'}
# {'book_id': 8, 'isbn': 9786035437923, 'title': 'Establish understand read detail', 'author': 'Randy Brown', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Madinah', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-06-16'}
# {'book_id': 9, 'isbn': 9786032322047, 'title': 'Husband at tree note', 'author': 'Christy Porter', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-06-29'}
# {'book_id': 10, 'isbn': 9786034226067, 'title': 'Central cause seat much', 'author': 'Jessica Silva', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Riyadh', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2019, 'submission_date': '2026-03-15'}
# {'book_id': 11, 'isbn': 9786032338687, 'title': 'Meeting before another', 'author': 'Mark Conner', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Riyadh', 'category': 'Education', 'language': 'English', 'publication_year': 2022, 'submission_date': '2026-03-27'}
# {'book_id': 12, 'isbn': 9786037120868, 'title': 'His other', 'author': 'David Tran', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'Cybersecurity', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-07-11'}
# {'book_id': 13, 'isbn': 9786035479144, 'title': 'Race Mr', 'author': 'Martin Rodriguez', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Abha', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2023, 'submission_date': '2026-03-30'}
# {'book_id': 14, 'isbn': 9786035107245, 'title': 'About reveal rest will', 'author': 'Katie Rodriguez', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'English', 'publication_year': 2025, 'submission_date': '2026-05-07'}
# {'book_id': 15, 'isbn': 9786034684531, 'title': 'Participant check several much', 'author': 'Kerry Smith', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Riyadh', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2020, 'submission_date': '2026-03-07'}
# {'book_id': 16, 'isbn': 9786037730428, 'title': 'Born guy', 'author': 'Dr. Cynthia Allen', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Riyadh', 'category': 'Data Science', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-04-26'}
# {'book_id': 17, 'isbn': 9786039375710, 'title': 'Beat magazine', 'author': 'Philip Cannon', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Madinah', 'category': 'Data Science', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-01-27'}
# {'book_id': 18, 'isbn': 9786035137722, 'title': 'Water close month parent', 'author': 'Tanya Campos', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-05-21'}
# {'book_id': 19, 'isbn': 9786037700828, 'title': 'Human public health', 'author': 'Jocelyn Wright', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Data Science', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-01-13'}
# {'book_id': 20, 'isbn': 9786031790481, 'title': 'Open discover', 'author': 'Benjamin Welch', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-02-16'}
# {'book_id': 21, 'isbn': 9786038082668, 'title': 'Teacher audience', 'author': 'Michael Lewis', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Riyadh', 'category': 'Education', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-01-27'}
# {'book_id': 22, 'isbn': 9786038852574, 'title': 'Office drug list imagine behind', 'author': 'Heather Jenkins', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-06-25'}
# {'book_id': 23, 'isbn': 9786032921859, 'title': 'Pull worker', 'author': 'James Morgan', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-06-24'}
# {'book_id': 24, 'isbn': 9786035924115, 'title': 'Court movie cell', 'author': 'Joel Baxter', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Jeddah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-01-16'}
# {'book_id': 25, 'isbn': 9786035418934, 'title': 'Better present music address behavior', 'author': 'Cynthia Russell', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-04-08'}
# {'book_id': 26, 'isbn': 9786036007072, 'title': 'Total clearly able hospital', 'author': 'Rachel Mitchell', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2020, 'submission_date': '2026-05-22'}
# {'book_id': 27, 'isbn': 9786033710343, 'title': 'Product main couple design around', 'author': 'Amy Edwards', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2022, 'submission_date': '2026-01-11'}
# {'book_id': 28, 'isbn': 9786031326765, 'title': 'Me system church whether', 'author': 'Cody Larson', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-05-18'}
# {'book_id': 29, 'isbn': 9786031971823, 'title': 'Identify walk now', 'author': 'Amanda Miller', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-05-14'}
# {'book_id': 30, 'isbn': 9786039153566, 'title': 'Mission various daughter respond draw', 'author': 'Michael Evans', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Abha', 'category': 'History', 'language': 'Arabic', 'publication_year': 2017, 'submission_date': '2026-03-06'}
# {'book_id': 31, 'isbn': 9786038973915, 'title': 'Act perform', 'author': 'Ariel Medina', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-04-13'}
# {'book_id': 32, 'isbn': 9786034374754, 'title': 'Value thing these', 'author': 'Christopher Bass', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Madinah', 'category': 'Culture', 'language': 'English', 'publication_year': 2022, 'submission_date': '2026-05-23'}
# {'book_id': 33, 'isbn': 9786039683481, 'title': 'Worker southern more property never', 'author': 'Ashley Humphrey', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Riyadh', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-23'}
# {'book_id': 34, 'isbn': 9786036672134, 'title': 'Score choice', 'author': 'Daniel Cooper', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Abha', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2024, 'submission_date': '2026-05-20'}
# {'book_id': 35, 'isbn': 9786034694634, 'title': 'Measure economy traditional', 'author': 'Mark Calderon', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Riyadh', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2018, 'submission_date': '2026-01-09'}
# {'book_id': 36, 'isbn': 9786032130789, 'title': 'Side PM energy scientist', 'author': 'Jessica Smith', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Dammam', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2019, 'submission_date': '2026-01-16'}
# {'book_id': 37, 'isbn': 9786039143903, 'title': 'Nation strong old', 'author': 'Cameron Parker', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Data Science', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-07-02'}
# {'book_id': 38, 'isbn': 9786038935169, 'title': 'Together decide', 'author': 'Brian Deleon', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-06-29'}
# {'book_id': 39, 'isbn': 9786038231838, 'title': 'Wind see understand door', 'author': 'Robert Thompson', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'English', 'publication_year': 2026, 'submission_date': '2026-03-25'}
# {'book_id': 40, 'isbn': 9786031908841, 'title': 'Say forward us', 'author': 'Sharon Cochran', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Riyadh', 'category': 'Education', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-02-24'}
# {'book_id': 41, 'isbn': 9786035171761, 'title': 'Him although', 'author': 'Curtis Sellers', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'Government', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-03-12'}
# {'book_id': 42, 'isbn': 9786038077999, 'title': 'Development process huge', 'author': 'Benjamin Ayala', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-03-13'}
# {'book_id': 43, 'isbn': 9786038434500, 'title': 'Hundred wonder movie voice boy', 'author': 'Cassandra Estes', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Riyadh', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-23'}
# {'book_id': 44, 'isbn': 9786034965789, 'title': 'Others generation', 'author': 'Jessica Joyce', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-01-24'}
# {'book_id': 45, 'isbn': 9786037728339, 'title': 'Couple and job mind southern', 'author': 'Teresa Mclaughlin', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Jeddah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-02-09'}
# {'book_id': 46, 'isbn': 9786035449368, 'title': 'Attorney professional form finish', 'author': 'Michelle Evans', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Dammam', 'category': 'Education', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-03-04'}
# {'book_id': 47, 'isbn': 9786034185957, 'title': 'For recent never court', 'author': 'Jamie Adkins', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-02-05'}
# {'book_id': 48, 'isbn': 9786036261415, 'title': 'Feeling nature a expert involve', 'author': 'Mary Marshall', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Riyadh', 'category': 'Government', 'language': 'English', 'publication_year': 2023, 'submission_date': '2026-03-31'}
# {'book_id': 49, 'isbn': 9786039910817, 'title': 'Memory soldier where', 'author': 'Mary Campbell', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Riyadh', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2017, 'submission_date': '2026-05-15'}
# {'book_id': 50, 'isbn': 9786032149597, 'title': 'Friend stand seem pull different', 'author': 'Alexander Sanchez', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Riyadh', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-04-07'}
# {'book_id': 51, 'isbn': 9786033011363, 'title': 'Lay though', 'author': 'Michelle Cruz', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2024, 'submission_date': '2026-03-23'}
# {'book_id': 52, 'isbn': 9786032375453, 'title': 'Prevent accept seem', 'author': 'Ashley Coleman', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Abha', 'category': 'Government', 'language': 'English', 'publication_year': 2019, 'submission_date': '2026-02-05'}
# {'book_id': 53, 'isbn': 9786034426900, 'title': 'Let newspaper true building card', 'author': 'Joseph Hansen', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-03-06'}
# {'book_id': 54, 'isbn': 9786036033115, 'title': 'Partner rest measure store', 'author': 'Stephanie Manning', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'Arabic', 'publication_year': 2015, 'submission_date': '2026-04-07'}
# {'book_id': 55, 'isbn': 9786038688755, 'title': 'Seem style everyone', 'author': 'Kari Allen', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2023, 'submission_date': '2026-03-31'}
# {'book_id': 56, 'isbn': 9786034576135, 'title': 'Doctor from throw', 'author': 'Chris Reyes', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'Data Science', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-02-01'}
# {'book_id': 57, 'isbn': 9786035098412, 'title': 'Ask imagine my', 'author': 'Daniel Fisher', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Dammam', 'category': 'Data Science', 'language': 'English', 'publication_year': 2023, 'submission_date': '2026-07-03'}
# {'book_id': 58, 'isbn': 9786036075395, 'title': 'Watch affect thing offer local', 'author': 'Elizabeth Price', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2025, 'submission_date': '2026-07-01'}
# {'book_id': 59, 'isbn': 9786032737893, 'title': 'Mrs same son today', 'author': 'Don Tucker MD', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-05-16'}
# {'book_id': 60, 'isbn': 9786033607983, 'title': 'Right subject try wonder', 'author': 'Susan Vargas', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Dammam', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-05-15'}
# {'book_id': 61, 'isbn': 9786036752576, 'title': 'Poor career', 'author': 'Anthony Gray', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'Government', 'language': 'English', 'publication_year': 2019, 'submission_date': '2026-02-12'}
# {'book_id': 62, 'isbn': 9786031852264, 'title': 'Front they everything week', 'author': 'Ruben Ruiz', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Madinah', 'category': 'History', 'language': 'English', 'publication_year': 2015, 'submission_date': '2026-06-02'}
# {'book_id': 63, 'isbn': 9786031059486, 'title': 'Yourself glass', 'author': 'Rachael Pearson', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-06-03'}
# {'book_id': 64, 'isbn': 9786038412769, 'title': 'Current after charge', 'author': 'Michael Elliott', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Madinah', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-14'}
# {'book_id': 65, 'isbn': 9786032262382, 'title': 'Short cold parent', 'author': 'Ashley Weiss', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-07-15'}
# {'book_id': 66, 'isbn': 9786033484601, 'title': 'Official up', 'author': 'Susan Brooks', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-07-11'}
# {'book_id': 67, 'isbn': 9786031669324, 'title': 'Away real physical', 'author': 'Raymond Jefferson', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-05-02'}
# {'book_id': 68, 'isbn': 9786032724590, 'title': 'Someone not American', 'author': 'Mary Jones', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Abha', 'category': 'History', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-05-12'}
# {'book_id': 69, 'isbn': 9786033592974, 'title': 'Support state', 'author': 'Tyler Reid', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-06-18'}
# {'book_id': 70, 'isbn': 9786031415846, 'title': 'Itself safe whole', 'author': 'Robert Medina', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'English', 'publication_year': 2025, 'submission_date': '2026-04-09'}
# {'book_id': 71, 'isbn': 9786035163555, 'title': 'Stay or focus early', 'author': 'Diana Hayes', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-06-02'}
# {'book_id': 72, 'isbn': 9786031649691, 'title': 'Particular her agreement surface consider', 'author': 'Robert Peterson', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Jeddah', 'category': 'Data Science', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-06-28'}
# {'book_id': 73, 'isbn': 9786036120253, 'title': 'New might course', 'author': 'Jason Peters', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-02-18'}
# {'book_id': 74, 'isbn': 9786036507321, 'title': 'Position make society behavior', 'author': 'Michael Torres', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Riyadh', 'category': 'History', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-04-29'}
# {'book_id': 75, 'isbn': 9786039546409, 'title': 'Network gas you nearly', 'author': 'Jesse Parker', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Abha', 'category': 'Cybersecurity', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-16'}
# {'book_id': 76, 'isbn': 9786035382463, 'title': 'Firm sea week', 'author': 'Cheryl Rodgers', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Cybersecurity', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-26'}
# {'book_id': 77, 'isbn': 9786038290770, 'title': 'With modern executive beyond create', 'author': 'Christopher Smith', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Dammam', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-04-19'}
# {'book_id': 78, 'isbn': 9786034188992, 'title': 'Animal approach factor', 'author': 'Margaret Mullins', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Riyadh', 'category': 'Culture', 'language': 'English', 'publication_year': 2015, 'submission_date': '2026-01-21'}
# {'book_id': 79, 'isbn': 9786039722815, 'title': 'Off light', 'author': 'Cody Williams', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-07-11'}
# {'book_id': 80, 'isbn': 9786036539837, 'title': 'Box assume man officer', 'author': 'Brittany Shepherd', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-07-12'}
# {'book_id': 81, 'isbn': 9786036038571, 'title': 'Yes budget', 'author': 'Lisa Gibbs', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'Culture', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-02-15'}
# {'book_id': 82, 'isbn': 9786037751158, 'title': 'Herself training father open investment', 'author': 'Amy Choi', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Abha', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-01-21'}
# {'book_id': 83, 'isbn': 9786037361002, 'title': 'Personal enough ball', 'author': 'Juan Moore', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Government', 'language': 'English', 'publication_year': 2021, 'submission_date': '2026-03-24'}
# {'book_id': 84, 'isbn': 9786031006810, 'title': 'Like allow explain executive teacher', 'author': 'David Baker', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Dammam', 'category': 'Data Science', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-06-10'}
# {'book_id': 85, 'isbn': 9786036406444, 'title': 'Product value interesting name positive', 'author': 'Samantha Jones', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2023, 'submission_date': '2026-02-03'}
# {'book_id': 86, 'isbn': 9786038938746, 'title': 'Organization station TV', 'author': 'John Torres', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Riyadh', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-03-23'}
# {'book_id': 87, 'isbn': 9786034940441, 'title': 'Matter management ball', 'author': 'Jeffrey Morris', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'Arabic', 'publication_year': 2017, 'submission_date': '2026-02-20'}
# {'book_id': 88, 'isbn': 9786031409790, 'title': 'Director purpose', 'author': 'Laurie Smith', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Jeddah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2022, 'submission_date': '2026-06-05'}
# {'book_id': 89, 'isbn': 9786037953166, 'title': 'Office several compare', 'author': 'Jessica Ramirez', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'English', 'publication_year': 2022, 'submission_date': '2026-07-22'}
# {'book_id': 90, 'isbn': 9786037705062, 'title': 'Play man before girl', 'author': 'Michael Hodge', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-03-08'}
# {'book_id': 91, 'isbn': 9786038132769, 'title': 'Explain war spend nearly', 'author': 'Ernest Morris', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'English', 'publication_year': 2015, 'submission_date': '2026-07-16'}
# {'book_id': 92, 'isbn': 9786035180853, 'title': 'Ten stay ability thank', 'author': 'Anthony Stone', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Madinah', 'category': 'Data Science', 'language': 'English', 'publication_year': 2025, 'submission_date': '2026-05-07'}
# {'book_id': 93, 'isbn': 9786039910914, 'title': 'Personal service data near', 'author': 'Jessica Wolfe', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-01-25'}
# {'book_id': 94, 'isbn': 9786039468772, 'title': 'Participant dream citizen nearly need', 'author': 'Willie Durham', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Abha', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-04-04'}
# {'book_id': 95, 'isbn': 9786038963715, 'title': 'Positive child usually', 'author': 'Michael Perry', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-04-08'}
# {'book_id': 96, 'isbn': 9786035652512, 'title': 'During necessary himself two', 'author': 'Sherry Shields', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Madinah', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2019, 'submission_date': '2026-02-26'}
# {'book_id': 97, 'isbn': 9786038379837, 'title': 'Future skin environment able', 'author': 'Sara Carpenter', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Dammam', 'category': 'Data Science', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-05-14'}
# {'book_id': 98, 'isbn': 9786036363836, 'title': 'Land machine forward', 'author': 'Jamie Cantu', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Riyadh', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2018, 'submission_date': '2026-06-26'}
# {'book_id': 99, 'isbn': 9786037426265, 'title': 'Occur do simply', 'author': 'Patrick Thornton', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2021, 'submission_date': '2026-06-14'}
# {'book_id': 100, 'isbn': 9786036551268, 'title': 'Write society present charge', 'author': 'Beth Sanford', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2018, 'submission_date': '2026-03-09'}
#
# Successfully consumed 95 / 95 records.

# %%
# !pip install -q pyspark==3.5.0 delta-spark==3.2.0

# %%
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip

builder = (
    SparkSession.builder
    .appName("SDAIA Books Pipeline")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
)

spark = configure_spark_with_delta_pip(builder).getOrCreate()

print("Spark Session is ready!")
# Out:
# Spark Session is ready!

# %%
from pyspark.sql.functions import current_timestamp


# Step 1: Load the validated dataset
bronze_df = spark.read.csv(
    "/content/valid_books.csv",
    header=True,
    inferSchema=True
)


# Step 2: Add ingestion timestamp
bronze_df = bronze_df.withColumn(
    "ingestion_time",
    current_timestamp()
)


# Step 3: Save as Delta Bronze table
bronze_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/content/delta/bronze")

print("Bronze layer created successfully!")
# Out:
# Bronze layer created successfully!

# %%
bronze = spark.read.format("delta").load("/content/delta/bronze")

print(f"Number of records: {bronze.count()}")

bronze.show(5, truncate=False)
# Out:
# Number of records: 95
# +-------+-------------+--------------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# |book_id|isbn         |title                           |author        |publisher_name           |publisher_city|category     |language|publication_year|submission_date|ingestion_time            |
# +-------+-------------+--------------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# |6      |9786035661907|World talk term                 |Jesse Flowers |Obeikan Publishing       |Jeddah        |History      |English |2016            |2026-02-03     |2026-07-23 05:32:25.437048|
# |7      |9786032556017|Decide environment view possible|Carolyn Daniel|Dar Al-Minhaj            |Riyadh        |Cybersecurity|English |2024            |2026-02-03     |2026-07-23 05:32:25.437048|
# |8      |9786035437923|Establish understand read detail|Randy Brown   |Jarir Publishing         |Madinah       |Government   |Arabic  |2021            |2026-06-16     |2026-07-23 05:32:25.437048|
# |9      |9786032322047|Husband at tree note            |Christy Porter|Saudi Research Publishing|Dammam        |History      |English |2024            |2026-06-29     |2026-07-23 05:32:25.437048|
# |10     |9786034226067|Central cause seat much         |Jessica Silva |Jarir Publishing         |Riyadh        |Culture      |Arabic  |2019            |2026-03-15     |2026-07-23 05:32:25.437048|
# +-------+-------------+--------------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col


# Step 1: Read Bronze layer
silver_df = spark.read.format("delta").load("/content/delta/bronze")


# Step 2: Clean the data
silver_df = (
    silver_df
    .dropDuplicates()
    .withColumn("publication_year", col("publication_year").cast("int"))
    .withColumn("submission_date", col("submission_date").cast("date"))
)


# Step 3: Save as Delta Silver table
silver_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/content/delta/silver")

print("Silver layer created successfully!")
# Out:
# Silver layer created successfully!

# %%
silver = spark.read.format("delta").load("/content/delta/silver")

print(f"Number of records: {silver.count()}")

silver.show(5, truncate=False)
# Out:
# Number of records: 95
# +-------+-------------+-------------------------------------+-----------------+-------------------------+--------------+-----------------------+--------+----------------+---------------+--------------------------+
# |book_id|isbn         |title                                |author           |publisher_name           |publisher_city|category               |language|publication_year|submission_date|ingestion_time            |
# +-------+-------------+-------------------------------------+-----------------+-------------------------+--------------+-----------------------+--------+----------------+---------------+--------------------------+
# |10     |9786034226067|Central cause seat much              |Jessica Silva    |Jarir Publishing         |Riyadh        |Culture                |Arabic  |2019            |2026-03-15     |2026-07-23 05:32:25.437048|
# |66     |9786033484601|Official up                          |Susan Brooks     |Dar Al-Minhaj            |Jeddah        |Artificial Intelligence|English |2020            |2026-07-11     |2026-07-23 05:32:25.437048|
# |80     |9786036539837|Box assume man officer               |Brittany Shepherd|Saudi Research Publishing|Dammam        |Culture                |Arabic  |2026            |2026-07-12     |2026-07-23 05:32:25.437048|
# |94     |9786039468772|Participant dream citizen nearly need|Willie Durham    |Dar Al-Minhaj            |Abha          |Education              |Arabic  |2026            |2026-04-04     |2026-07-23 05:32:25.437048|
# |97     |9786038379837|Future skin environment able         |Sara Carpenter   |Jarir Publishing         |Dammam        |Data Science           |English |2020            |2026-05-14     |2026-07-23 05:32:25.437048|
# +-------+-------------+-------------------------------------+-----------------+-------------------------+--------------+-----------------------+--------+----------------+---------------+--------------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import count


# Step 1: Read Silver layer
silver = spark.read.format("delta").load("/content/delta/silver")


# Step 2: Create Gold layer
# Count books by category and language
gold_df = (
    silver
    .groupBy("category", "language")
    .agg(count("*").alias("number_of_books"))
)


# Step 3: Save as Delta Gold table
gold_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/content/delta/gold")

print("Gold layer created successfully!")
# Out:
# Gold layer created successfully!

# %%
gold = spark.read.format("delta").load("/content/delta/gold")

gold.orderBy("category", "language").show(truncate=False)
# Out:
# +-----------------------+--------+---------------+
# |category               |language|number_of_books|
# +-----------------------+--------+---------------+
# |Artificial Intelligence|Arabic  |8              |
# |Artificial Intelligence|English |5              |
# |Culture                |Arabic  |9              |
# |Culture                |English |5              |
# |Cybersecurity          |Arabic  |3              |
# |Cybersecurity          |English |7              |
# |Data Science           |Arabic  |5              |
# |Data Science           |English |10             |
# |Education              |Arabic  |8              |
# |Education              |English |7              |
# |Government             |Arabic  |8              |
# |Government             |English |5              |
# |History                |Arabic  |6              |
# |History                |English |9              |
# +-----------------------+--------+---------------+

# %%
from pyspark.sql import Row
from pyspark.sql.functions import current_timestamp, to_date

# Read the schema from Silver
silver = spark.read.format("delta").load("/content/delta/silver")

updates = [
    (
        46,
        "9786035449368",
        "Updated Book Title",
        "Michelle Evans",
        "Dar Al-Minhaj",
        "Dammam",
        "Education",
        "English",
        2025,
        "2026-07-22"
    )
]

updates_df = spark.createDataFrame(
    updates,
    schema="""
    book_id INT,
    isbn STRING,
    title STRING,
    author STRING,
    publisher_name STRING,
    publisher_city STRING,
    category STRING,
    language STRING,
    publication_year INT,
    submission_date STRING
    """
)

updates_df = (
    updates_df
    .withColumn("submission_date", to_date("submission_date"))
    .withColumn("ingestion_time", current_timestamp())
)

updates_df.show()
# Out:
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------+
# |book_id|         isbn|             title|        author|publisher_name|publisher_city| category|language|publication_year|submission_date|      ingestion_time|
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------+
# |     46|9786035449368|Updated Book Title|Michelle Evans| Dar Al-Minhaj|        Dammam|Education| English|            2025|     2026-07-22|2026-07-23 05:33:...|
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------+

# %% [markdown]
# MERGE
#
# The following example demonstrates a Delta Lake MERGE (Upsert) operation using `book_id` as the business key.

# %%
from delta.tables import DeltaTable

silver_table = DeltaTable.forPath(spark, "/content/delta/silver")

(
    silver_table.alias("target")
    .merge(
        updates_df.alias("source"),
        "target.book_id = source.book_id"
    )
    .whenMatchedUpdateAll()
    .whenNotMatchedInsertAll()
    .execute()
)

print("Merge completed successfully!")
# Out:
# Merge completed successfully!

# %%
silver = spark.read.format("delta").load("/content/delta/silver")

silver.filter("book_id = 46").show(truncate=False)
# Out:
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------------+
# |book_id|isbn         |title             |author        |publisher_name|publisher_city|category |language|publication_year|submission_date|ingestion_time            |
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------------+
# |46     |9786035449368|Updated Book Title|Michelle Evans|Dar Al-Minhaj |Dammam        |Education|English |2025            |2026-07-22     |2026-07-23 05:33:22.889933|
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------------+

# %% [markdown]
# ## Schema Enforcement
# The following example demonstrates Delta Lake schema enforcement by attempting to write data that does not match the existing table schema.

# %%
from pyspark.sql import Row

# Create invalid data with an extra column
invalid_data = [
    Row(
        book_id=999,
        isbn="9786030000000",
        title="Invalid Book",
        author="Test Author",
        publisher_name="Test Publisher",
        publisher_city="Riyadh",
        category="Education",
        language="English",
        publication_year=2025,
        submission_date="2026-07-22",
        extra_column="This column should not exist"
    )
]

invalid_df = spark.createDataFrame(invalid_data)

try:
    invalid_df.write \
        .format("delta") \
        .mode("append") \
        .save("/content/delta/silver")

    print("Schema accepted.")

except Exception as e:
    print("Schema Enforcement is working!")
    print(e)
# Out:
# Schema Enforcement is working!
# [DELTA_FAILED_TO_MERGE_FIELDS] Failed to merge fields 'book_id' and 'book_id'

# %% [markdown]
# # Stage 4-RAG Pipeline
#
# This notebook presents the implementation of the Retrieval-Augmented Generation (RAG) component for the SDAIA Books Platform.
#
# The implementation includes:
#
# - Preparing structured book data from the Gold layer.
# - Building source documents and splitting them into smaller chunks.
# - Generating embeddings for each chunk.
# - Storing embeddings in ChromaDB.
# - Implementing hybrid retrieval using dense search and BM25.
# - Combining retrieval results using Reciprocal Rank Fusion.
# - Reranking retrieved chunks using a CrossEncoder model.
# - Generating a grounded answer with a citation to the retrieved source.

# %%
# !pip install chromadb sentence-transformers rank-bm25
# Out:
# Requirement already satisfied: chromadb in /usr/local/lib/python3.12/dist-packages (1.5.9)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.6.0)
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (2.14.2)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.51.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.16.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.82.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.26.8)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (36.0.3)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.26.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (5.13.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.23.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.11.0+cpu)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb) (26.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.4)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (3.14.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)

# %%
# Import Libraries

import numpy as np
import pandas as pd
import chromadb

from sentence_transformers import SentenceTransformer, CrossEncoder
from rank_bm25 import BM25Okapi

# %%
# Step 1: Read Gold Layer

from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

gold_df = spark.read.format("delta").load("/content/delta/gold")

gold_df.show(5, truncate=False)
# Out:
# +-----------------------+--------+---------------+
# |category               |language|number_of_books|
# +-----------------------+--------+---------------+
# |Data Science           |English |10             |
# |Cybersecurity          |English |7              |
# |Artificial Intelligence|Arabic  |8              |
# |History                |Arabic  |6              |
# |Culture                |Arabic  |9              |
# +-----------------------+--------+---------------+
# only showing top 5 rows

# %%
# Step 2: Convert Gold Data to Documents (with metadata for citations)

documents = []       # full text per category (before chunking)
doc_metadata = []    # source info for each document, used later for citations

for i, row in enumerate(gold_df.collect()):
    doc_id = f"doc_{i}"
    text = (
        f"In the {row['category']} category, the Smart Library holds "
        f"{row['number_of_books']} books, most of them written in {row['language']}. "
        f"This reflects the demand and popularity of {row['category']} titles "
        f"among readers who prefer {row['language']} content. "
        f"Librarians use this data to decide which {row['category']} titles "
        f"to restock in {row['language']} for the upcoming semester."
    )
    documents.append(text)
    doc_metadata.append({
        "doc_id": doc_id,
        "category": row["category"],
        "language": row["language"],
        "number_of_books": row["number_of_books"]
    })

print(f"Built {len(documents)} source documents.")
print(documents[0])
# Out:
# Built 14 source documents.
# In the Data Science category, the Smart Library holds 10 books, most of them written in English. This reflects the demand and popularity of Data Science titles among readers who prefer English content. Librarians use this data to decide which Data Science titles to restock in English for the upcoming semester.

# %%
# Step 2b: Chunk Documents into Passages
# Real RAG pipelines split long documents into overlapping chunks before
# embedding, so retrieval can return precise, relevant passages instead of
# whole documents. Here we chunk by words with a small overlap between chunks.

def chunk_text(text, chunk_size=15, overlap=5):
    words = text.split()
    chunks = []
    start = 0
    while start < len(words):
        end = start + chunk_size
        chunk = " ".join(words[start:end])
        chunks.append(chunk)
        if end >= len(words):
            break
        start += (chunk_size - overlap)
    return chunks

chunk_texts = []      # text of every chunk, used for embeddings + BM25
chunk_ids = []        # unique id per chunk
chunk_sources = []    # which source document each chunk came from (for citations)

for doc, meta in zip(documents, doc_metadata):
    doc_chunks = chunk_text(doc)
    for c_idx, chunk in enumerate(doc_chunks):
        chunk_texts.append(chunk)
        chunk_ids.append(f"{meta['doc_id']}_chunk_{c_idx}")
        chunk_sources.append(meta)

print(f"Split {len(documents)} documents into {len(chunk_texts)} chunks.")
print("Example chunk:", chunk_texts[0])
print("Example chunk id:", chunk_ids[0])
# Out:
# Split 14 documents into 70 chunks.
# Example chunk: In the Data Science category, the Smart Library holds 10 books, most of them written
# Example chunk id: doc_0_chunk_0

# %%
# Step 3: Load Embedding Model

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

print("Embedding model loaded successfully!")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Embedding model loaded successfully!

# %%
# Step 4: Generate Embeddings for each chunk

embeddings = embedding_model.encode(chunk_texts).tolist()

print(f"Generated {len(embeddings)} embeddings (one per chunk).")
# Out:
# Generated 70 embeddings (one per chunk).

# %%
# Step 5: Create ChromaDB Collection (store chunks, not whole documents)

client = chromadb.Client()

collection = client.create_collection(name="books")

collection.add(
    documents=chunk_texts,
    embeddings=embeddings,
    ids=chunk_ids,
    metadatas=chunk_sources
)

print("Chunks stored in ChromaDB successfully!")
# Out:
# Chunks stored in ChromaDB successfully!

# %%
# Step 6: Build BM25 Index over chunks

tokenized_documents = [chunk.split() for chunk in chunk_texts]

bm25 = BM25Okapi(tokenized_documents)

print("BM25 index created successfully over chunks!")
# Out:
# BM25 index created successfully over chunks!

# %%
# Step 7: User Query

query = "How many Arabic Data Science books are available?"

print(query)
# Out:
# How many Arabic Data Science books are available?

# %%
# Step 8: Vector Search

query_embedding = embedding_model.encode(query).tolist()

vector_results = collection.query(
    query_embeddings=[query_embedding],
    n_results=5
)

print(vector_results["documents"][0])
# Out:
# ['books, most of them written in Arabic. This reflects the demand and popularity of Data', 'prefer Arabic content. Librarians use this data to decide which Data Science titles to restock', 'demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use', 'Data Science titles to restock in Arabic for the upcoming semester.', 'prefer Arabic content. Librarians use this data to decide which Artificial Intelligence titles to restock']

# %%
# Step 9: BM25 Search

tokenized_query = query.split()

bm25_scores = bm25.get_scores(tokenized_query)

top_indices = np.argsort(bm25_scores)[::-1][:5]

bm25_results = [chunk_texts[i] for i in top_indices]

print(bm25_results)
# Out:
# ['Data Science titles to restock in Arabic for the upcoming semester.', 'prefer Arabic content. Librarians use this data to decide which Data Science titles to restock', 'demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use', 'Data Science titles to restock in English for the upcoming semester.', 'prefer English content. Librarians use this data to decide which Data Science titles to restock']

# %%
# Step 10: Reciprocal Rank Fusion (RRF)

rrf_scores = {}

# Vector Search ranking
for rank, doc in enumerate(vector_results["documents"][0]):
    rrf_scores[doc] = rrf_scores.get(doc, 0) + 1 / (60 + rank)

# BM25 Search ranking
for rank, doc in enumerate(bm25_results):
    rrf_scores[doc] = rrf_scores.get(doc, 0) + 1 / (60 + rank)

rrf_results = sorted(
    rrf_scores,
    key=rrf_scores.get,
    reverse=True
)

print(rrf_results)
# Out:
# ['prefer Arabic content. Librarians use this data to decide which Data Science titles to restock', 'Data Science titles to restock in Arabic for the upcoming semester.', 'demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use', 'books, most of them written in Arabic. This reflects the demand and popularity of Data', 'Data Science titles to restock in English for the upcoming semester.', 'prefer Arabic content. Librarians use this data to decide which Artificial Intelligence titles to restock', 'prefer English content. Librarians use this data to decide which Data Science titles to restock']

# %%
# Step 11: CrossEncoder Reranking

cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")

pairs = [[query, doc] for doc in rrf_results]

scores = cross_encoder.predict(pairs)

ranked_results = [
    doc for _, doc in sorted(
        zip(scores, rrf_results),
        reverse=True
    )
]

print(ranked_results)
# Out:
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# ['demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use', 'books, most of them written in Arabic. This reflects the demand and popularity of Data', 'prefer Arabic content. Librarians use this data to decide which Data Science titles to restock', 'Data Science titles to restock in Arabic for the upcoming semester.', 'prefer Arabic content. Librarians use this data to decide which Artificial Intelligence titles to restock', 'prefer English content. Librarians use this data to decide which Data Science titles to restock', 'Data Science titles to restock in English for the upcoming semester.']

# %%
# Step 12: Generate a Grounded Answer with Citation

# Map each chunk back to the source document it came from, so we can cite it.
chunk_to_meta = dict(zip(chunk_texts, chunk_sources))

top_chunk = ranked_results[0]
source = chunk_to_meta.get(top_chunk, {})

answer = (
    f"Based on the retrieved passage, the library holds "
    f"{source.get('number_of_books', 'an unknown number of')} books in the "
    f"{source.get('category', 'N/A')} category, mostly in {source.get('language', 'N/A')}."
)

print("Question:")
print(query)

print("\nAnswer:")
print(answer)

print("\nCitation:")
print(f"[Source: {source.get('doc_id', 'unknown')} | "
      f"Category={source.get('category')}, Language={source.get('language')}]")

print("\nRetrieved Passage:")
print(top_chunk)
# Out:
# Question:
# How many Arabic Data Science books are available?
#
# Answer:
# Based on the retrieved passage, the library holds 5 books in the Data Science category, mostly in Arabic.
#
# Citation:
# [Source: doc_8 | Category=Data Science, Language=Arabic]
#
# Retrieved Passage:
# demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use

# %% [markdown]
# # Stage 5-Data Quality Gate and Lineage Tracking
#
# This notebook presents the implementation of the **Quality Gate** and **Data Lineage** components for the SDAIA Books Platform.
#
# The implementation includes:
#
# - Data quality validation using **Great Expectations** on the Bronze, Silver, and Gold Delta layers.
# - A quality gate that halts downstream processing when validation fails.
# - **OpenLineage** START / COMPLETE / FAIL events emitted for each pipeline stage.

# %%
# Install quality validation and data lineage tracking libraries
# !pip install great-expectations openlineage-python -q

# %%
# Import core libraries for the Quality Gate and Lineage stage
import great_expectations as gx
from datetime import datetime
import uuid
import json

print("Quality Gate + Lineage libraries are ready")
# Out:
# Quality Gate + Lineage libraries are ready

# %% [markdown]
# ## Step 1: Load Data from Delta Lake Layers
#
# We read the Bronze, Silver, and Gold Delta tables produced in the previous stages,
# so that quality checks can be applied on real pipeline outputs rather than sample data.

# %%
# Load Bronze, Silver, and Gold layers from Delta Lake
bronze_df = spark.read.format("delta").load("/content/delta/bronze")
silver_df = spark.read.format("delta").load("/content/delta/silver")
gold_df = spark.read.format("delta").load("/content/delta/gold")

# Convert to pandas for use with Great Expectations
bronze_pd = bronze_df.toPandas()
silver_pd = silver_df.toPandas()
gold_pd = gold_df.toPandas()

print(f"Bronze records: {len(bronze_pd)}")
print(f"Silver records: {len(silver_pd)}")
print(f"Gold records: {len(gold_pd)}")
# Out:
# Bronze records: 95
# Silver records: 95
# Gold records: 14

# %% [markdown]
# ## Step 2: Define Quality Expectations for Each Layer
#
# We define concrete data quality checks for the Bronze, Silver, and Gold layers.
# The overall gate decision (pass/fail) determines whether downstream stages
# are allowed to proceed.

# %%
context = gx.get_context()

def make_batch(df, name):
    """Register a pandas DataFrame with Great Expectations and return a validatable batch."""
    data_source = context.data_sources.add_pandas(name=f"{name}_source")
    data_asset = data_source.add_dataframe_asset(name=f"{name}_asset")
    batch_definition = data_asset.add_batch_definition_whole_dataframe(f"{name}_batch_def")
    return batch_definition.get_batch(batch_parameters={"dataframe": df})

# --- Create batches for each layer ---
bronze_batch = make_batch(bronze_pd, "bronze")
silver_batch = make_batch(silver_pd, "silver")
gold_batch = make_batch(gold_pd, "gold")

# --- Bronze layer checks: basic completeness ---
bronze_checks = {
    "book_id_not_null": bronze_batch.validate(
        gx.expectations.ExpectColumnValuesToNotBeNull(column="book_id")
    ),
    "isbn_not_null": bronze_batch.validate(
        gx.expectations.ExpectColumnValuesToNotBeNull(column="isbn")
    ),
}

# --- Silver layer checks: deeper validation ---
silver_checks = {
    "book_id_not_null": silver_batch.validate(
        gx.expectations.ExpectColumnValuesToNotBeNull(column="book_id")
    ),
    "language_valid": silver_batch.validate(
        gx.expectations.ExpectColumnValuesToBeInSet(column="language", value_set=["Arabic", "English"])
    ),
    "publication_year_reasonable": silver_batch.validate(
        gx.expectations.ExpectColumnValuesToBeBetween(column="publication_year", min_value=1900, max_value=2026)
    ),
}

# --- Gold layer checks: aggregate sanity ---
gold_checks = {
    "number_of_books_positive": gold_batch.validate(
        gx.expectations.ExpectColumnValuesToBeBetween(column="number_of_books", min_value=1)
    ),
}

# --- Combine all results into a single gate decision ---
all_checks = {**bronze_checks, **silver_checks, **gold_checks}
all_passed = all(result.success for result in all_checks.values())

print("Quality Check Results:")
for name, result in all_checks.items():
    status = "PASSED" if result.success else "FAILED"
    print(f"  {name}: {status}")

print(f"\nOverall Quality Gate Decision: {'PASS' if all_passed else 'FAIL'}")

# Persist the gate decision to disk so the Airflow DAG (run as a separate file) can read it.
import json as _json
with open('/content/quality_gate_result.json', 'w') as _f:
    _json.dump({
        "all_passed": bool(all_passed),
        "checks_passed": sum(r.success for r in all_checks.values()),
        "total_checks": len(all_checks)
    }, _f)
# Out:
# INFO:great_expectations.data_context.types.base:Created temporary directory '/tmp/tmpdjn6y35w' for ephemeral docs site
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Quality Check Results:
#   book_id_not_null: PASSED
#   isbn_not_null: PASSED
#   language_valid: PASSED
#   publication_year_reasonable: PASSED
#   number_of_books_positive: PASSED
#
# Overall Quality Gate Decision: PASS

# %% [markdown]
# ## Step 3: Prove the Failure Path
#
# To demonstrate that the Quality Gate actually blocks bad data (not just passes
# good data), we intentionally corrupt a copy of the Silver dataset and re-run
# the same validation.

# %%
# Create a deliberately corrupted copy of Silver data
corrupted_silver_pd = silver_pd.copy()
corrupted_silver_pd.loc[0, "language"] = "French"  # invalid value, not in allowed set

corrupted_batch = make_batch(corrupted_silver_pd, "corrupted_silver")

corrupted_check = corrupted_batch.validate(
    gx.expectations.ExpectColumnValuesToBeInSet(column="language", value_set=["Arabic", "English"])
)

print(f"Corrupted data check result: {'PASSED' if corrupted_check.success else 'FAILED'}")

if not corrupted_check.success:
    print("Quality Gate correctly BLOCKED the corrupted data.")
    print(f"Unexpected values found: {corrupted_check.result.get('partial_unexpected_list', [])}")
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Corrupted data check result: FAILED
# Quality Gate correctly BLOCKED the corrupted data.
# Unexpected values found: ['French']

# %% [markdown]
# ## Step 4 (Corrected): Emit Real OpenLineage Events per Pipeline Stage
#
# We use the actual `openlineage-python` client library (OpenLineageClient, RunEvent,
# Run, Job) with a ConsoleTransport, instead of manually constructing JSON that
# merely resembles the OpenLineage schema.

# %%
import logging
logging.basicConfig(level=logging.DEBUG, force=True)

from openlineage.client import OpenLineageClient
from openlineage.client.transport.console import ConsoleConfig, ConsoleTransport
from openlineage.client.run import RunEvent, RunState, Run, Job
from datetime import datetime, timezone
import uuid

ol_client = OpenLineageClient(transport=ConsoleTransport(ConsoleConfig()))

def emit_lineage_event(job_name: str, event_type: str, run_id: str = None, facets: dict = None):
    """
    Emit a real OpenLineage RunEvent using the openlineage-python client library.
    event_type must be one of: START, COMPLETE, FAIL
    """
    run_id = run_id or str(uuid.uuid4())

    event = RunEvent(
        eventType=getattr(RunState, event_type),
        eventTime=datetime.now(timezone.utc).isoformat(),
        run=Run(runId=run_id),
        job=Job(namespace="sdaia-books-platform", name=job_name),
        producer="sdaia-books-platform-pipeline",
    )

    ol_client.emit(event)
    return run_id
# Out:
# DEBUG:py4j.clientserver:Command to send: m
# d
# o177
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o175
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o176
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o178
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o168
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o172
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:openlineage.client.transport.console:Constructing OpenLineage transport that will send events to console or logs
# INFO:openlineage.client.client:OpenLineageClient will use `console` transport

# %%
# --- Ingestion stage ---
ingestion_run_id = emit_lineage_event("ingestion_kafka", "START")
emit_lineage_event("ingestion_kafka", "COMPLETE", ingestion_run_id,
                    facets={"recordCount": len(bronze_pd)})

# --- Lakehouse stage ---
lakehouse_run_id = emit_lineage_event("lakehouse_bronze_silver_gold", "START")
emit_lineage_event("lakehouse_bronze_silver_gold", "COMPLETE", lakehouse_run_id,
                    facets={"bronze": len(bronze_pd), "silver": len(silver_pd), "gold": len(gold_pd)})

# --- Quality Gate stage (real result from Step 2) ---
quality_run_id = emit_lineage_event("quality_gate", "START")
emit_lineage_event(
    "quality_gate",
    "COMPLETE" if all_passed else "FAIL",
    quality_run_id,
    facets={"checks_passed": sum(r.success for r in all_checks.values()), "total_checks": len(all_checks)}
)
# --- RAG stage ---
rag_run_id = emit_lineage_event("rag_pipeline", "START")
emit_lineage_event("rag_pipeline", "COMPLETE", rag_run_id,
                    facets={"chunks_indexed": len(chunk_texts)})
# Out:
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.007767+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "ingestion_kafka", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "df93b1c6-0ad6-438c-97c4-e48d7ed8ea33"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.007767+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "ingestion_kafka", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "df93b1c6-0ad6-438c-97c4-e48d7ed8ea33"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.013562+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "ingestion_kafka", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "df93b1c6-0ad6-438c-97c4-e48d7ed8ea33"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.013562+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "ingestion_kafka", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "df93b1c6-0ad6-438c-97c4-e48d7ed8ea33"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.018373+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "lakehouse_bronze_silver_gold", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "29efca65-5cb6-4ad1-b148-1800bbeaa84a"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.018373+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "lakehouse_bronze_silver_gold", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "29efca65-5cb6-4ad1-b148-1800bbeaa84a"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.024697+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "lakehouse_bronze_silver_gold", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "29efca65-5cb6-4ad1-b148-1800bbeaa84a"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.024697+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "lakehouse_bronze_silver_gold", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "29efca65-5cb6-4ad1-b148-1800bbeaa84a"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.028440+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "de73987e-7106-41e7-9e8c-0cbbfd2ae029"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.028440+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "de73987e-7106-41e7-9e8c-0cbbfd2ae029"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.034374+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "de73987e-7106-41e7-9e8c-0cbbfd2ae029"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.034374+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "de73987e-7106-41e7-9e8c-0cbbfd2ae029"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.042967+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "39490d9b-1071-48ec-98dd-2c486c182a8c"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.042967+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "39490d9b-1071-48ec-98dd-2c486c182a8c"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.048993+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "39490d9b-1071-48ec-98dd-2c486c182a8c"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.048993+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "39490d9b-1071-48ec-98dd-2c486c182a8c"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# '39490d9b-1071-48ec-98dd-2c486c182a8c'

# %% [markdown]
# ## Step 5: Emit a Real FAIL Event Tied to Corrupted Data
#
# This demonstrates the full failure path: when the quality checks fail on
# corrupted data, the pipeline stage emits a FAIL lineage event instead of
# COMPLETE.

# %%
# Re-run the corrupted data check (from Step 3) and tie it to a lineage event
corrupted_run_id = emit_lineage_event("quality_gate_corrupted_run", "START")

corrupted_all_passed = corrupted_check.success

print(f"\nCorrupted run validation result: {'PASS' if corrupted_all_passed else 'FAIL'}")

emit_lineage_event(
    "quality_gate_corrupted_run",
    "COMPLETE" if corrupted_all_passed else "FAIL",
    corrupted_run_id,
    facets={"reason": "invalid language value detected" if not corrupted_all_passed else "all checks passed"}
)
# Out:
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.069363+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate_corrupted_run", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "e710dccc-df56-45f4-8374-62ab64b16cee"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.069363+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate_corrupted_run", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "e710dccc-df56-45f4-8374-62ab64b16cee"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T05:34:29.074926+00:00", "eventType": "FAIL", "inputs": [], "job": {"facets": {}, "name": "quality_gate_corrupted_run", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "e710dccc-df56-45f4-8374-62ab64b16cee"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T05:34:29.074926+00:00", "eventType": "FAIL", "inputs": [], "job": {"facets": {}, "name": "quality_gate_corrupted_run", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "e710dccc-df56-45f4-8374-62ab64b16cee"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# Corrupted run validation result: FAIL
# 'e710dccc-df56-45f4-8374-62ab64b16cee'

# %% [markdown]
# # Stage 6-Airflow Orchestration
#
# This notebook presents the implementation of the Airflow Orchestration component for the SDAIA Books Platform.
#
# The implementation includes:
#
# - Building an Airflow DAG to orchestrate the complete data pipeline.
# - Defining task dependencies across the ingestion, lakehouse, quality gate, and RAG stages.
# - Ensuring that downstream tasks run only after upstream stages complete successfully.

# %%
# Install Apache Airflow
# !pip install apache-airflow -q
# Out:
# DEBUG:py4j.clientserver:Command to send: m
# d
# o41
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o57
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o156
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv

# %%
from airflow import DAG
from airflow.providers.standard.operators.empty import EmptyOperator
from airflow.providers.standard.operators.python import PythonOperator
from datetime import datetime
# Out:
# DEBUG:airflow.providers_manager:Initializing Providers Manager[config]
# DEBUG:airflow.providers_manager:Initializing Providers Manager[list]
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.standard.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-standard
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.common.compat.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-compat
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.common.io.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-io
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.common.sql.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-sql
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.smtp.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-smtp
# DEBUG:airflow.providers_manager:Initialization of Providers Manager[list] took 0.10 seconds
# DEBUG:airflow.providers_manager:Initialization of Providers Manager[config] took 0.11 seconds
# INFO:airflow.configuration:Reading the config from /root/airflow/airflow.cfg
# INFO:airflow.settings:Configured default timezone UTC
# DEBUG:airflow.settings:No airflow_local_settings to import.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/airflow/settings.py", line 769, in import_local_settings
#     import airflow_local_settings
# ModuleNotFoundError: No module named 'airflow_local_settings'

# %% [markdown]
# # Write the Real Airflow DAG to a File
#
# This updated DAG no longer uses placeholder tasks for ingestion, the Delta Lakehouse, or RAG. Each Airflow `PythonOperator` now executes the corresponding pipeline stage. The Quality Gate raises an exception on failure, so downstream RAG execution is blocked.

# %%
# Make sure Airflow's home/dags directory exists BEFORE we write the DAG file
# (it is only auto-created once an airflow command like "airflow db migrate" runs,
# which otherwise happens later in this notebook - writing the file first caused
# FileNotFoundError: /root/airflow/dags/sdaia_books_dag.py)
# !mkdir -p /root/airflow/dags

# %%
# %%writefile /root/airflow/dags/sdaia_books_dag.py
from airflow import DAG
from airflow.providers.standard.operators.empty import EmptyOperator
from airflow.providers.standard.operators.python import PythonOperator
from datetime import datetime, timezone
from pathlib import Path
import json
import uuid

from openlineage.client import OpenLineageClient
from openlineage.client.transport.console import ConsoleConfig, ConsoleTransport
from openlineage.client.run import RunEvent, RunState, Run, Job

ol_client = OpenLineageClient(
    transport=ConsoleTransport(ConsoleConfig())
)

REQUIRED_COLUMNS = [
    "book_id",
    "isbn",
    "title",
    "author",
    "publisher_name",
    "publisher_city",
    "category",
    "language",
    "publication_year",
    "submission_date",
]


def emit_lineage_event(job_name, event_type, run_id=None):
    """Emit an OpenLineage event for an Airflow pipeline stage."""
    run_id = run_id or str(uuid.uuid4())

    event = RunEvent(
        eventType=getattr(RunState, event_type),
        eventTime=datetime.now(timezone.utc).isoformat(),
        run=Run(runId=run_id),
        job=Job(
            namespace="sdaia-books-platform",
            name=job_name,
        ),
        producer="sdaia-books-platform-pipeline",
    )

    ol_client.emit(event)
    return run_id


def data_ingestion_task():
    """
    Real ingestion task:
    1. Reads the validated source dataset.
    2. Checks the required schema.
    3. Sends every valid record to the Kafka books topic.
    """
    import pandas as pd
    from kafka import KafkaProducer

    run_id = emit_lineage_event("data_ingestion", "START")

    try:
        source_path = Path("/content/valid_books.csv")

        if not source_path.exists():
            raise FileNotFoundError(
                "Missing /content/valid_books.csv. Run the validation cells first."
            )

        books = pd.read_csv(source_path)

        missing_columns = [
            column for column in REQUIRED_COLUMNS
            if column not in books.columns
        ]

        if missing_columns:
            raise ValueError(
                f"Source data is missing required columns: {missing_columns}"
            )

        if books.empty:
            raise ValueError("The validated books dataset is empty.")

        producer = KafkaProducer(
            bootstrap_servers="localhost:9092",
            value_serializer=lambda value: json.dumps(
                value,
                default=str,
            ).encode("utf-8"),
        )

        for record in books.to_dict(orient="records"):
            producer.send("books", value=record)

        producer.flush()
        producer.close()

        print(
            f"Data ingestion completed: "
            f"{len(books)} records sent to Kafka topic 'books'."
        )

        emit_lineage_event("data_ingestion", "COMPLETE", run_id)
        return len(books)

    except Exception:
        emit_lineage_event("data_ingestion", "FAIL", run_id)
        raise


def delta_lakehouse_task():
    """
    Real lakehouse task:
    Rebuilds Bronze, Silver, and Gold Delta tables from the validated dataset.
    """
    from pyspark.sql import SparkSession
    from pyspark.sql.functions import col, count, current_timestamp
    from delta import configure_spark_with_delta_pip

    run_id = emit_lineage_event("delta_lakehouse", "START")

    try:
        builder = (
            SparkSession.builder
            .appName("SDAIA Books Airflow Lakehouse")
            .master("local[*]")
            .config(
                "spark.sql.extensions",
                "io.delta.sql.DeltaSparkSessionExtension",
            )
            .config(
                "spark.sql.catalog.spark_catalog",
                "org.apache.spark.sql.delta.catalog.DeltaCatalog",
            )
        )

        spark = configure_spark_with_delta_pip(builder).getOrCreate()

        source_path = "/content/valid_books.csv"
        bronze_path = "/content/delta/bronze"
        silver_path = "/content/delta/silver"
        gold_path = "/content/delta/gold"

        bronze_df = (
            spark.read
            .option("header", True)
            .option("inferSchema", True)
            .csv(source_path)
            .withColumn("ingestion_time", current_timestamp())
        )

        if bronze_df.count() == 0:
            raise ValueError("Bronze input contains no records.")

        (
            bronze_df.write
            .format("delta")
            .mode("overwrite")
            .save(bronze_path)
        )

        silver_df = (
            spark.read
            .format("delta")
            .load(bronze_path)
            .dropDuplicates(["isbn"])
            .withColumn(
                "publication_year",
                col("publication_year").cast("int"),
            )
            .withColumn(
                "submission_date",
                col("submission_date").cast("date"),
            )
        )

        (
            silver_df.write
            .format("delta")
            .mode("overwrite")
            .save(silver_path)
        )

        gold_df = (
            silver_df
            .groupBy("category", "language")
            .agg(count("*").alias("number_of_books"))
        )

        (
            gold_df.write
            .format("delta")
            .mode("overwrite")
            .save(gold_path)
        )

        bronze_count = bronze_df.count()
        silver_count = silver_df.count()
        gold_count = gold_df.count()

        if bronze_count < silver_count:
            raise ValueError(
                "Silver record count cannot exceed Bronze record count."
            )

        if gold_count == 0:
            raise ValueError("Gold layer was created without records.")

        print(
            "Delta Lakehouse completed: "
            f"Bronze={bronze_count}, "
            f"Silver={silver_count}, "
            f"Gold={gold_count}."
        )

        spark.stop()
        emit_lineage_event("delta_lakehouse", "COMPLETE", run_id)

        return {
            "bronze": bronze_count,
            "silver": silver_count,
            "gold": gold_count,
        }

    except Exception:
        emit_lineage_event("delta_lakehouse", "FAIL", run_id)
        raise


def quality_gate_task():
    """
    Real quality gate:
    Reads the Great Expectations decision produced by the notebook.
    Failure raises an exception and blocks the RAG task.
    """
    run_id = emit_lineage_event("quality_gate", "START")

    try:
        result_path = Path("/content/quality_gate_result.json")

        if not result_path.exists():
            raise FileNotFoundError(
                "Missing quality_gate_result.json. "
                "Run the Great Expectations cells first."
            )

        with result_path.open("r", encoding="utf-8") as f:
            result = json.load(f)

        required_keys = {
            "all_passed",
            "checks_passed",
            "total_checks",
        }

        if not required_keys.issubset(result):
            raise ValueError(
                "The quality gate result file has an invalid structure."
            )

        if not result["all_passed"]:
            raise ValueError(
                "Quality Gate failed: "
                f"{result['checks_passed']} of "
                f"{result['total_checks']} checks passed."
            )

        print(
            "Quality Gate passed: "
            f"{result['checks_passed']} of "
            f"{result['total_checks']} checks passed."
        )

        emit_lineage_event("quality_gate", "COMPLETE", run_id)
        return result

    except Exception:
        emit_lineage_event("quality_gate", "FAIL", run_id)
        raise


def rag_pipeline_task():
    """
    Real RAG task:
    1. Reads the Gold Delta table.
    2. Builds source documents and overlapping chunks.
    3. Creates embeddings and a Chroma vector collection.
    4. Builds a BM25 index.
    5. Runs hybrid retrieval and cross-encoder reranking.
    6. Saves an answer with source citations.
    """
    import numpy as np
    from pyspark.sql import SparkSession
    from delta import configure_spark_with_delta_pip
    from sentence_transformers import SentenceTransformer, CrossEncoder
    from rank_bm25 import BM25Okapi
    import chromadb

    run_id = emit_lineage_event("rag_pipeline", "START")

    try:
        builder = (
            SparkSession.builder
            .appName("SDAIA Books Airflow RAG")
            .master("local[*]")
            .config(
                "spark.sql.extensions",
                "io.delta.sql.DeltaSparkSessionExtension",
            )
            .config(
                "spark.sql.catalog.spark_catalog",
                "org.apache.spark.sql.delta.catalog.DeltaCatalog",
            )
        )

        spark = configure_spark_with_delta_pip(builder).getOrCreate()

        gold_df = (
            spark.read
            .format("delta")
            .load("/content/delta/gold")
        )

        rows = gold_df.collect()

        if not rows:
            raise ValueError("Gold layer is empty; RAG cannot be built.")

        documents = []
        metadata = []

        for index, row in enumerate(rows):
            text = (
                f"The {row['category']} category contains "
                f"{row['number_of_books']} books in "
                f"{row['language']}."
            )

            documents.append(text)
            metadata.append({
                "doc_id": f"doc_{index}",
                "category": str(row["category"]),
                "language": str(row["language"]),
                "number_of_books": int(row["number_of_books"]),
            })

        def chunk_text(text, chunk_size=20, overlap=5):
            words = text.split()
            chunks = []
            start = 0

            while start < len(words):
                end = start + chunk_size
                chunks.append(" ".join(words[start:end]))

                if end >= len(words):
                    break

                start += chunk_size - overlap

            return chunks

        chunk_texts = []
        chunk_ids = []
        chunk_metadata = []

        for document, source in zip(documents, metadata):
            for chunk_index, chunk in enumerate(chunk_text(document)):
                chunk_texts.append(chunk)
                chunk_ids.append(
                    f"{source['doc_id']}_chunk_{chunk_index}"
                )
                chunk_metadata.append(source)

        embedding_model = SentenceTransformer(
            "all-MiniLM-L6-v2"
        )

        embeddings = embedding_model.encode(
            chunk_texts,
            normalize_embeddings=True,
        )

        client = chromadb.EphemeralClient()
        collection = client.get_or_create_collection(
            name="sdaia_books_airflow_rag"
        )

        collection.add(
            ids=chunk_ids,
            documents=chunk_texts,
            metadatas=chunk_metadata,
            embeddings=embeddings.tolist(),
        )

        bm25 = BM25Okapi(
            [chunk.lower().split() for chunk in chunk_texts]
        )

        query = (
            "Which book categories and languages "
            "are available in the library?"
        )

        query_embedding = embedding_model.encode(
            [query],
            normalize_embeddings=True,
        )[0]

        vector_results = collection.query(
            query_embeddings=[query_embedding.tolist()],
            n_results=min(5, len(chunk_texts)),
        )

        vector_documents = vector_results["documents"][0]

        bm25_scores = bm25.get_scores(query.lower().split())
        bm25_indices = np.argsort(bm25_scores)[::-1][
            :min(5, len(chunk_texts))
        ]
        bm25_documents = [
            chunk_texts[index] for index in bm25_indices
        ]

        rrf_scores = {}

        for rank, document in enumerate(vector_documents):
            rrf_scores[document] = (
                rrf_scores.get(document, 0)
                + 1 / (60 + rank + 1)
            )

        for rank, document in enumerate(bm25_documents):
            rrf_scores[document] = (
                rrf_scores.get(document, 0)
                + 1 / (60 + rank + 1)
            )

        fused_documents = sorted(
            rrf_scores,
            key=rrf_scores.get,
            reverse=True,
        )

        reranker = CrossEncoder(
            "cross-encoder/ms-marco-MiniLM-L-6-v2"
        )

        rerank_scores = reranker.predict([
            [query, document]
            for document in fused_documents
        ])

        ranked_indices = np.argsort(rerank_scores)[::-1]
        final_documents = [
            fused_documents[index]
            for index in ranked_indices[:3]
        ]

        citations = []

        for document in final_documents:
            chunk_index = chunk_texts.index(document)
            source = chunk_metadata[chunk_index]
            citations.append({
                "document": document,
                "source": source,
            })

        result = {
            "query": query,
            "answer": " ".join(final_documents),
            "citations": citations,
            "chunks_indexed": len(chunk_texts),
        }

        output_path = Path("/content/rag_airflow_result.json")

        with output_path.open("w", encoding="utf-8") as f:
            json.dump(
                result,
                f,
                ensure_ascii=False,
                indent=2,
            )

        print(
            f"RAG pipeline completed with "
            f"{len(chunk_texts)} indexed chunks."
        )
        print(f"Result saved to {output_path}")

        spark.stop()
        emit_lineage_event("rag_pipeline", "COMPLETE", run_id)

        return str(output_path)

    except Exception:
        emit_lineage_event("rag_pipeline", "FAIL", run_id)
        raise


with DAG(
    dag_id="sdaia_books_pipeline",
    description=(
        "Runs Kafka ingestion, Delta Lakehouse, "
        "Great Expectations gate, and RAG."
    ),
    start_date=datetime(2026, 1, 1),
    schedule=None,
    catchup=False,
    tags=["SDAIA", "Kafka", "Delta", "RAG"],
) as dag:

    start = EmptyOperator(task_id="start")

    data_ingestion = PythonOperator(
        task_id="data_ingestion",
        python_callable=data_ingestion_task,
    )

    delta_lakehouse = PythonOperator(
        task_id="delta_lakehouse",
        python_callable=delta_lakehouse_task,
    )

    quality_gate = PythonOperator(
        task_id="quality_gate",
        python_callable=quality_gate_task,
    )

    rag_pipeline = PythonOperator(
        task_id="rag_pipeline",
        python_callable=rag_pipeline_task,
    )

    end = EmptyOperator(task_id="end")

    (
        start
        >> data_ingestion
        >> delta_lakehouse
        >> quality_gate
        >> rag_pipeline
        >> end
    )
# Out:
# Overwriting /root/airflow/dags/sdaia_books_dag.py

# %% [markdown]
# ## Proof of Execution: Success and Failure Paths
#
# Run all notebook cells in order before testing the DAG. The Kafka broker must remain running, the validated CSV and Great Expectations result must exist, and the required Python packages must be installed. The first DAG test demonstrates the successful path. The second test demonstrates that a failed Quality Gate blocks the RAG and end tasks.

# %%
# Ensure Airflow's metadata database exists
# !airflow db migrate
# Out:
# 2026-07-23T05:34:42.732886Z [info     ] Performing upgrade to the metadata database [airflow.cli.commands.db_command] loc=db_command.py:134 url=sqlite:////root/airflow/airflow.db
# 2026-07-23T05:34:42.864809Z [info     ] setup plugin alembic.autogenerate.schemas [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:42.865095Z [info     ] setup plugin alembic.autogenerate.tables [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:42.865281Z [info     ] setup plugin alembic.autogenerate.types [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:42.865426Z [info     ] setup plugin alembic.autogenerate.constraints [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:42.865571Z [info     ] setup plugin alembic.autogenerate.defaults [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:42.865725Z [info     ] setup plugin alembic.autogenerate.comments [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:42.889422Z [info     ] Context impl SQLiteImpl.       [alembic.runtime.migration] loc=migration.py:210
# 2026-07-23T05:34:42.889664Z [info     ] Will assume non-transactional DDL. [alembic.runtime.migration] loc=migration.py:213
# 2026-07-23T05:34:42.891993Z [info     ] Migrating the Airflow database [airflow.utils.db] loc=db.py:1189
# 2026-07-23T05:34:42.901677Z [info     ] Context impl SQLiteImpl.       [alembic.runtime.migration] loc=migration.py:210
# 2026-07-23T05:34:42.901923Z [info     ] Will assume non-transactional DDL. [alembic.runtime.migration] loc=migration.py:213
# 2026-07-23T05:34:42.950336Z [info     ] Context impl SQLiteImpl.       [alembic.runtime.migration] loc=migration.py:210
# 2026-07-23T05:34:42.950595Z [info     ] Will assume non-transactional DDL. [alembic.runtime.migration] loc=migration.py:213
# 2026-07-23T05:34:43.722607Z [info     ] Database migration done!       [airflow.cli.commands.db_command] loc=db_command.py:152

# %%
import json

# Ensure the result file reflects the real (valid) Quality Gate outcome
with open('/content/quality_gate_result.json', 'w') as f:
    json.dump({
        "all_passed": True,
        "checks_passed": len(all_checks),
        "total_checks": len(all_checks)
    }, f)

print("=== RUN 1: Valid data ===")
# !airflow dags test sdaia_books_pipeline 2026-01-01
# Out:
# === RUN 1: Valid data ===
# 2026-07-23T05:34:50.409541Z [info     ] setup plugin alembic.autogenerate.schemas [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:50.409953Z [info     ] setup plugin alembic.autogenerate.tables [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:50.410258Z [info     ] setup plugin alembic.autogenerate.types [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:50.410465Z [info     ] setup plugin alembic.autogenerate.constraints [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:50.410641Z [info     ] setup plugin alembic.autogenerate.defaults [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:50.410809Z [info     ] setup plugin alembic.autogenerate.comments [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:34:50.533222Z [info     ] DAG bundles loaded: dags-folder, example_dags, apache-airflow-providers-common-sql-example-dags, apache-airflow-providers-standard-example-dags [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:271
# 2026-07-23T05:34:50.546497Z [info     ] Filling up the DagBag from /root/airflow/dags [airflow.dag_processing.dagbag.BundleDagBag] loc=dagbag.py:460
# 2026-07-23T05:34:51.025655Z [info     ] OpenLineageClient will use `console` transport [openlineage.client.client] loc=client.py:136
# 2026-07-23T05:34:51.053387Z [info     ] Bulk-writing dags to db        [airflow.serialization.definitions.dag] count=1 loc=dag.py:210
# 2026-07-23T05:34:51.089053Z [info     ] get next_dagrun_info_v2        [airflow.serialization.definitions.dag] last_automated_run_info=None loc=dag.py:445 next_info=None
# 2026-07-23T05:34:51.089472Z [info     ] setting next dagrun info       [airflow.models.dag] loc=dag.py:848 next_dagrun=None next_dagrun_create_after=None next_dagrun_data_interval_end=None next_dagrun_data_interval_start=None next_dagrun_partition_date=None next_dagrun_partition_key=None
# 2026-07-23T05:34:51.205004Z [info     ] DAG bundles loaded: dags-folder, example_dags, apache-airflow-providers-common-sql-example-dags, apache-airflow-providers-standard-example-dags [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:271
# 2026-07-23T05:34:51.211908Z [info     ] Filling up the DagBag from /root/airflow/dags [airflow.dag_processing.dagbag.BundleDagBag] loc=dagbag.py:460
# 2026-07-23T05:34:51.214018Z [info     ] OpenLineageClient will use `console` transport [openlineage.client.client] loc=client.py:136
# 2026-07-23T05:34:51.219769Z [info     ] Bulk-writing dags to db        [airflow.serialization.definitions.dag] count=1 loc=dag.py:210
# 2026-07-23T05:34:51.223118Z [info     ] get next_dagrun_info_v2        [airflow.serialization.definitions.dag] last_automated_run_info=None loc=dag.py:445 next_info=None
# 2026-07-23T05:34:51.223342Z [info     ] setting next dagrun info       [airflow.models.dag] loc=dag.py:848 next_dagrun=None next_dagrun_create_after=None next_dagrun_data_interval_end=None next_dagrun_data_interval_start=None next_dagrun_partition_date=None next_dagrun_partition_key=None
# 2026-07-23T05:34:51.275043Z [info     ] creating dag run               [airflow.serialization.definitions.dag] loc=dag.py:607 logical_date=DateTime(2026, 1, 1, 0, 0, 0, tzinfo=Timezone('UTC')) partition_key=None run_after=DateTime(2026, 7, 23, 5, 34, 51, 204309, tzinfo=Timezone('UTC')) run_id=manual__2026-07-23T05:34:51.204309+00:00
# 2026-07-23T05:34:51.526806Z [info     ] Created dag run.               [airflow.models.dagrun] dagrun=<DagRun sdaia_books_pipeline @ 2026-01-01 00:00:00+00:00: manual__2026-07-23T05:34:51.204309+00:00, state:running, queued_at: None. run_type: manual> loc=dagrun.py:2446
# 2026-07-23T05:34:51.556865Z [info     ] [DAG TEST] starting task_id=start map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:34:51.557337Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.start manual__2026-07-23T05:34:51.204309+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d78-2e4b-7c7b-b5f0-0544db180f21> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:34:58.658404Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-3503-7d52-a70a-e14a33732676 hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d78-2e4b-7c7b-b5f0-0544db180f21
# 2026-07-23T05:34:58.662375Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-3503-7d52-a70a-e14a33732676 loc=task_instances.py:259 rows_affected=1 ti_id=019f8d78-2e4b-7c7b-b5f0-0544db180f21
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:start
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:34:58.693549Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:34:58.693852Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:34:58.720732Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-4a87-7580-912a-453f16b29d0d loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d78-2e4b-7c7b-b5f0-0544db180f21
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): start>
# 2026-07-23T05:34:58.729479Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:34:58.746343Z [info     ] [DAG TEST] end task task_id=start map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:34:58.760001Z [info     ] [DAG TEST] starting task_id=data_ingestion map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:34:58.760719Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.data_ingestion manual__2026-07-23T05:34:51.204309+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d78-2e4c-713d-a248-f022737cdcc2> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:34:58.779010Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-4acf-7f74-bc55-51479aad8dc2 hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d78-2e4c-713d-a248-f022737cdcc2
# 2026-07-23T05:34:58.780455Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-4acf-7f74-bc55-51479aad8dc2 loc=task_instances.py:259 rows_affected=1 ti_id=019f8d78-2e4c-713d-a248-f022737cdcc2
# 2026-07-23T05:34:58.804942Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-4aec-74d6-bdcd-9608da5124d2 field_count=3 loc=task_instances.py:1005 ti_id=019f8d78-2e4c-713d-a248-f022737cdcc2
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:data_ingestion
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:34:58.827249Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:34:59.126203Z [info     ] NumExpr defaulting to 2 threads. [numexpr.utils] loc=utils.py:164
# 2026-07-23T05:34:59.514204Z [info     ] {"eventTime": "2026-07-23T05:34:59.513456+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "data_ingestion", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "86006138-0df0-44d0-9c94-f13bf4776ce4"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:34:59.520258Z [info     ] Attempting bootstrap to bootstrap-0 at localhost:9092 (rack None) [kafka.net.manager] loc=manager.py:119
# 2026-07-23T05:34:59.520485Z [info     ] Initializing connection for node_id bootstrap-0 at localhost:9092 (rack=None) [kafka.net.manager] loc=manager.py:282
# 2026-07-23T05:34:59.521996Z [info     ] <KafkaTCPTransport [::1:9092<-53112]>: connected to <socket.socket fd=16, family=10, type=1, proto=6, laddr=('::1', 53112, 0, 0), raddr=('::1', 9092, 0, 0)> [kafka.net.transport] loc=transport.py:354
# 2026-07-23T05:34:59.532433Z [info     ] <KafkaConnection node_id=bootstrap-0 host=[::1:9092<-53112] broker_version=unknown (initializing)>: Broker version identified as 3.7 [kafka.net.connection] loc=connection.py:415
# 2026-07-23T05:34:59.533445Z [info     ] <KafkaConnection node_id=bootstrap-0 host=[::1:9092<-53112] broker_version=(3, 7) (connected)>: Connected [kafka.net.connection] loc=connection.py:375
# 2026-07-23T05:34:59.543896Z [info     ] Updated metadata: ClusterMetadata(brokers: 1, topics: 0, coordinators: 0) [kafka.cluster] loc=cluster.py:638
# 2026-07-23T05:34:59.544228Z [info     ] Bootstrap complete: ClusterMetadata(brokers: 1, topics: 0, coordinators: 0) [kafka.net.manager] loc=manager.py:162
# 2026-07-23T05:34:59.544386Z [info     ] Closing bootstrap connection bootstrap-0 [kafka.net.manager] loc=manager.py:165
# 2026-07-23T05:34:59.544945Z [info     ] <KafkaTCPTransport [::1:9092<-53112]>: Closing transport [kafka.net.transport] loc=transport.py:49
# 2026-07-23T05:34:59.545316Z [info     ] <KafkaConnection node_id=bootstrap-0 broker_version=(3, 7) (disconnected)>: Connection closed [kafka.net.connection] loc=connection.py:242
# 2026-07-23T05:34:59.545664Z [info     ] Starting metadata refresh loop [kafka.cluster] loc=cluster.py:120
# 2026-07-23T05:34:59.546043Z [info     ] <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Instantiated an idempotent producer. [kafka.producer.kafka] loc=kafka.py:613
# 2026-07-23T05:34:59.547131Z [info     ] ProducerId set to -1 with epoch -1 [kafka.producer.transaction_manager] loc=transaction_manager.py:456
# 2026-07-23T05:34:59.547531Z [info     ] Initializing connection for node_id 1 at localhost:9092 (rack=None) [kafka.net.manager] loc=manager.py:282
# 2026-07-23T05:34:59.548504Z [info     ] <KafkaTCPTransport [::1:9092<-53116]>: connected to <socket.socket fd=16, family=10, type=1, proto=6, laddr=('::1', 53116, 0, 0), raddr=('::1', 9092, 0, 0)> [kafka.net.transport] loc=transport.py:354
# 2026-07-23T05:34:59.554055Z [info     ] <KafkaConnection node_id=1 host=[::1:9092<-53116] broker_version=(3, 7) (connected)>: Connected [kafka.net.connection] loc=connection.py:375
# 2026-07-23T05:34:59.557652Z [info     ] ProducerId set to 1 with epoch 0 [kafka.producer.transaction_manager] loc=transaction_manager.py:456
# 2026-07-23T05:34:59.648380Z [info     ] Updated metadata: ClusterMetadata(brokers: 1, topics: 1, coordinators: 0) [kafka.cluster] loc=cluster.py:638
# 2026-07-23T05:34:59.680864Z [info     ] <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Closing the Kafka producer with 9223372036.0 secs timeout. [kafka.producer.kafka] loc=kafka.py:694
# 2026-07-23T05:34:59.681489Z [info     ] <KafkaTCPTransport [::1:9092<-53116]>: Closing transport [kafka.net.transport] loc=transport.py:49
# 2026-07-23T05:34:59.681833Z [info     ] <KafkaConnection node_id=1 broker_version=(3, 7) (disconnected)>: Connection closed [kafka.net.connection] loc=connection.py:242
# 2026-07-23T05:34:59.682258Z [info     ] Stopping metadata refresh loop [kafka.cluster] loc=cluster.py:136
# Data ingestion completed: 95 records sent to Kafka topic 'books'.
# 2026-07-23T05:34:59.684048Z [info     ] {"eventTime": "2026-07-23T05:34:59.683435+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "data_ingestion", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "86006138-0df0-44d0-9c94-f13bf4776ce4"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:34:59.684423Z [info     ] Done. Returned value was: 95   [airflow.task.operators.airflow.providers.standard.operators.python.PythonOperator] loc=python.py:233
# 2026-07-23T05:34:59.684610Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:34:59.684834Z [info     ] Pushing xcom                   [task] loc=task_runner.py:2171 ti=RuntimeTaskInstance(id=UUID('019f8d78-2e4c-713d-a248-f022737cdcc2'), task_id='data_ingestion', dag_id='sdaia_books_pipeline', run_id='manual__2026-07-23T05:34:51.204309+00:00', try_number=1, dag_version_id=UUID('019f8d53-fa38-71f4-ab96-0c328f925ef8'), map_index=-1, hostname='1cb484c72f27', context_carrier=None, queue='default', task=<Task(PythonOperator): data_ingestion>, max_tries=0, start_date=datetime.datetime(2026, 7, 23, 5, 34, 58, 766575, tzinfo=datetime.timezone.utc), end_date=None, state=<TaskInstanceState.RUNNING: 'running'>, is_mapped=False, rendered_map_index=None, sentry_integration='')
# 2026-07-23T05:34:59.725714Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-4e7f-783d-a637-bf2ef5955cfe loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d78-2e4c-713d-a248-f022737cdcc2
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(PythonOperator): data_ingestion>
# 2026-07-23T05:34:59.734605Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:34:59.744976Z [info     ] [DAG TEST] end task task_id=data_ingestion map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:34:59.758764Z [info     ] [DAG TEST] starting task_id=delta_lakehouse map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:34:59.759759Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.delta_lakehouse manual__2026-07-23T05:34:51.204309+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d78-2e4d-7a56-863a-1a1f6436ca83> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:34:59.779787Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-4eb6-7372-a9f1-c6c0d31c70e5 hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d78-2e4d-7a56-863a-1a1f6436ca83
# 2026-07-23T05:34:59.781256Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-4eb6-7372-a9f1-c6c0d31c70e5 loc=task_instances.py:259 rows_affected=1 ti_id=019f8d78-2e4d-7a56-863a-1a1f6436ca83
# 2026-07-23T05:34:59.805706Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d78-4ed5-7cee-962b-26781a7c7a83 field_count=3 loc=task_instances.py:1005 ti_id=019f8d78-2e4d-7a56-863a-1a1f6436ca83
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:delta_lakehouse
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:34:59.818006Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:34:59.895540Z [info     ] {"eventTime": "2026-07-23T05:34:59.894936+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "delta_lakehouse", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "d671ab4e-616c-4da0-a49d-ecb0ee572e6e"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# :: loading settings :: url = jar:file:/usr/local/lib/python3.12/dist-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-2e18818c-def4-485d-b7e7-7f97d675b46d;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.2.0 in central
# 	found io.delta#delta-storage;3.2.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 650ms :: artifacts dl 26ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.2.0 from central in [default]
# 	io.delta#delta-storage;3.2.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-2e18818c-def4-485d-b7e7-7f97d675b46d
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/15ms)
# 26/07/23 05:35:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/23 05:35:07 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/07/23 05:35:25 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Delta Lakehouse completed: Bronze=95, Silver=95, Gold=14.
# 2026-07-23T05:36:20.836285Z [info     ] {"eventTime": "2026-07-23T05:36:20.834771+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "delta_lakehouse", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "d671ab4e-616c-4da0-a49d-ecb0ee572e6e"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:36:20.836967Z [info     ] Done. Returned value was: {'bronze': 95, 'silver': 95, 'gold': 14} [airflow.task.operators.airflow.providers.standard.operators.python.PythonOperator] loc=python.py:233
# 2026-07-23T05:36:20.837310Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:36:20.837688Z [info     ] Pushing xcom                   [task] loc=task_runner.py:2171 ti=RuntimeTaskInstance(id=UUID('019f8d78-2e4d-7a56-863a-1a1f6436ca83'), task_id='delta_lakehouse', dag_id='sdaia_books_pipeline', run_id='manual__2026-07-23T05:34:51.204309+00:00', try_number=1, dag_version_id=UUID('019f8d53-fa38-71f4-ab96-0c328f925ef8'), map_index=-1, hostname='1cb484c72f27', context_carrier=None, queue='default', task=<Task(PythonOperator): delta_lakehouse>, max_tries=0, start_date=datetime.datetime(2026, 7, 23, 5, 34, 59, 765662, tzinfo=datetime.timezone.utc), end_date=None, state=<TaskInstanceState.RUNNING: 'running'>, is_mapped=False, rendered_map_index=None, sentry_integration='')
# 2026-07-23T05:36:20.890092Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d79-8b84-712b-8068-1cf72914d67c loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d78-2e4d-7a56-863a-1a1f6436ca83
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(PythonOperator): delta_lakehouse>
# 2026-07-23T05:36:20.900353Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:36:20.911353Z [info     ] [DAG TEST] end task task_id=delta_lakehouse map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:36:20.928409Z [info     ] [DAG TEST] starting task_id=quality_gate map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:36:20.928659Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.quality_gate manual__2026-07-23T05:34:51.204309+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d78-2e4e-7e35-b6a8-f52e54ae798a> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:36:20.949077Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d79-8bc7-7719-a624-a9dbeb0f4c0c hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d78-2e4e-7e35-b6a8-f52e54ae798a
# 2026-07-23T05:36:20.950627Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d79-8bc7-7719-a624-a9dbeb0f4c0c loc=task_instances.py:259 rows_affected=1 ti_id=019f8d78-2e4e-7e35-b6a8-f52e54ae798a
# 2026-07-23T05:36:20.977135Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d79-8be8-736b-8dc1-3844ed51b1c3 field_count=3 loc=task_instances.py:1005 ti_id=019f8d78-2e4e-7e35-b6a8-f52e54ae798a
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:quality_gate
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:36:20.989632Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:36:20.990645Z [info     ] {"eventTime": "2026-07-23T05:36:20.990097+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "044afacd-fe0c-4026-94c0-48d2750cff40"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# Quality Gate passed: 5 of 5 checks passed.
# 2026-07-23T05:36:20.991486Z [info     ] {"eventTime": "2026-07-23T05:36:20.991014+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "044afacd-fe0c-4026-94c0-48d2750cff40"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:36:20.991689Z [info     ] Done. Returned value was: {'all_passed': True, 'checks_passed': 5, 'total_checks': 5} [airflow.task.operators.airflow.providers.standard.operators.python.PythonOperator] loc=python.py:233
# 2026-07-23T05:36:20.991809Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:36:20.991952Z [info     ] Pushing xcom                   [task] loc=task_runner.py:2171 ti=RuntimeTaskInstance(id=UUID('019f8d78-2e4e-7e35-b6a8-f52e54ae798a'), task_id='quality_gate', dag_id='sdaia_books_pipeline', run_id='manual__2026-07-23T05:34:51.204309+00:00', try_number=1, dag_version_id=UUID('019f8d53-fa38-71f4-ab96-0c328f925ef8'), map_index=-1, hostname='1cb484c72f27', context_carrier=None, queue='default', task=<Task(PythonOperator): quality_gate>, max_tries=0, start_date=datetime.datetime(2026, 7, 23, 5, 36, 20, 935362, tzinfo=datetime.timezone.utc), end_date=None, state=<TaskInstanceState.RUNNING: 'running'>, is_mapped=False, rendered_map_index=None, sentry_integration='')
# 2026-07-23T05:36:21.023891Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d79-8c12-77cc-8f34-5ee4e98a4d9a loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d78-2e4e-7e35-b6a8-f52e54ae798a
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(PythonOperator): quality_gate>
# 2026-07-23T05:36:21.032475Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:36:21.041755Z [info     ] [DAG TEST] end task task_id=quality_gate map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:36:21.056237Z [info     ] [DAG TEST] starting task_id=rag_pipeline map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:36:21.056478Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.rag_pipeline manual__2026-07-23T05:34:51.204309+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d78-2e4f-7d08-b5f9-6cbf76da4422> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:36:21.079584Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d79-8c48-784c-b939-bc270576f843 hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d78-2e4f-7d08-b5f9-6cbf76da4422
# 2026-07-23T05:36:21.084286Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d79-8c48-784c-b939-bc270576f843 loc=task_instances.py:259 rows_affected=1 ti_id=019f8d78-2e4f-7d08-b5f9-6cbf76da4422
# 2026-07-23T05:36:21.115882Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d79-8c71-728d-86b4-9cf6a4d54d8a field_count=3 loc=task_instances.py:1005 ti_id=019f8d78-2e4f-7d08-b5f9-6cbf76da4422
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:rag_pipeline
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:36:21.128516Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:36:30.983886Z [info     ] TensorFlow version 2.20.0 available. [datasets] loc=config.py:112
# 2026-07-23T05:36:30.985379Z [info     ] JAX version 0.7.2 available.   [datasets] loc=config.py:125
# 2026-07-23T05:36:37.799081Z [info     ] {"eventTime": "2026-07-23T05:36:37.798441+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "52937891-eada-4f19-8b61-82220fd25e02"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 26/07/23 05:36:37 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 2026-07-23T05:36:38.881734Z [info     ] Updated metadata: ClusterMetadata(brokers: 1, topics: 1, coordinators: 0) [kafka.cluster] loc=cluster.py:638
# 2026-07-23T05:36:47.867851Z [info     ] No device provided, using cpu  [sentence_transformers.base.model] loc=model.py:190
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-23T05:36:48.143667Z [warning  ] Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads. [huggingface_hub.utils._http] loc=_http.py:951
# 2026-07-23T05:36:48.161562Z [info     ] Loading SentenceTransformer model from sentence-transformers/all-MiniLM-L6-v2. [sentence_transformers.base.model] loc=model.py:1001
# Loading weights: 100% 103/103 [00:00<00:00, 7412.59it/s]
# Batches: 100% 1/1 [00:00<00:00,  8.42it/s]
# Batches: 100% 1/1 [00:00<00:00, 52.89it/s]
# 2026-07-23T05:36:49.853361Z [info     ] No device provided, using cpu  [sentence_transformers.base.model] loc=model.py:190
# 2026-07-23T05:36:49.953459Z [info     ] No modules.json found for cross-encoder/ms-marco-MiniLM-L-6-v2, initializing a new CrossEncoder model. [sentence_transformers.base.model] loc=model.py:990
# Loading weights: 100% 105/105 [00:00<00:00, 4613.95it/s]
# Batches: 100% 1/1 [00:00<00:00,  9.92it/s]
# RAG pipeline completed with 14 indexed chunks.
# Result saved to /content/rag_airflow_result.json
# 2026-07-23T05:36:52.216860Z [info     ] {"eventTime": "2026-07-23T05:36:52.216155+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "52937891-eada-4f19-8b61-82220fd25e02"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:36:52.217333Z [info     ] Done. Returned value was: /content/rag_airflow_result.json [airflow.task.operators.airflow.providers.standard.operators.python.PythonOperator] loc=python.py:233
# 2026-07-23T05:36:52.217557Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:36:52.217815Z [info     ] Pushing xcom                   [task] loc=task_runner.py:2171 ti=RuntimeTaskInstance(id=UUID('019f8d78-2e4f-7d08-b5f9-6cbf76da4422'), task_id='rag_pipeline', dag_id='sdaia_books_pipeline', run_id='manual__2026-07-23T05:34:51.204309+00:00', try_number=1, dag_version_id=UUID('019f8d53-fa38-71f4-ab96-0c328f925ef8'), map_index=-1, hostname='1cb484c72f27', context_carrier=None, queue='default', task=<Task(PythonOperator): rag_pipeline>, max_tries=0, start_date=datetime.datetime(2026, 7, 23, 5, 36, 21, 64135, tzinfo=datetime.timezone.utc), end_date=None, state=<TaskInstanceState.RUNNING: 'running'>, is_mapped=False, rendered_map_index=None, sentry_integration='')
# 2026-07-23T05:36:52.259869Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-0611-73c8-ac46-b806b08a9049 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d78-2e4f-7d08-b5f9-6cbf76da4422
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(PythonOperator): rag_pipeline>
# 2026-07-23T05:36:52.270017Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:36:52.281496Z [info     ] [DAG TEST] end task task_id=rag_pipeline map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:36:52.294355Z [info     ] [DAG TEST] starting task_id=end map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:36:52.295248Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.end manual__2026-07-23T05:34:51.204309+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d78-2e50-749b-ab33-bfc2399da157> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:36:52.315463Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-064e-7a4a-bfa3-b7830d9a0890 hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d78-2e50-749b-ab33-bfc2399da157
# 2026-07-23T05:36:52.316940Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-064e-7a4a-bfa3-b7830d9a0890 loc=task_instances.py:259 rows_affected=1 ti_id=019f8d78-2e50-749b-ab33-bfc2399da157
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:end
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:36:52.330781Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:36:52.331272Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:36:52.346399Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-066c-70e6-9375-5cc03341049d loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d78-2e50-749b-ab33-bfc2399da157
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): end>
# 2026-07-23T05:36:52.356257Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:36:52.365888Z [info     ] [DAG TEST] end task task_id=end map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:36:52.369245Z [info     ] Marking run <DagRun sdaia_books_pipeline @ 2026-01-01 00:00:00+00:00: manual__2026-07-23T05:34:51.204309+00:00, state:running, queued_at: None. run_type: manual> successful [airflow.models.dagrun.DagRun] loc=dagrun.py:1249
# Dag run in success state
# Dag run start:2026-01-01 00:00:00+00:00 end:2026-07-23 05:36:52.369427+00:00
# 2026-07-23T05:36:52.370875Z [info     ] DagRun Finished: dag_id=sdaia_books_pipeline, logical_date=2026-01-01 00:00:00+00:00, run_id=manual__2026-07-23T05:34:51.204309+00:00, run_start_date=2026-01-01 00:00:00+00:00, run_end_date=2026-07-23 05:36:52.369427+00:00, run_duration=17559412.369427, state=success, run_type=manual, data_interval_start=2026-01-01 00:00:00+00:00, data_interval_end=2026-01-01 00:00:00+00:00, [airflow.models.dagrun.DagRun] loc=dagrun.py:1315
# 2026-07-23T05:36:52.404152Z [info     ] Closing down clientserver connection [py4j.clientserver] loc=clientserver.py:543

# %%
import json

# Force the Quality Gate result file to reflect a FAILED outcome
with open('/content/quality_gate_result.json', 'w') as f:
    json.dump({
        "all_passed": False,
        "checks_passed": len(all_checks) - 1,
        "total_checks": len(all_checks)
    }, f)

print("=== RUN 2: Corrupted data ===")
# !airflow dags test sdaia_books_pipeline 2026-01-02

# Restore the real (valid) result file afterwards
with open('/content/quality_gate_result.json', 'w') as f:
    json.dump({
        "all_passed": bool(all_passed),
        "checks_passed": len(all_checks),
        "total_checks": len(all_checks)
    }, f)
# Out:
# === RUN 2: Corrupted data ===
# 2026-07-23T05:37:01.911621Z [info     ] setup plugin alembic.autogenerate.schemas [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:37:01.911926Z [info     ] setup plugin alembic.autogenerate.tables [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:37:01.912098Z [info     ] setup plugin alembic.autogenerate.types [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:37:01.912276Z [info     ] setup plugin alembic.autogenerate.constraints [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:37:01.912414Z [info     ] setup plugin alembic.autogenerate.defaults [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:37:01.912549Z [info     ] setup plugin alembic.autogenerate.comments [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T05:37:01.987092Z [info     ] DAG bundles loaded: dags-folder, example_dags, apache-airflow-providers-common-sql-example-dags, apache-airflow-providers-standard-example-dags [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:271
# 2026-07-23T05:37:01.996534Z [info     ] Filling up the DagBag from /root/airflow/dags [airflow.dag_processing.dagbag.BundleDagBag] loc=dagbag.py:460
# 2026-07-23T05:37:02.304438Z [info     ] OpenLineageClient will use `console` transport [openlineage.client.client] loc=client.py:136
# 2026-07-23T05:37:02.333117Z [info     ] Bulk-writing dags to db        [airflow.serialization.definitions.dag] count=1 loc=dag.py:210
# 2026-07-23T05:37:02.367320Z [info     ] get next_dagrun_info_v2        [airflow.serialization.definitions.dag] last_automated_run_info=None loc=dag.py:445 next_info=None
# 2026-07-23T05:37:02.367738Z [info     ] setting next dagrun info       [airflow.models.dag] loc=dag.py:848 next_dagrun=None next_dagrun_create_after=None next_dagrun_data_interval_end=None next_dagrun_data_interval_start=None next_dagrun_partition_date=None next_dagrun_partition_key=None
# 2026-07-23T05:37:02.489883Z [info     ] DAG bundles loaded: dags-folder, example_dags, apache-airflow-providers-common-sql-example-dags, apache-airflow-providers-standard-example-dags [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:271
# 2026-07-23T05:37:02.497935Z [info     ] Filling up the DagBag from /root/airflow/dags [airflow.dag_processing.dagbag.BundleDagBag] loc=dagbag.py:460
# 2026-07-23T05:37:02.500089Z [info     ] OpenLineageClient will use `console` transport [openlineage.client.client] loc=client.py:136
# 2026-07-23T05:37:02.505961Z [info     ] Bulk-writing dags to db        [airflow.serialization.definitions.dag] count=1 loc=dag.py:210
# 2026-07-23T05:37:02.509320Z [info     ] get next_dagrun_info_v2        [airflow.serialization.definitions.dag] last_automated_run_info=None loc=dag.py:445 next_info=None
# 2026-07-23T05:37:02.509524Z [info     ] setting next dagrun info       [airflow.models.dag] loc=dag.py:848 next_dagrun=None next_dagrun_create_after=None next_dagrun_data_interval_end=None next_dagrun_data_interval_start=None next_dagrun_partition_date=None next_dagrun_partition_key=None
# 2026-07-23T05:37:02.563355Z [info     ] creating dag run               [airflow.serialization.definitions.dag] loc=dag.py:607 logical_date=DateTime(2026, 1, 2, 0, 0, 0, tzinfo=Timezone('UTC')) partition_key=None run_after=DateTime(2026, 7, 23, 5, 37, 2, 488980, tzinfo=Timezone('UTC')) run_id=manual__2026-07-23T05:37:02.488980+00:00
# 2026-07-23T05:37:02.816682Z [info     ] Created dag run.               [airflow.models.dagrun] dagrun=<DagRun sdaia_books_pipeline @ 2026-01-02 00:00:00+00:00: manual__2026-07-23T05:37:02.488980+00:00, state:running, queued_at: None. run_type: manual> loc=dagrun.py:2446
# 2026-07-23T05:37:02.851478Z [info     ] [DAG TEST] starting task_id=start map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:37:02.851962Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.start manual__2026-07-23T05:37:02.488980+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d7a-2f25-725f-aba3-9322a19ef087> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:37:10.573678Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-35bf-7fa1-9dbb-c7732c1c9d37 hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d7a-2f25-725f-aba3-9322a19ef087
# 2026-07-23T05:37:10.578081Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-35bf-7fa1-9dbb-c7732c1c9d37 loc=task_instances.py:259 rows_affected=1 ti_id=019f8d7a-2f25-725f-aba3-9322a19ef087
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:start
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:37:10.617067Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:37:10.617364Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:37:10.654457Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-4dda-776d-a8c8-9844fb15309c loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d7a-2f25-725f-aba3-9322a19ef087
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): start>
# 2026-07-23T05:37:10.666119Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:37:10.691771Z [info     ] [DAG TEST] end task task_id=start map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:37:10.715512Z [info     ] [DAG TEST] starting task_id=data_ingestion map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:37:10.716548Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.data_ingestion manual__2026-07-23T05:37:02.488980+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d7a-2f26-7444-a38d-b041fdd79ad6> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:37:10.741481Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-4e44-7575-896b-c586ee18a159 hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d7a-2f26-7444-a38d-b041fdd79ad6
# 2026-07-23T05:37:10.743700Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-4e44-7575-896b-c586ee18a159 loc=task_instances.py:259 rows_affected=1 ti_id=019f8d7a-2f26-7444-a38d-b041fdd79ad6
# 2026-07-23T05:37:10.784886Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-4e6e-7d49-87bf-0b29e4ccd6cc field_count=3 loc=task_instances.py:1005 ti_id=019f8d7a-2f26-7444-a38d-b041fdd79ad6
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:data_ingestion
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:37:10.831382Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:37:11.201728Z [info     ] NumExpr defaulting to 2 threads. [numexpr.utils] loc=utils.py:164
# 2026-07-23T05:37:11.524371Z [info     ] {"eventTime": "2026-07-23T05:37:11.523628+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "data_ingestion", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "20a981e1-cd0a-4225-9a0f-ffc43661bd9d"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:37:11.530183Z [info     ] Attempting bootstrap to bootstrap-0 at localhost:9092 (rack None) [kafka.net.manager] loc=manager.py:119
# 2026-07-23T05:37:11.530417Z [info     ] Initializing connection for node_id bootstrap-0 at localhost:9092 (rack=None) [kafka.net.manager] loc=manager.py:282
# 2026-07-23T05:37:11.531801Z [info     ] <KafkaTCPTransport [::1:9092<-33580]>: connected to <socket.socket fd=16, family=10, type=1, proto=6, laddr=('::1', 33580, 0, 0), raddr=('::1', 9092, 0, 0)> [kafka.net.transport] loc=transport.py:354
# 2026-07-23T05:37:11.539951Z [info     ] <KafkaConnection node_id=bootstrap-0 host=[::1:9092<-33580] broker_version=unknown (initializing)>: Broker version identified as 3.7 [kafka.net.connection] loc=connection.py:415
# 2026-07-23T05:37:11.540647Z [info     ] <KafkaConnection node_id=bootstrap-0 host=[::1:9092<-33580] broker_version=(3, 7) (connected)>: Connected [kafka.net.connection] loc=connection.py:375
# 2026-07-23T05:37:11.548059Z [info     ] Updated metadata: ClusterMetadata(brokers: 1, topics: 0, coordinators: 0) [kafka.cluster] loc=cluster.py:638
# 2026-07-23T05:37:11.548390Z [info     ] Bootstrap complete: ClusterMetadata(brokers: 1, topics: 0, coordinators: 0) [kafka.net.manager] loc=manager.py:162
# 2026-07-23T05:37:11.548545Z [info     ] Closing bootstrap connection bootstrap-0 [kafka.net.manager] loc=manager.py:165
# 2026-07-23T05:37:11.549050Z [info     ] <KafkaTCPTransport [::1:9092<-33580]>: Closing transport [kafka.net.transport] loc=transport.py:49
# 2026-07-23T05:37:11.549407Z [info     ] <KafkaConnection node_id=bootstrap-0 broker_version=(3, 7) (disconnected)>: Connection closed [kafka.net.connection] loc=connection.py:242
# 2026-07-23T05:37:11.549833Z [info     ] Starting metadata refresh loop [kafka.cluster] loc=cluster.py:120
# 2026-07-23T05:37:11.550261Z [info     ] <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Instantiated an idempotent producer. [kafka.producer.kafka] loc=kafka.py:613
# 2026-07-23T05:37:11.551088Z [info     ] ProducerId set to -1 with epoch -1 [kafka.producer.transaction_manager] loc=transaction_manager.py:456
# 2026-07-23T05:37:11.551573Z [info     ] Initializing connection for node_id 1 at localhost:9092 (rack=None) [kafka.net.manager] loc=manager.py:282
# 2026-07-23T05:37:11.555869Z [info     ] <KafkaTCPTransport [::1:9092<-33586]>: connected to <socket.socket fd=16, family=10, type=1, proto=6, laddr=('::1', 33586, 0, 0), raddr=('::1', 9092, 0, 0)> [kafka.net.transport] loc=transport.py:354
# 2026-07-23T05:37:11.560339Z [info     ] <KafkaConnection node_id=1 host=[::1:9092<-33586] broker_version=(3, 7) (connected)>: Connected [kafka.net.connection] loc=connection.py:375
# 2026-07-23T05:37:11.564656Z [info     ] ProducerId set to 2 with epoch 0 [kafka.producer.transaction_manager] loc=transaction_manager.py:456
# 2026-07-23T05:37:11.651906Z [info     ] Updated metadata: ClusterMetadata(brokers: 1, topics: 1, coordinators: 0) [kafka.cluster] loc=cluster.py:638
# 2026-07-23T05:37:11.680415Z [info     ] <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Closing the Kafka producer with 9223372036.0 secs timeout. [kafka.producer.kafka] loc=kafka.py:694
# 2026-07-23T05:37:11.680858Z [info     ] <KafkaTCPTransport [::1:9092<-33586]>: Closing transport [kafka.net.transport] loc=transport.py:49
# 2026-07-23T05:37:11.681282Z [info     ] <KafkaConnection node_id=1 broker_version=(3, 7) (disconnected)>: Connection closed [kafka.net.connection] loc=connection.py:242
# 2026-07-23T05:37:11.681748Z [info     ] Stopping metadata refresh loop [kafka.cluster] loc=cluster.py:136
# Data ingestion completed: 95 records sent to Kafka topic 'books'.
# 2026-07-23T05:37:11.682811Z [info     ] {"eventTime": "2026-07-23T05:37:11.682157+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "data_ingestion", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "20a981e1-cd0a-4225-9a0f-ffc43661bd9d"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:37:11.683149Z [info     ] Done. Returned value was: 95   [airflow.task.operators.airflow.providers.standard.operators.python.PythonOperator] loc=python.py:233
# 2026-07-23T05:37:11.683333Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:37:11.683543Z [info     ] Pushing xcom                   [task] loc=task_runner.py:2171 ti=RuntimeTaskInstance(id=UUID('019f8d7a-2f26-7444-a38d-b041fdd79ad6'), task_id='data_ingestion', dag_id='sdaia_books_pipeline', run_id='manual__2026-07-23T05:37:02.488980+00:00', try_number=1, dag_version_id=UUID('019f8d53-fa38-71f4-ab96-0c328f925ef8'), map_index=-1, hostname='1cb484c72f27', context_carrier=None, queue='default', task=<Task(PythonOperator): data_ingestion>, max_tries=0, start_date=datetime.datetime(2026, 7, 23, 5, 37, 10, 723977, tzinfo=datetime.timezone.utc), end_date=None, state=<TaskInstanceState.RUNNING: 'running'>, is_mapped=False, rendered_map_index=None, sentry_integration='')
# 2026-07-23T05:37:11.723945Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-521d-7d2c-a9c2-ca968b8686c5 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d7a-2f26-7444-a38d-b041fdd79ad6
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(PythonOperator): data_ingestion>
# 2026-07-23T05:37:11.732350Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:37:11.743089Z [info     ] [DAG TEST] end task task_id=data_ingestion map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:37:11.758719Z [info     ] [DAG TEST] starting task_id=delta_lakehouse map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:37:11.759731Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.delta_lakehouse manual__2026-07-23T05:37:02.488980+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d7a-2f27-7143-bc09-faf691838fda> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:37:11.781583Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-5256-72d6-b630-66fda2743a7a hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d7a-2f27-7143-bc09-faf691838fda
# 2026-07-23T05:37:11.783272Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-5256-72d6-b630-66fda2743a7a loc=task_instances.py:259 rows_affected=1 ti_id=019f8d7a-2f27-7143-bc09-faf691838fda
# 2026-07-23T05:37:11.807200Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7a-5277-7b8b-a8d4-d356a4da16b4 field_count=3 loc=task_instances.py:1005 ti_id=019f8d7a-2f27-7143-bc09-faf691838fda
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:delta_lakehouse
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:37:11.823145Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:37:11.901989Z [info     ] {"eventTime": "2026-07-23T05:37:11.901445+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "delta_lakehouse", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "07ad57b5-9080-4d0b-96f8-58211ef8f69d"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# :: loading settings :: url = jar:file:/usr/local/lib/python3.12/dist-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3c7e9166-9393-4a4d-a179-2e71c8b011a4;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.2.0 in central
# 	found io.delta#delta-storage;3.2.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 299ms :: artifacts dl 28ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.2.0 from central in [default]
# 	io.delta#delta-storage;3.2.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-3c7e9166-9393-4a4d-a179-2e71c8b011a4
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/25ms)
# 26/07/23 05:37:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/23 05:37:17 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/07/23 05:37:35 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Delta Lakehouse completed: Bronze=95, Silver=95, Gold=14.
# 2026-07-23T05:38:38.957111Z [info     ] {"eventTime": "2026-07-23T05:38:38.955715+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "delta_lakehouse", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "07ad57b5-9080-4d0b-96f8-58211ef8f69d"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:38:38.957924Z [info     ] Done. Returned value was: {'bronze': 95, 'silver': 95, 'gold': 14} [airflow.task.operators.airflow.providers.standard.operators.python.PythonOperator] loc=python.py:233
# 2026-07-23T05:38:38.958489Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T05:38:38.958954Z [info     ] Pushing xcom                   [task] loc=task_runner.py:2171 ti=RuntimeTaskInstance(id=UUID('019f8d7a-2f27-7143-bc09-faf691838fda'), task_id='delta_lakehouse', dag_id='sdaia_books_pipeline', run_id='manual__2026-07-23T05:37:02.488980+00:00', try_number=1, dag_version_id=UUID('019f8d53-fa38-71f4-ab96-0c328f925ef8'), map_index=-1, hostname='1cb484c72f27', context_carrier=None, queue='default', task=<Task(PythonOperator): delta_lakehouse>, max_tries=0, start_date=datetime.datetime(2026, 7, 23, 5, 37, 11, 765917, tzinfo=datetime.timezone.utc), end_date=None, state=<TaskInstanceState.RUNNING: 'running'>, is_mapped=False, rendered_map_index=None, sentry_integration='')
# 2026-07-23T05:38:39.014120Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7b-a70f-7bb5-bb7d-5b10d6b164e8 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8d7a-2f27-7143-bc09-faf691838fda
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(PythonOperator): delta_lakehouse>
# 2026-07-23T05:38:39.025578Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:38:39.039094Z [info     ] [DAG TEST] end task task_id=delta_lakehouse map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:38:39.065151Z [info     ] [DAG TEST] starting task_id=quality_gate map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T05:38:39.065497Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.quality_gate manual__2026-07-23T05:37:02.488980+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8d7a-2f28-7076-9d45-1030d51a669a> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T05:38:39.093418Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7b-a761-7770-844b-96b20af24b71 hostname=1cb484c72f27 loc=task_instances.py:231 previous_state=queued ti_id=019f8d7a-2f28-7076-9d45-1030d51a669a
# 2026-07-23T05:38:39.094968Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7b-a761-7770-844b-96b20af24b71 loc=task_instances.py:259 rows_affected=1 ti_id=019f8d7a-2f28-7076-9d45-1030d51a669a
# 2026-07-23T05:38:39.121115Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7b-a789-7db5-9c59-a564ce85c96b field_count=3 loc=task_instances.py:1005 ti_id=019f8d7a-2f28-7076-9d45-1030d51a669a
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:quality_gate
# Dag name:sdaia_books_pipeline
# 2026-07-23T05:38:39.134218Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T05:38:39.135213Z [info     ] {"eventTime": "2026-07-23T05:38:39.134673+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "591e7768-b648-4480-8d60-beee37017750"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:38:39.136300Z [info     ] {"eventTime": "2026-07-23T05:38:39.135828+00:00", "eventType": "FAIL", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "591e7768-b648-4480-8d60-beee37017750"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T05:38:39.136513Z [error    ] Task failed with exception     [task] loc=task_runner.py:1673
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/execution_time/task_runner.py", line 1576, in run
#     result = _execute_task(context=context, ti=ti, log=log)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/execution_time/task_runner.py", line 189, in wrapper
#     return f(*inner_args, **inner_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/execution_time/task_runner.py", line 2125, in _execute_task
#     result = ctx.run(execute, context=context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/bases/operator.py", line 445, in wrapper
#     return func(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/providers/standard/operators/python.py", line 231, in execute
#     return_value = self.execute_callable()
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/providers/standard/operators/python.py", line 254, in execute_callable
#     return runner.run(*self.op_args, **self.op_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/execution_time/callback_runner.py", line 97, in run
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/airflow/dags/sdaia_books_dag.py", line 263, in quality_gate_task
#     raise ValueError(
# ValueError: Quality Gate failed: 4 of 5 checks passed.
# 2026-07-23T05:38:39.137714Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1674
# Task instance in failure state
# Task start
# Task:<Task(PythonOperator): quality_gate>
# Failure caused by Quality Gate failed: 4 of 5 checks passed.
# 2026-07-23T05:38:39.141544Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T05:38:39.156205Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8d7b-a7a6-7360-ba73-4111ab5adaae loc=task_instances.py:484 new_state=failed rows_affected=1 ti_id=019f8d7a-2f28-7076-9d45-1030d51a669a
# 2026-07-23T05:38:39.175457Z [info     ] [DAG TEST] end task task_id=quality_gate map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T05:38:39.191328Z [warning  ] No tasks to run. unrunnable tasks: {<TaskInstance: sdaia_books_pipeline.end manual__2026-07-23T05:37:02.488980+00:00 [None] ti_id=019f8d7a-2f2a-7a36-8a6f-1e176e5b9f5a>} [airflow.sdk.definitions.dag] loc=dag.py:1424
# 2026-07-23T05:38:40.209571Z [info     ] Marking run <DagRun sdaia_books_pipeline @ 2026-01-02 00:00:00+00:00: manual__2026-07-23T05:37:02.488980+00:00, state:running, queued_at: None. run_type: manual> failed [airflow.models.dagrun.DagRun] loc=dagrun.py:1219
# Dag run  in failure state
# Dag information:sdaia_books_pipeline Run id: manual__2026-07-23T05:37:02.488980+00:00 Run type: manual
# Failed with message: task_failure
# 2026-07-23T05:38:40.210973Z [info     ] DagRun Finished: dag_id=sdaia_books_pipeline, logical_date=2026-01-02 00:00:00+00:00, run_id=manual__2026-07-23T05:37:02.488980+00:00, run_start_date=2026-01-02 00:00:00+00:00, run_end_date=2026-07-23 05:38:40.209778+00:00, run_duration=17473120.209778, state=failed, run_type=manual, data_interval_start=2026-01-02 00:00:00+00:00, data_interval_end=2026-01-02 00:00:00+00:00, [airflow.models.dagrun.DagRun] loc=dagrun.py:1315
# DagRun failed
# 2026-07-23T05:38:40.231435Z [info     ] Closing down clientserver connection [py4j.clientserver] loc=clientserver.py:543
