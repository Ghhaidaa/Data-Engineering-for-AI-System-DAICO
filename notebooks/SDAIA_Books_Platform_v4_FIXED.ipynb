# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghhaidaa/Data-Engineering-for-AI-System-DAICO/blob/main/notebooks/SDAIA_Books_Platform_v4_FIXED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SDAIA** **Books** **Platform**
#
# A data engineering platform for validating, streaming, and storing book registration data submitted by publishers across Saudi Arabia.

# %% [markdown]
# # Data Ingestion and Delta Lake
#
# This notebook presents the implementation of the **Data Ingestion** and **Delta Lakehouse** components for the SDAIA Books Platform.
#
# The implementation includes:
#
# - Data validation using **Pydantic**.
# - Real-time data streaming with **Apache Kafka** (Producer & Consumer).
# - Delta Lake **Bronze**, **Silver**, and **Gold** layers.
# - **MERGE (Upsert)** using `book_id` as the business key.
# - **Schema Enforcement** demonstration to validate schema consistency.
#
# This notebook corresponds to **Parts 1 & 2** of the project deliverables.

# %%
# !apt-get update -qq
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt-get install -y openjdk-17-jdk-headless
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openjdk-17-jdk-headless is already the newest version (17.0.19+10-1~22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 118 not upgraded.

# %%
# !pip install kafka-python pydantic faker
# Out:
# Collecting kafka-python
#   Downloading kafka_python-3.0.9-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (2.13.4)
# Collecting faker
#   Downloading faker-40.35.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.4.2)
# Downloading kafka_python-3.0.9-py3-none-any.whl (614 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.1/614.1 kB 3.2 MB/s eta 0:00:00
# Downloading faker-40.35.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 17.8 MB/s eta 0:00:00
# Installing collected packages: kafka-python, faker
# Successfully installed faker-40.35.0 kafka-python-3.0.9

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

# Make results reproducible
Faker.seed(42)
random.seed(42)

# %%
publisher_names = [
    "Jarir Publishing",
    "Obeikan Publishing",
    "King Fahad National Library",
    "Dar Al-Minhaj",
    "Saudi Research Publishing"
]

publisher_cities = [
    "Riyadh",
    "Jeddah",
    "Dammam",
    "Madinah",
    "Abha"
]

categories = [
    "Artificial Intelligence",
    "Data Science",
    "Cybersecurity",
    "Education",
    "Government",
    "Culture",
    "History"
]

languages = ["Arabic", "English"]

records = []

for book_id in range(1, 101):

    isbn = f"978603{random.randint(1000000,9999999)}"

    records.append({
        "book_id": book_id,
        "isbn": isbn,
        "title": fake.sentence(nb_words=4).replace(".", ""),
        "author": fake.name(),
        "publisher_name": random.choice(publisher_names),
        "publisher_city": random.choice(publisher_cities),
        "category": random.choice(categories),
        "language": random.choice(languages),
        "publication_year": random.randint(2015, 2026),
        "submission_date": fake.date_this_year().strftime("%Y-%m-%d")
    })

df = pd.DataFrame(records)

df.head()
# Out:
#    book_id           isbn                                    title  \
# 0        1  9786032867825                              Agent every
# 1        2  9786032719583                          Opportunity all
# 2        3  9786031499914  Information last everything thank serve
# 3        4  9786034335942                       Bill here grow gas
# 4        5  9786035667265                      Bad fall pick those
#
#            author             publisher_name publisher_city      category  \
# 0     Noah Rhodes           Jarir Publishing         Dammam  Data Science
# 1    David Guzman  Saudi Research Publishing         Riyadh    Government
# 2     Jay Ramirez           Jarir Publishing         Jeddah  Data Science
# 3  Andrew Stevens  Saudi Research Publishing        Madinah  Data Science
# 4     Corey Jones           Jarir Publishing         Jeddah       Culture
#
#   language  publication_year submission_date
# 0   Arabic              2017      2026-07-01
# 1  English              2015      2026-04-24
# 2   Arabic              2023      2026-02-13
# 3  English              2024      2026-01-26
# 4  English              2020      2026-05-15

# %%
# Missing ISBN
df.loc[0, "isbn"] = None

# Empty title
df.loc[1, "title"] = ""

# Unsupported language
df.loc[2, "language"] = "French"

# Future publication year
df.loc[3, "publication_year"] = 2050

# Invalid date format
df.loc[4, "submission_date"] = "2026/15/40"

df.head()
# Out:
#    book_id           isbn                                    title  \
# 0        1           None                              Agent every
# 1        2  9786032719583
# 2        3  9786031499914  Information last everything thank serve
# 3        4  9786034335942                       Bill here grow gas
# 4        5  9786035667265                      Bad fall pick those
#
#            author             publisher_name publisher_city      category  \
# 0     Noah Rhodes           Jarir Publishing         Dammam  Data Science
# 1    David Guzman  Saudi Research Publishing         Riyadh    Government
# 2     Jay Ramirez           Jarir Publishing         Jeddah  Data Science
# 3  Andrew Stevens  Saudi Research Publishing        Madinah  Data Science
# 4     Corey Jones           Jarir Publishing         Jeddah       Culture
#
#   language  publication_year submission_date
# 0   Arabic              2017      2026-07-01
# 1  English              2015      2026-04-24
# 2   French              2023      2026-02-13
# 3  English              2050      2026-01-26
# 4  English              2020      2026/15/40

# %%
df.to_csv("books_data.csv", index=False)

print("Dataset created successfully!")
print(f"Total records: {len(df)}")
# Out:
# Dataset created successfully!
# Total records: 100

# %%
from pydantic import BaseModel, Field, ValidationError, field_validator
from datetime import datetime

# %%
class BookRecord(BaseModel):
    book_id: int = Field(gt=0)
    isbn: str
    title: str
    author: str
    publisher_name: str
    publisher_city: str
    category: str
    language: str
    publication_year: int
    submission_date: str

    @field_validator("isbn")
    @classmethod
    def validate_isbn(cls, value):
        if not value:
            raise ValueError("ISBN cannot be empty.")
        return value

    @field_validator("title")
    @classmethod
    def validate_title(cls, value):
        if not value.strip():
            raise ValueError("Title cannot be empty.")
        return value

    @field_validator("language")
    @classmethod
    def validate_language(cls, value):
        if value not in ["Arabic", "English"]:
            raise ValueError("Language must be Arabic or English.")
        return value

    @field_validator("publication_year")
    @classmethod
    def validate_year(cls, value):
        current_year = datetime.now().year
        if value > current_year:
            raise ValueError("Publication year cannot be in the future.")
        return value

    @field_validator("submission_date")
    @classmethod
    def validate_date(cls, value):
        datetime.strptime(value, "%Y-%m-%d")
        return value

# %%
valid_records = []
invalid_records = []

for _, row in df.iterrows():
    try:
        record = BookRecord(**row.to_dict())
        valid_records.append(record.model_dump())
    except ValidationError as e:
        invalid_records.append({
            **row.to_dict(),
            "error": str(e)
        })

valid_df = pd.DataFrame(valid_records)
invalid_df = pd.DataFrame(invalid_records)

print(f"✅ Valid Records: {len(valid_df)}")
print(f"❌ Invalid Records: {len(invalid_df)}")
# Out:
# ✅ Valid Records: 95
# ❌ Invalid Records: 5

# %%
valid_df.to_csv("valid_books.csv", index=False)
invalid_df.to_csv("rejected_books.csv", index=False)

print("Files saved successfully!")

print(f"Valid records: {len(valid_df)}")
print(f"Invalid records: {len(invalid_df)}")
# Out:
# Files saved successfully!
# Valid records: 95
# Invalid records: 5

# %%
# Download and extract Kafka (single clean setup - no duplicate download/format)
# !wget -q https://archive.apache.org/dist/kafka/3.7.0/kafka_2.13-3.7.0.tgz
# !tar -xzf kafka_2.13-3.7.0.tgz

# %%
# %cd kafka_2.13-3.7.0
# Out:
# /content/kafka_2.13-3.7.0

# %%
import os

# Make sure there is no leftover storage from a previous run - this is what
# previously caused: "Invalid cluster.id ... Expected X, but read Y"
# !rm -rf /tmp/kraft-combined-logs

cluster_id = os.popen("bin/kafka-storage.sh random-uuid").read().strip()
print(cluster_id)

# !bin/kafka-storage.sh format -t $cluster_id -c config/kraft/server.properties
# Out:
# y_fr8qF0QqOWf_pLsOPfqg
# metaPropertiesEnsemble=MetaPropertiesEnsemble(metadataLogDir=Optional.empty, dirs={/tmp/kraft-combined-logs: EMPTY})
# Formatting /tmp/kraft-combined-logs with metadata.version 3.7-IV4.

# %%
import subprocess
import time

# Start the Kafka broker (started only ONCE - starting it twice would try to
# bind the same port and is unnecessary)
broker = subprocess.Popen(
    ["bin/kafka-server-start.sh", "config/kraft/server.properties"]
)

time.sleep(10)

print("Kafka Broker started!")
# Out:
# Kafka Broker started!

# %%
# !bin/kafka-topics.sh \
  --create \
  --topic books \
  --bootstrap-server localhost:9092
# Out:
# Created topic books.

# %%
from kafka import KafkaProducer
import pandas as pd
import json


# Step 1: Create a Kafka Producer
producer = KafkaProducer(
    bootstrap_servers="localhost:9092",
    value_serializer=lambda x: json.dumps(x).encode("utf-8")
)

# Step 2: Load the validated dataset
valid_books = pd.read_csv("/content/valid_books.csv")


# Step 3: Send each record to the Kafka topic
for _, record in valid_books.iterrows():
    producer.send("books", value=record.to_dict())


# Step 4: Ensure all messages are delivered
producer.flush()

print(f"Successfully sent {len(valid_books)} records to the 'books' topic.")
# Out:
# Successfully sent 95 records to the 'books' topic.

# %%
from kafka import KafkaConsumer
import json


# Step 1: Create a Kafka Consumer
# consumer_timeout_ms stops iteration automatically if no new message arrives
# for 10 seconds, instead of hanging forever if the expected count is wrong.
consumer = KafkaConsumer(
    "books",
    bootstrap_servers="localhost:9092",
    auto_offset_reset="earliest",
    enable_auto_commit=True,
    consumer_timeout_ms=10000,
    value_deserializer=lambda x: json.loads(x.decode("utf-8"))
)

print("Reading records from Kafka...\n")

# Step 2: Read records from Kafka
# Stop after reading exactly as many records as were produced (dynamic,
# not hard-coded), so this works even if the number of valid records changes.
expected_count = len(valid_books)
count = 0

for message in consumer:
    print(message.value)
    count += 1

    if count == expected_count:
        break

consumer.close()

print(f"\nSuccessfully consumed {count} / {expected_count} records.")
if count < expected_count:
    print("Warning: consumer timed out before reaching the expected count.")
# Out:
# /tmp/ipykernel_5593/170633921.py:8: DeprecationWarning: value_deserializer does not implement kafka.serializer.Deserializer
#   consumer = KafkaConsumer(
# WARNING:kafka.coordinator.consumer:group_id is None: disabling auto-commit.
# Reading records from Kafka...
#
# {'book_id': 6, 'isbn': 9786035661907, 'title': 'World talk term', 'author': 'Jesse Flowers', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-02-03'}
# {'book_id': 7, 'isbn': 9786032556017, 'title': 'Decide environment view possible', 'author': 'Carolyn Daniel', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Riyadh', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-02-03'}
# {'book_id': 8, 'isbn': 9786035437923, 'title': 'Establish understand read detail', 'author': 'Randy Brown', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Madinah', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-06-16'}
# {'book_id': 9, 'isbn': 9786032322047, 'title': 'Husband at tree note', 'author': 'Christy Porter', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-06-29'}
# {'book_id': 10, 'isbn': 9786034226067, 'title': 'Central cause seat much', 'author': 'Jessica Silva', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Riyadh', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2019, 'submission_date': '2026-03-15'}
# {'book_id': 11, 'isbn': 9786032338687, 'title': 'Meeting before another', 'author': 'Mark Conner', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Riyadh', 'category': 'Education', 'language': 'English', 'publication_year': 2022, 'submission_date': '2026-03-27'}
# {'book_id': 12, 'isbn': 9786037120868, 'title': 'His other', 'author': 'David Tran', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'Cybersecurity', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-07-11'}
# {'book_id': 13, 'isbn': 9786035479144, 'title': 'Race Mr', 'author': 'Martin Rodriguez', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Abha', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2023, 'submission_date': '2026-03-30'}
# {'book_id': 14, 'isbn': 9786035107245, 'title': 'About reveal rest will', 'author': 'Katie Rodriguez', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'English', 'publication_year': 2025, 'submission_date': '2026-05-07'}
# {'book_id': 15, 'isbn': 9786034684531, 'title': 'Participant check several much', 'author': 'Kerry Smith', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Riyadh', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2020, 'submission_date': '2026-03-07'}
# {'book_id': 16, 'isbn': 9786037730428, 'title': 'Born guy', 'author': 'Dr. Cynthia Allen', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Riyadh', 'category': 'Data Science', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-04-26'}
# {'book_id': 17, 'isbn': 9786039375710, 'title': 'Beat magazine', 'author': 'Philip Cannon', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Madinah', 'category': 'Data Science', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-01-27'}
# {'book_id': 18, 'isbn': 9786035137722, 'title': 'Water close month parent', 'author': 'Tanya Campos', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-05-21'}
# {'book_id': 19, 'isbn': 9786037700828, 'title': 'Human public health', 'author': 'Jocelyn Wright', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Data Science', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-01-13'}
# {'book_id': 20, 'isbn': 9786031790481, 'title': 'Open discover', 'author': 'Benjamin Welch', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-02-16'}
# {'book_id': 21, 'isbn': 9786038082668, 'title': 'Teacher audience', 'author': 'Michael Lewis', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Riyadh', 'category': 'Education', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-01-27'}
# {'book_id': 22, 'isbn': 9786038852574, 'title': 'Office drug list imagine behind', 'author': 'Heather Jenkins', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-06-25'}
# {'book_id': 23, 'isbn': 9786032921859, 'title': 'Pull worker', 'author': 'James Morgan', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-06-24'}
# {'book_id': 24, 'isbn': 9786035924115, 'title': 'Court movie cell', 'author': 'Joel Baxter', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Jeddah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-01-16'}
# {'book_id': 25, 'isbn': 9786035418934, 'title': 'Better present music address behavior', 'author': 'Cynthia Russell', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-04-08'}
# {'book_id': 26, 'isbn': 9786036007072, 'title': 'Total clearly able hospital', 'author': 'Rachel Mitchell', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2020, 'submission_date': '2026-05-22'}
# {'book_id': 27, 'isbn': 9786033710343, 'title': 'Product main couple design around', 'author': 'Amy Edwards', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2022, 'submission_date': '2026-01-11'}
# {'book_id': 28, 'isbn': 9786031326765, 'title': 'Me system church whether', 'author': 'Cody Larson', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-05-18'}
# {'book_id': 29, 'isbn': 9786031971823, 'title': 'Identify walk now', 'author': 'Amanda Miller', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-05-14'}
# {'book_id': 30, 'isbn': 9786039153566, 'title': 'Mission various daughter respond draw', 'author': 'Michael Evans', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Abha', 'category': 'History', 'language': 'Arabic', 'publication_year': 2017, 'submission_date': '2026-03-06'}
# {'book_id': 31, 'isbn': 9786038973915, 'title': 'Act perform', 'author': 'Ariel Medina', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-04-13'}
# {'book_id': 32, 'isbn': 9786034374754, 'title': 'Value thing these', 'author': 'Christopher Bass', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Madinah', 'category': 'Culture', 'language': 'English', 'publication_year': 2022, 'submission_date': '2026-05-23'}
# {'book_id': 33, 'isbn': 9786039683481, 'title': 'Worker southern more property never', 'author': 'Ashley Humphrey', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Riyadh', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-23'}
# {'book_id': 34, 'isbn': 9786036672134, 'title': 'Score choice', 'author': 'Daniel Cooper', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Abha', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2024, 'submission_date': '2026-05-20'}
# {'book_id': 35, 'isbn': 9786034694634, 'title': 'Measure economy traditional', 'author': 'Mark Calderon', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Riyadh', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2018, 'submission_date': '2026-01-09'}
# {'book_id': 36, 'isbn': 9786032130789, 'title': 'Side PM energy scientist', 'author': 'Jessica Smith', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Dammam', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2019, 'submission_date': '2026-01-16'}
# {'book_id': 37, 'isbn': 9786039143903, 'title': 'Nation strong old', 'author': 'Cameron Parker', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Data Science', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-07-02'}
# {'book_id': 38, 'isbn': 9786038935169, 'title': 'Together decide', 'author': 'Brian Deleon', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-06-29'}
# {'book_id': 39, 'isbn': 9786038231838, 'title': 'Wind see understand door', 'author': 'Robert Thompson', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'English', 'publication_year': 2026, 'submission_date': '2026-03-25'}
# {'book_id': 40, 'isbn': 9786031908841, 'title': 'Say forward us', 'author': 'Sharon Cochran', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Riyadh', 'category': 'Education', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-02-24'}
# {'book_id': 41, 'isbn': 9786035171761, 'title': 'Him although', 'author': 'Curtis Sellers', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'Government', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-03-12'}
# {'book_id': 42, 'isbn': 9786038077999, 'title': 'Development process huge', 'author': 'Benjamin Ayala', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-03-13'}
# {'book_id': 43, 'isbn': 9786038434500, 'title': 'Hundred wonder movie voice boy', 'author': 'Cassandra Estes', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Riyadh', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-23'}
# {'book_id': 44, 'isbn': 9786034965789, 'title': 'Others generation', 'author': 'Jessica Joyce', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'English', 'publication_year': 2018, 'submission_date': '2026-01-24'}
# {'book_id': 45, 'isbn': 9786037728339, 'title': 'Couple and job mind southern', 'author': 'Teresa Mclaughlin', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Jeddah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-02-09'}
# {'book_id': 46, 'isbn': 9786035449368, 'title': 'Attorney professional form finish', 'author': 'Michelle Evans', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Dammam', 'category': 'Education', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-03-04'}
# {'book_id': 47, 'isbn': 9786034185957, 'title': 'For recent never court', 'author': 'Jamie Adkins', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-02-05'}
# {'book_id': 48, 'isbn': 9786036261415, 'title': 'Feeling nature a expert involve', 'author': 'Mary Marshall', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Riyadh', 'category': 'Government', 'language': 'English', 'publication_year': 2023, 'submission_date': '2026-03-31'}
# {'book_id': 49, 'isbn': 9786039910817, 'title': 'Memory soldier where', 'author': 'Mary Campbell', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Riyadh', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2017, 'submission_date': '2026-05-15'}
# {'book_id': 50, 'isbn': 9786032149597, 'title': 'Friend stand seem pull different', 'author': 'Alexander Sanchez', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Riyadh', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-04-07'}
# {'book_id': 51, 'isbn': 9786033011363, 'title': 'Lay though', 'author': 'Michelle Cruz', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2024, 'submission_date': '2026-03-23'}
# {'book_id': 52, 'isbn': 9786032375453, 'title': 'Prevent accept seem', 'author': 'Ashley Coleman', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Abha', 'category': 'Government', 'language': 'English', 'publication_year': 2019, 'submission_date': '2026-02-05'}
# {'book_id': 53, 'isbn': 9786034426900, 'title': 'Let newspaper true building card', 'author': 'Joseph Hansen', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-03-06'}
# {'book_id': 54, 'isbn': 9786036033115, 'title': 'Partner rest measure store', 'author': 'Stephanie Manning', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'Arabic', 'publication_year': 2015, 'submission_date': '2026-04-07'}
# {'book_id': 55, 'isbn': 9786038688755, 'title': 'Seem style everyone', 'author': 'Kari Allen', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2023, 'submission_date': '2026-03-31'}
# {'book_id': 56, 'isbn': 9786034576135, 'title': 'Doctor from throw', 'author': 'Chris Reyes', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'Data Science', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-02-01'}
# {'book_id': 57, 'isbn': 9786035098412, 'title': 'Ask imagine my', 'author': 'Daniel Fisher', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Dammam', 'category': 'Data Science', 'language': 'English', 'publication_year': 2023, 'submission_date': '2026-07-03'}
# {'book_id': 58, 'isbn': 9786036075395, 'title': 'Watch affect thing offer local', 'author': 'Elizabeth Price', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2025, 'submission_date': '2026-07-01'}
# {'book_id': 59, 'isbn': 9786032737893, 'title': 'Mrs same son today', 'author': 'Don Tucker MD', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-05-16'}
# {'book_id': 60, 'isbn': 9786033607983, 'title': 'Right subject try wonder', 'author': 'Susan Vargas', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Dammam', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-05-15'}
# {'book_id': 61, 'isbn': 9786036752576, 'title': 'Poor career', 'author': 'Anthony Gray', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'Government', 'language': 'English', 'publication_year': 2019, 'submission_date': '2026-02-12'}
# {'book_id': 62, 'isbn': 9786031852264, 'title': 'Front they everything week', 'author': 'Ruben Ruiz', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Madinah', 'category': 'History', 'language': 'English', 'publication_year': 2015, 'submission_date': '2026-06-02'}
# {'book_id': 63, 'isbn': 9786031059486, 'title': 'Yourself glass', 'author': 'Rachael Pearson', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'English', 'publication_year': 2017, 'submission_date': '2026-06-03'}
# {'book_id': 64, 'isbn': 9786038412769, 'title': 'Current after charge', 'author': 'Michael Elliott', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Madinah', 'category': 'Government', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-14'}
# {'book_id': 65, 'isbn': 9786032262382, 'title': 'Short cold parent', 'author': 'Ashley Weiss', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-07-15'}
# {'book_id': 66, 'isbn': 9786033484601, 'title': 'Official up', 'author': 'Susan Brooks', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-07-11'}
# {'book_id': 67, 'isbn': 9786031669324, 'title': 'Away real physical', 'author': 'Raymond Jefferson', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-05-02'}
# {'book_id': 68, 'isbn': 9786032724590, 'title': 'Someone not American', 'author': 'Mary Jones', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Abha', 'category': 'History', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-05-12'}
# {'book_id': 69, 'isbn': 9786033592974, 'title': 'Support state', 'author': 'Tyler Reid', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-06-18'}
# {'book_id': 70, 'isbn': 9786031415846, 'title': 'Itself safe whole', 'author': 'Robert Medina', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'English', 'publication_year': 2025, 'submission_date': '2026-04-09'}
# {'book_id': 71, 'isbn': 9786035163555, 'title': 'Stay or focus early', 'author': 'Diana Hayes', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-06-02'}
# {'book_id': 72, 'isbn': 9786031649691, 'title': 'Particular her agreement surface consider', 'author': 'Robert Peterson', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Jeddah', 'category': 'Data Science', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-06-28'}
# {'book_id': 73, 'isbn': 9786036120253, 'title': 'New might course', 'author': 'Jason Peters', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-02-18'}
# {'book_id': 74, 'isbn': 9786036507321, 'title': 'Position make society behavior', 'author': 'Michael Torres', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Riyadh', 'category': 'History', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-04-29'}
# {'book_id': 75, 'isbn': 9786039546409, 'title': 'Network gas you nearly', 'author': 'Jesse Parker', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Abha', 'category': 'Cybersecurity', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-16'}
# {'book_id': 76, 'isbn': 9786035382463, 'title': 'Firm sea week', 'author': 'Cheryl Rodgers', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Cybersecurity', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-02-26'}
# {'book_id': 77, 'isbn': 9786038290770, 'title': 'With modern executive beyond create', 'author': 'Christopher Smith', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Dammam', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-04-19'}
# {'book_id': 78, 'isbn': 9786034188992, 'title': 'Animal approach factor', 'author': 'Margaret Mullins', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Riyadh', 'category': 'Culture', 'language': 'English', 'publication_year': 2015, 'submission_date': '2026-01-21'}
# {'book_id': 79, 'isbn': 9786039722815, 'title': 'Off light', 'author': 'Cody Williams', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-07-11'}
# {'book_id': 80, 'isbn': 9786036539837, 'title': 'Box assume man officer', 'author': 'Brittany Shepherd', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-07-12'}
# {'book_id': 81, 'isbn': 9786036038571, 'title': 'Yes budget', 'author': 'Lisa Gibbs', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Dammam', 'category': 'Culture', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-02-15'}
# {'book_id': 82, 'isbn': 9786037751158, 'title': 'Herself training father open investment', 'author': 'Amy Choi', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Abha', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2021, 'submission_date': '2026-01-21'}
# {'book_id': 83, 'isbn': 9786037361002, 'title': 'Personal enough ball', 'author': 'Juan Moore', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Abha', 'category': 'Government', 'language': 'English', 'publication_year': 2021, 'submission_date': '2026-03-24'}
# {'book_id': 84, 'isbn': 9786031006810, 'title': 'Like allow explain executive teacher', 'author': 'David Baker', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Dammam', 'category': 'Data Science', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-06-10'}
# {'book_id': 85, 'isbn': 9786036406444, 'title': 'Product value interesting name positive', 'author': 'Samantha Jones', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2023, 'submission_date': '2026-02-03'}
# {'book_id': 86, 'isbn': 9786038938746, 'title': 'Organization station TV', 'author': 'John Torres', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Riyadh', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2016, 'submission_date': '2026-03-23'}
# {'book_id': 87, 'isbn': 9786034940441, 'title': 'Matter management ball', 'author': 'Jeffrey Morris', 'publisher_name': 'King Fahad National Library', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'Arabic', 'publication_year': 2017, 'submission_date': '2026-02-20'}
# {'book_id': 88, 'isbn': 9786031409790, 'title': 'Director purpose', 'author': 'Laurie Smith', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Jeddah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2022, 'submission_date': '2026-06-05'}
# {'book_id': 89, 'isbn': 9786037953166, 'title': 'Office several compare', 'author': 'Jessica Ramirez', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'English', 'publication_year': 2022, 'submission_date': '2026-07-22'}
# {'book_id': 90, 'isbn': 9786037705062, 'title': 'Play man before girl', 'author': 'Michael Hodge', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2016, 'submission_date': '2026-03-08'}
# {'book_id': 91, 'isbn': 9786038132769, 'title': 'Explain war spend nearly', 'author': 'Ernest Morris', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'History', 'language': 'English', 'publication_year': 2015, 'submission_date': '2026-07-16'}
# {'book_id': 92, 'isbn': 9786035180853, 'title': 'Ten stay ability thank', 'author': 'Anthony Stone', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Madinah', 'category': 'Data Science', 'language': 'English', 'publication_year': 2025, 'submission_date': '2026-05-07'}
# {'book_id': 93, 'isbn': 9786039910914, 'title': 'Personal service data near', 'author': 'Jessica Wolfe', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Abha', 'category': 'Cybersecurity', 'language': 'English', 'publication_year': 2024, 'submission_date': '2026-01-25'}
# {'book_id': 94, 'isbn': 9786039468772, 'title': 'Participant dream citizen nearly need', 'author': 'Willie Durham', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Abha', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2026, 'submission_date': '2026-04-04'}
# {'book_id': 95, 'isbn': 9786038963715, 'title': 'Positive child usually', 'author': 'Michael Perry', 'publisher_name': 'Dar Al-Minhaj', 'publisher_city': 'Dammam', 'category': 'History', 'language': 'Arabic', 'publication_year': 2025, 'submission_date': '2026-04-08'}
# {'book_id': 96, 'isbn': 9786035652512, 'title': 'During necessary himself two', 'author': 'Sherry Shields', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Madinah', 'category': 'Culture', 'language': 'Arabic', 'publication_year': 2019, 'submission_date': '2026-02-26'}
# {'book_id': 97, 'isbn': 9786038379837, 'title': 'Future skin environment able', 'author': 'Sara Carpenter', 'publisher_name': 'Jarir Publishing', 'publisher_city': 'Dammam', 'category': 'Data Science', 'language': 'English', 'publication_year': 2020, 'submission_date': '2026-05-14'}
# {'book_id': 98, 'isbn': 9786036363836, 'title': 'Land machine forward', 'author': 'Jamie Cantu', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Riyadh', 'category': 'Data Science', 'language': 'Arabic', 'publication_year': 2018, 'submission_date': '2026-06-26'}
# {'book_id': 99, 'isbn': 9786037426265, 'title': 'Occur do simply', 'author': 'Patrick Thornton', 'publisher_name': 'Obeikan Publishing', 'publisher_city': 'Jeddah', 'category': 'Artificial Intelligence', 'language': 'English', 'publication_year': 2021, 'submission_date': '2026-06-14'}
# {'book_id': 100, 'isbn': 9786036551268, 'title': 'Write society present charge', 'author': 'Beth Sanford', 'publisher_name': 'Saudi Research Publishing', 'publisher_city': 'Madinah', 'category': 'Education', 'language': 'Arabic', 'publication_year': 2018, 'submission_date': '2026-03-09'}
#
# Successfully consumed 95 / 95 records.

# %%
# !pip install -q pyspark==3.5.0 delta-spark==3.2.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 6.2 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-spark-connect 1.1.0 requires pyspark[connect]~=4.0.0, but you have pyspark 3.5.0 which is incompatible.

# %%
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip

builder = (
    SparkSession.builder
    .appName("SDAIA Books Pipeline")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
)

spark = configure_spark_with_delta_pip(builder).getOrCreate()

print("Spark Session is ready!")
# Out:
# Spark Session is ready!

# %%
from pyspark.sql.functions import current_timestamp


# Step 1: Load the validated dataset
bronze_df = spark.read.csv(
    "/content/valid_books.csv",
    header=True,
    inferSchema=True
)


# Step 2: Add ingestion timestamp
bronze_df = bronze_df.withColumn(
    "ingestion_time",
    current_timestamp()
)


# Step 3: Save as Delta Bronze table
bronze_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/content/delta/bronze")

print("Bronze layer created successfully!")
# Out:
# Bronze layer created successfully!

# %%
bronze = spark.read.format("delta").load("/content/delta/bronze")

print(f"Number of records: {bronze.count()}")

bronze.show(5, truncate=False)
# Out:
# Number of records: 95
# +-------+-------------+--------------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# |book_id|isbn         |title                           |author        |publisher_name           |publisher_city|category     |language|publication_year|submission_date|ingestion_time            |
# +-------+-------------+--------------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# |6      |9786035661907|World talk term                 |Jesse Flowers |Obeikan Publishing       |Jeddah        |History      |English |2016            |2026-02-03     |2026-07-23 00:57:56.865936|
# |7      |9786032556017|Decide environment view possible|Carolyn Daniel|Dar Al-Minhaj            |Riyadh        |Cybersecurity|English |2024            |2026-02-03     |2026-07-23 00:57:56.865936|
# |8      |9786035437923|Establish understand read detail|Randy Brown   |Jarir Publishing         |Madinah       |Government   |Arabic  |2021            |2026-06-16     |2026-07-23 00:57:56.865936|
# |9      |9786032322047|Husband at tree note            |Christy Porter|Saudi Research Publishing|Dammam        |History      |English |2024            |2026-06-29     |2026-07-23 00:57:56.865936|
# |10     |9786034226067|Central cause seat much         |Jessica Silva |Jarir Publishing         |Riyadh        |Culture      |Arabic  |2019            |2026-03-15     |2026-07-23 00:57:56.865936|
# +-------+-------------+--------------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col


# Step 1: Read Bronze layer
silver_df = spark.read.format("delta").load("/content/delta/bronze")


# Step 2: Clean the data
silver_df = (
    silver_df
    .dropDuplicates()
    .withColumn("publication_year", col("publication_year").cast("int"))
    .withColumn("submission_date", col("submission_date").cast("date"))
)


# Step 3: Save as Delta Silver table
silver_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/content/delta/silver")

print("Silver layer created successfully!")
# Out:
# Silver layer created successfully!

# %%
silver = spark.read.format("delta").load("/content/delta/silver")

print(f"Number of records: {silver.count()}")

silver.show(5, truncate=False)
# Out:
# Number of records: 95
# +-------+-------------+----------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# |book_id|isbn         |title                       |author        |publisher_name           |publisher_city|category     |language|publication_year|submission_date|ingestion_time            |
# +-------+-------------+----------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# |12     |9786037120868|His other                   |David Tran    |Obeikan Publishing       |Dammam        |Cybersecurity|Arabic  |2025            |2026-07-11     |2026-07-23 00:57:56.865936|
# |96     |9786035652512|During necessary himself two|Sherry Shields|Saudi Research Publishing|Madinah       |Culture      |Arabic  |2019            |2026-02-26     |2026-07-23 00:57:56.865936|
# |44     |9786034965789|Others generation           |Jessica Joyce |Obeikan Publishing       |Madinah       |Education    |English |2018            |2026-01-24     |2026-07-23 00:57:56.865936|
# |24     |9786035924115|Court movie cell            |Joel Baxter   |Dar Al-Minhaj            |Jeddah        |Education    |Arabic  |2026            |2026-01-16     |2026-07-23 00:57:56.865936|
# |49     |9786039910817|Memory soldier where        |Mary Campbell |Obeikan Publishing       |Riyadh        |Government   |Arabic  |2017            |2026-05-15     |2026-07-23 00:57:56.865936|
# +-------+-------------+----------------------------+--------------+-------------------------+--------------+-------------+--------+----------------+---------------+--------------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import count


# Step 1: Read Silver layer
silver = spark.read.format("delta").load("/content/delta/silver")


# Step 2: Create Gold layer
# Count books by category and language
gold_df = (
    silver
    .groupBy("category", "language")
    .agg(count("*").alias("number_of_books"))
)


# Step 3: Save as Delta Gold table
gold_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/content/delta/gold")

print("Gold layer created successfully!")
# Out:
# Gold layer created successfully!

# %%
gold = spark.read.format("delta").load("/content/delta/gold")

gold.orderBy("category", "language").show(truncate=False)
# Out:
# +-----------------------+--------+---------------+
# |category               |language|number_of_books|
# +-----------------------+--------+---------------+
# |Artificial Intelligence|Arabic  |8              |
# |Artificial Intelligence|English |5              |
# |Culture                |Arabic  |9              |
# |Culture                |English |5              |
# |Cybersecurity          |Arabic  |3              |
# |Cybersecurity          |English |7              |
# |Data Science           |Arabic  |5              |
# |Data Science           |English |10             |
# |Education              |Arabic  |8              |
# |Education              |English |7              |
# |Government             |Arabic  |8              |
# |Government             |English |5              |
# |History                |Arabic  |6              |
# |History                |English |9              |
# +-----------------------+--------+---------------+

# %%
from pyspark.sql import Row
from pyspark.sql.functions import current_timestamp, to_date

# Read the schema from Silver
silver = spark.read.format("delta").load("/content/delta/silver")

updates = [
    (
        46,
        "9786035449368",
        "Updated Book Title",
        "Michelle Evans",
        "Dar Al-Minhaj",
        "Dammam",
        "Education",
        "English",
        2025,
        "2026-07-22"
    )
]

updates_df = spark.createDataFrame(
    updates,
    schema="""
    book_id INT,
    isbn STRING,
    title STRING,
    author STRING,
    publisher_name STRING,
    publisher_city STRING,
    category STRING,
    language STRING,
    publication_year INT,
    submission_date STRING
    """
)

updates_df = (
    updates_df
    .withColumn("submission_date", to_date("submission_date"))
    .withColumn("ingestion_time", current_timestamp())
)

updates_df.show()
# Out:
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------+
# |book_id|         isbn|             title|        author|publisher_name|publisher_city| category|language|publication_year|submission_date|      ingestion_time|
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------+
# |     46|9786035449368|Updated Book Title|Michelle Evans| Dar Al-Minhaj|        Dammam|Education| English|            2025|     2026-07-22|2026-07-23 00:58:...|
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------+

# %% [markdown]
# MERGE
#
# The following example demonstrates a Delta Lake MERGE (Upsert) operation using `book_id` as the business key.

# %%
from delta.tables import DeltaTable

silver_table = DeltaTable.forPath(spark, "/content/delta/silver")

(
    silver_table.alias("target")
    .merge(
        updates_df.alias("source"),
        "target.book_id = source.book_id"
    )
    .whenMatchedUpdateAll()
    .whenNotMatchedInsertAll()
    .execute()
)

print("Merge completed successfully!")
# Out:
# Merge completed successfully!

# %%
silver = spark.read.format("delta").load("/content/delta/silver")

silver.filter("book_id = 46").show(truncate=False)
# Out:
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------------+
# |book_id|isbn         |title             |author        |publisher_name|publisher_city|category |language|publication_year|submission_date|ingestion_time            |
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------------+
# |46     |9786035449368|Updated Book Title|Michelle Evans|Dar Al-Minhaj |Dammam        |Education|English |2025            |2026-07-22     |2026-07-23 00:59:00.885441|
# +-------+-------------+------------------+--------------+--------------+--------------+---------+--------+----------------+---------------+--------------------------+

# %% [markdown]
# ## Schema Enforcement
# The following example demonstrates Delta Lake schema enforcement by attempting to write data that does not match the existing table schema.

# %%
from pyspark.sql import Row

# Create invalid data with an extra column
invalid_data = [
    Row(
        book_id=999,
        isbn="9786030000000",
        title="Invalid Book",
        author="Test Author",
        publisher_name="Test Publisher",
        publisher_city="Riyadh",
        category="Education",
        language="English",
        publication_year=2025,
        submission_date="2026-07-22",
        extra_column="This column should not exist"
    )
]

invalid_df = spark.createDataFrame(invalid_data)

try:
    invalid_df.write \
        .format("delta") \
        .mode("append") \
        .save("/content/delta/silver")

    print("Schema accepted.")

except Exception as e:
    print("Schema Enforcement is working!")
    print(e)
# Out:
# Schema Enforcement is working!
# [DELTA_FAILED_TO_MERGE_FIELDS] Failed to merge fields 'book_id' and 'book_id'

# %% [markdown]
# # Stage 3-RAG Pipeline
#
# This notebook presents the implementation of the Retrieval-Augmented Generation (RAG) component for the SDAIA Books Platform.
#
# The implementation includes:
#
# - Preparing structured book data from the Gold layer.
# - Building source documents and splitting them into smaller chunks.
# - Generating embeddings for each chunk.
# - Storing embeddings in ChromaDB.
# - Implementing hybrid retrieval using dense search and BM25.
# - Combining retrieval results using Reciprocal Rank Fusion.
# - Reranking retrieved chunks using a CrossEncoder model.
# - Generating a grounded answer with a citation to the retrieved source.

# %%
# !pip install chromadb sentence-transformers rank-bm25
# Out:
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.6.0)
# Collecting rank-bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (2.13.4)
# Collecting pydantic-settings>=2.0 (from chromadb)
#   Downloading pydantic_settings-2.14.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.51.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.16.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.27.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.42.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 717.7 kB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.82.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.26.8)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.26.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (5.13.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.23.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.11.0+cpu)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb) (26.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.4)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (3.14.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 43.8 MB/s eta 0:00:00
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 16.9 MB/s eta 0:00:00
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Downloading kubernetes-36.0.3-py2.py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 59.7 MB/s eta 0:00:00
# Downloading onnxruntime-1.27.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 44.9 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.9 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 7.8 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.2 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 13.4 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.8 MB/s eta 0:00:00
# Downloading pydantic_settings-2.14.2-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 3.9 MB/s eta 0:00:00
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.8 MB/s eta 0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pypika, durationpy, rank-bm25, pyproject_hooks, pybase64, overrides, opentelemetry-proto, opentelemetry-api, onnxruntime, bcrypt, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, build, pydantic-settings, opentelemetry-sdk, kubernetes, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.42.1
#     Uninstalling opentelemetry-api-1.42.1:
#       Successfully uninstalled opentelemetry-api-1.42.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.63b1
#     Uninstalling opentelemetry-semantic-conventions-0.63b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.63b1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.42.1
#     Uninstalling opentelemetry-sdk-1.42.1:
#       Successfully uninstalled opentelemetry-sdk-1.42.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 2.4.0 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.4.0 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# Successfully installed bcrypt-5.0.0 build-1.5.0 chromadb-1.5.9 durationpy-0.10 kubernetes-36.0.3 onnxruntime-1.27.0 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-grpc-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 overrides-7.7.0 pybase64-1.4.3 pydantic-settings-2.14.2 pypika-0.51.1 pyproject_hooks-1.2.0 rank-bm25-0.2.2

# %%
# Import Libraries

import numpy as np
import pandas as pd
import chromadb

from sentence_transformers import SentenceTransformer, CrossEncoder
from rank_bm25 import BM25Okapi

# %%
# Step 1: Read Gold Layer

from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

gold_df = spark.read.format("delta").load("/content/delta/gold")

gold_df.show(5, truncate=False)
# Out:
# +-----------------------+--------+---------------+
# |category               |language|number_of_books|
# +-----------------------+--------+---------------+
# |Data Science           |English |10             |
# |Cybersecurity          |English |7              |
# |Artificial Intelligence|Arabic  |8              |
# |History                |Arabic  |6              |
# |Culture                |Arabic  |9              |
# +-----------------------+--------+---------------+
# only showing top 5 rows

# %%
# Step 2: Convert Gold Data to Documents (with metadata for citations)

documents = []       # full text per category (before chunking)
doc_metadata = []    # source info for each document, used later for citations

for i, row in enumerate(gold_df.collect()):
    doc_id = f"doc_{i}"
    text = (
        f"In the {row['category']} category, the Smart Library holds "
        f"{row['number_of_books']} books, most of them written in {row['language']}. "
        f"This reflects the demand and popularity of {row['category']} titles "
        f"among readers who prefer {row['language']} content. "
        f"Librarians use this data to decide which {row['category']} titles "
        f"to restock in {row['language']} for the upcoming semester."
    )
    documents.append(text)
    doc_metadata.append({
        "doc_id": doc_id,
        "category": row["category"],
        "language": row["language"],
        "number_of_books": row["number_of_books"]
    })

print(f"Built {len(documents)} source documents.")
print(documents[0])
# Out:
# Built 14 source documents.
# In the Data Science category, the Smart Library holds 10 books, most of them written in English. This reflects the demand and popularity of Data Science titles among readers who prefer English content. Librarians use this data to decide which Data Science titles to restock in English for the upcoming semester.

# %%
# Step 2b: Chunk Documents into Passages
# Real RAG pipelines split long documents into overlapping chunks before
# embedding, so retrieval can return precise, relevant passages instead of
# whole documents. Here we chunk by words with a small overlap between chunks.

def chunk_text(text, chunk_size=15, overlap=5):
    words = text.split()
    chunks = []
    start = 0
    while start < len(words):
        end = start + chunk_size
        chunk = " ".join(words[start:end])
        chunks.append(chunk)
        if end >= len(words):
            break
        start += (chunk_size - overlap)
    return chunks

chunk_texts = []      # text of every chunk, used for embeddings + BM25
chunk_ids = []        # unique id per chunk
chunk_sources = []    # which source document each chunk came from (for citations)

for doc, meta in zip(documents, doc_metadata):
    doc_chunks = chunk_text(doc)
    for c_idx, chunk in enumerate(doc_chunks):
        chunk_texts.append(chunk)
        chunk_ids.append(f"{meta['doc_id']}_chunk_{c_idx}")
        chunk_sources.append(meta)

print(f"Split {len(documents)} documents into {len(chunk_texts)} chunks.")
print("Example chunk:", chunk_texts[0])
print("Example chunk id:", chunk_ids[0])
# Out:
# Split 14 documents into 70 chunks.
# Example chunk: In the Data Science category, the Smart Library holds 10 books, most of them written
# Example chunk id: doc_0_chunk_0

# %%
# Step 3: Load Embedding Model

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

print("Embedding model loaded successfully!")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedding model loaded successfully!

# %%
# Step 4: Generate Embeddings for each chunk

embeddings = embedding_model.encode(chunk_texts).tolist()

print(f"Generated {len(embeddings)} embeddings (one per chunk).")
# Out:
# Generated 70 embeddings (one per chunk).

# %%
# Step 5: Create ChromaDB Collection (store chunks, not whole documents)

client = chromadb.Client()

collection = client.create_collection(name="books")

collection.add(
    documents=chunk_texts,
    embeddings=embeddings,
    ids=chunk_ids,
    metadatas=chunk_sources
)

print("Chunks stored in ChromaDB successfully!")
# Out:
# Chunks stored in ChromaDB successfully!

# %%
# Step 6: Build BM25 Index over chunks

tokenized_documents = [chunk.split() for chunk in chunk_texts]

bm25 = BM25Okapi(tokenized_documents)

print("BM25 index created successfully over chunks!")
# Out:
# BM25 index created successfully over chunks!

# %%
# Step 7: User Query

query = "How many Arabic Data Science books are available?"

print(query)
# Out:
# How many Arabic Data Science books are available?

# %%
# Step 8: Vector Search

query_embedding = embedding_model.encode(query).tolist()

vector_results = collection.query(
    query_embeddings=[query_embedding],
    n_results=5
)

print(vector_results["documents"][0])
# Out:
# ['books, most of them written in Arabic. This reflects the demand and popularity of Data', 'prefer Arabic content. Librarians use this data to decide which Data Science titles to restock', 'demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use', 'Data Science titles to restock in Arabic for the upcoming semester.', 'prefer Arabic content. Librarians use this data to decide which Artificial Intelligence titles to restock']

# %%
# Step 9: BM25 Search

tokenized_query = query.split()

bm25_scores = bm25.get_scores(tokenized_query)

top_indices = np.argsort(bm25_scores)[::-1][:5]

bm25_results = [chunk_texts[i] for i in top_indices]

print(bm25_results)
# Out:
# ['Data Science titles to restock in Arabic for the upcoming semester.', 'prefer Arabic content. Librarians use this data to decide which Data Science titles to restock', 'demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use', 'Data Science titles to restock in English for the upcoming semester.', 'prefer English content. Librarians use this data to decide which Data Science titles to restock']

# %%
# Step 10: Reciprocal Rank Fusion (RRF)

rrf_scores = {}

# Vector Search ranking
for rank, doc in enumerate(vector_results["documents"][0]):
    rrf_scores[doc] = rrf_scores.get(doc, 0) + 1 / (60 + rank)

# BM25 Search ranking
for rank, doc in enumerate(bm25_results):
    rrf_scores[doc] = rrf_scores.get(doc, 0) + 1 / (60 + rank)

rrf_results = sorted(
    rrf_scores,
    key=rrf_scores.get,
    reverse=True
)

print(rrf_results)
# Out:
# ['prefer Arabic content. Librarians use this data to decide which Data Science titles to restock', 'Data Science titles to restock in Arabic for the upcoming semester.', 'demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use', 'books, most of them written in Arabic. This reflects the demand and popularity of Data', 'Data Science titles to restock in English for the upcoming semester.', 'prefer Arabic content. Librarians use this data to decide which Artificial Intelligence titles to restock', 'prefer English content. Librarians use this data to decide which Data Science titles to restock']

# %%
# Step 11: CrossEncoder Reranking

cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")

pairs = [[query, doc] for doc in rrf_results]

scores = cross_encoder.predict(pairs)

ranked_results = [
    doc for _, doc in sorted(
        zip(scores, rrf_results),
        reverse=True
    )
]

print(ranked_results)
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# ['demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use', 'books, most of them written in Arabic. This reflects the demand and popularity of Data', 'prefer Arabic content. Librarians use this data to decide which Data Science titles to restock', 'Data Science titles to restock in Arabic for the upcoming semester.', 'prefer Arabic content. Librarians use this data to decide which Artificial Intelligence titles to restock', 'prefer English content. Librarians use this data to decide which Data Science titles to restock', 'Data Science titles to restock in English for the upcoming semester.']

# %%
# Step 12: Generate a Grounded Answer with Citation

# Map each chunk back to the source document it came from, so we can cite it.
chunk_to_meta = dict(zip(chunk_texts, chunk_sources))

top_chunk = ranked_results[0]
source = chunk_to_meta.get(top_chunk, {})

answer = (
    f"Based on the retrieved passage, the library holds "
    f"{source.get('number_of_books', 'an unknown number of')} books in the "
    f"{source.get('category', 'N/A')} category, mostly in {source.get('language', 'N/A')}."
)

print("Question:")
print(query)

print("\nAnswer:")
print(answer)

print("\nCitation:")
print(f"[Source: {source.get('doc_id', 'unknown')} | "
      f"Category={source.get('category')}, Language={source.get('language')}]")

print("\nRetrieved Passage:")
print(top_chunk)
# Out:
# Question:
# How many Arabic Data Science books are available?
#
# Answer:
# Based on the retrieved passage, the library holds 5 books in the Data Science category, mostly in Arabic.
#
# Citation:
# [Source: doc_8 | Category=Data Science, Language=Arabic]
#
# Retrieved Passage:
# demand and popularity of Data Science titles among readers who prefer Arabic content. Librarians use

# %% [markdown]
# # Stage 5-Data Quality Gate and Lineage Tracking
#
# This notebook presents the implementation of the **Quality Gate** and **Data Lineage** components for the SDAIA Books Platform.
#
# The implementation includes:
#
# - Data quality validation using **Great Expectations** on the Bronze, Silver, and Gold Delta layers.
# - A quality gate that halts downstream processing when validation fails.
# - **OpenLineage** START / COMPLETE / FAIL events emitted for each pipeline stage.

# %%
# Install quality validation and data lineage tracking libraries
# !pip install great-expectations openlineage-python -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 8.5 MB/s eta 0:00:00

# %%
# Import core libraries for the Quality Gate and Lineage stage
import great_expectations as gx
from datetime import datetime
import uuid
import json

print("Quality Gate + Lineage libraries are ready")
# Out:
# Quality Gate + Lineage libraries are ready

# %% [markdown]
# ## Step 1: Load Data from Delta Lake Layers
#
# We read the Bronze, Silver, and Gold Delta tables produced in the previous stages,
# so that quality checks can be applied on real pipeline outputs rather than sample data.

# %%
# Load Bronze, Silver, and Gold layers from Delta Lake
bronze_df = spark.read.format("delta").load("/content/delta/bronze")
silver_df = spark.read.format("delta").load("/content/delta/silver")
gold_df = spark.read.format("delta").load("/content/delta/gold")

# Convert to pandas for use with Great Expectations
bronze_pd = bronze_df.toPandas()
silver_pd = silver_df.toPandas()
gold_pd = gold_df.toPandas()

print(f"Bronze records: {len(bronze_pd)}")
print(f"Silver records: {len(silver_pd)}")
print(f"Gold records: {len(gold_pd)}")
# Out:
# Bronze records: 95
# Silver records: 95
# Gold records: 14

# %% [markdown]
# ## Step 2: Define Quality Expectations for Each Layer
#
# We define concrete data quality checks for the Bronze, Silver, and Gold layers.
# The overall gate decision (pass/fail) determines whether downstream stages
# are allowed to proceed.

# %%
context = gx.get_context()

def make_batch(df, name):
    """Register a pandas DataFrame with Great Expectations and return a validatable batch."""
    data_source = context.data_sources.add_pandas(name=f"{name}_source")
    data_asset = data_source.add_dataframe_asset(name=f"{name}_asset")
    batch_definition = data_asset.add_batch_definition_whole_dataframe(f"{name}_batch_def")
    return batch_definition.get_batch(batch_parameters={"dataframe": df})

# --- Create batches for each layer ---
bronze_batch = make_batch(bronze_pd, "bronze")
silver_batch = make_batch(silver_pd, "silver")
gold_batch = make_batch(gold_pd, "gold")

# --- Bronze layer checks: basic completeness ---
bronze_checks = {
    "book_id_not_null": bronze_batch.validate(
        gx.expectations.ExpectColumnValuesToNotBeNull(column="book_id")
    ),
    "isbn_not_null": bronze_batch.validate(
        gx.expectations.ExpectColumnValuesToNotBeNull(column="isbn")
    ),
}

# --- Silver layer checks: deeper validation ---
silver_checks = {
    "book_id_not_null": silver_batch.validate(
        gx.expectations.ExpectColumnValuesToNotBeNull(column="book_id")
    ),
    "language_valid": silver_batch.validate(
        gx.expectations.ExpectColumnValuesToBeInSet(column="language", value_set=["Arabic", "English"])
    ),
    "publication_year_reasonable": silver_batch.validate(
        gx.expectations.ExpectColumnValuesToBeBetween(column="publication_year", min_value=1900, max_value=2026)
    ),
}

# --- Gold layer checks: aggregate sanity ---
gold_checks = {
    "number_of_books_positive": gold_batch.validate(
        gx.expectations.ExpectColumnValuesToBeBetween(column="number_of_books", min_value=1)
    ),
}

# --- Combine all results into a single gate decision ---
all_checks = {**bronze_checks, **silver_checks, **gold_checks}
all_passed = all(result.success for result in all_checks.values())

print("Quality Check Results:")
for name, result in all_checks.items():
    status = "PASSED" if result.success else "FAILED"
    print(f"  {name}: {status}")

print(f"\nOverall Quality Gate Decision: {'PASS' if all_passed else 'FAIL'}")

# Persist the gate decision to disk so the Airflow DAG (run as a separate file) can read it.
import json as _json
with open('/content/quality_gate_result.json', 'w') as _f:
    _json.dump({
        "all_passed": bool(all_passed),
        "checks_passed": sum(r.success for r in all_checks.values()),
        "total_checks": len(all_checks)
    }, _f)
# Out:
# INFO:great_expectations.data_context.types.base:Created temporary directory '/tmp/tmpvkq9tity' for ephemeral docs site
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Quality Check Results:
#   book_id_not_null: PASSED
#   isbn_not_null: PASSED
#   language_valid: PASSED
#   publication_year_reasonable: PASSED
#   number_of_books_positive: PASSED
#
# Overall Quality Gate Decision: PASS

# %% [markdown]
# ## Step 3: Prove the Failure Path
#
# To demonstrate that the Quality Gate actually blocks bad data (not just passes
# good data), we intentionally corrupt a copy of the Silver dataset and re-run
# the same validation.

# %%
# Create a deliberately corrupted copy of Silver data
corrupted_silver_pd = silver_pd.copy()
corrupted_silver_pd.loc[0, "language"] = "French"  # invalid value, not in allowed set

corrupted_batch = make_batch(corrupted_silver_pd, "corrupted_silver")

corrupted_check = corrupted_batch.validate(
    gx.expectations.ExpectColumnValuesToBeInSet(column="language", value_set=["Arabic", "English"])
)

print(f"Corrupted data check result: {'PASSED' if corrupted_check.success else 'FAILED'}")

if not corrupted_check.success:
    print("Quality Gate correctly BLOCKED the corrupted data.")
    print(f"Unexpected values found: {corrupted_check.result.get('partial_unexpected_list', [])}")
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Corrupted data check result: FAILED
# Quality Gate correctly BLOCKED the corrupted data.
# Unexpected values found: ['French']

# %% [markdown]
# ## Step 4 (Corrected): Emit Real OpenLineage Events per Pipeline Stage
#
# We use the actual `openlineage-python` client library (OpenLineageClient, RunEvent,
# Run, Job) with a ConsoleTransport, instead of manually constructing JSON that
# merely resembles the OpenLineage schema.

# %%
import logging
logging.basicConfig(level=logging.DEBUG, force=True)

from openlineage.client import OpenLineageClient
from openlineage.client.transport.console import ConsoleConfig, ConsoleTransport
from openlineage.client.run import RunEvent, RunState, Run, Job
from datetime import datetime, timezone
import uuid

ol_client = OpenLineageClient(transport=ConsoleTransport(ConsoleConfig()))

def emit_lineage_event(job_name: str, event_type: str, run_id: str = None, facets: dict = None):
    """
    Emit a real OpenLineage RunEvent using the openlineage-python client library.
    event_type must be one of: START, COMPLETE, FAIL
    """
    run_id = run_id or str(uuid.uuid4())

    event = RunEvent(
        eventType=getattr(RunState, event_type),
        eventTime=datetime.now(timezone.utc).isoformat(),
        run=Run(runId=run_id),
        job=Job(namespace="sdaia-books-platform", name=job_name),
        producer="sdaia-books-platform-pipeline",
    )

    ol_client.emit(event)
    return run_id
# Out:
# DEBUG:openlineage.client.transport.console:Constructing OpenLineage transport that will send events to console or logs
# INFO:openlineage.client.client:OpenLineageClient will use `console` transport

# %%
# --- Ingestion stage ---
ingestion_run_id = emit_lineage_event("ingestion_kafka", "START")
emit_lineage_event("ingestion_kafka", "COMPLETE", ingestion_run_id,
                    facets={"recordCount": len(bronze_pd)})

# --- Lakehouse stage ---
lakehouse_run_id = emit_lineage_event("lakehouse_bronze_silver_gold", "START")
emit_lineage_event("lakehouse_bronze_silver_gold", "COMPLETE", lakehouse_run_id,
                    facets={"bronze": len(bronze_pd), "silver": len(silver_pd), "gold": len(gold_pd)})

# --- Quality Gate stage (real result from Step 2) ---
quality_run_id = emit_lineage_event("quality_gate", "START")
emit_lineage_event(
    "quality_gate",
    "COMPLETE" if all_passed else "FAIL",
    quality_run_id,
    facets={"checks_passed": sum(r.success for r in all_checks.values()), "total_checks": len(all_checks)}
)
# --- RAG stage ---
rag_run_id = emit_lineage_event("rag_pipeline", "START")
emit_lineage_event("rag_pipeline", "COMPLETE", rag_run_id,
                    facets={"chunks_indexed": len(chunk_texts)})
# Out:
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.812782+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "ingestion_kafka", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "b665f413-700a-4660-aa7e-29134c324959"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.812782+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "ingestion_kafka", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "b665f413-700a-4660-aa7e-29134c324959"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.820433+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "ingestion_kafka", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "b665f413-700a-4660-aa7e-29134c324959"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.820433+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "ingestion_kafka", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "b665f413-700a-4660-aa7e-29134c324959"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.828090+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "lakehouse_bronze_silver_gold", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "57bacf68-7825-4596-ba21-160bff65440d"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.828090+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "lakehouse_bronze_silver_gold", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "57bacf68-7825-4596-ba21-160bff65440d"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.835865+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "lakehouse_bronze_silver_gold", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "57bacf68-7825-4596-ba21-160bff65440d"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.835865+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "lakehouse_bronze_silver_gold", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "57bacf68-7825-4596-ba21-160bff65440d"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.844443+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "b060e4c7-5d5d-4b4e-8a78-5bb9541a6773"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.844443+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "b060e4c7-5d5d-4b4e-8a78-5bb9541a6773"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.856105+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "b060e4c7-5d5d-4b4e-8a78-5bb9541a6773"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.856105+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "b060e4c7-5d5d-4b4e-8a78-5bb9541a6773"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.860314+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "be6f70f9-8ddf-4599-9535-dcaa1b2b7fee"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.860314+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "be6f70f9-8ddf-4599-9535-dcaa1b2b7fee"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.865560+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "be6f70f9-8ddf-4599-9535-dcaa1b2b7fee"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.865560+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "rag_pipeline", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "be6f70f9-8ddf-4599-9535-dcaa1b2b7fee"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# 'be6f70f9-8ddf-4599-9535-dcaa1b2b7fee'

# %% [markdown]
# ## Step 5: Emit a Real FAIL Event Tied to Corrupted Data
#
# This demonstrates the full failure path: when the quality checks fail on
# corrupted data, the pipeline stage emits a FAIL lineage event instead of
# COMPLETE.

# %%
# Re-run the corrupted data check (from Step 3) and tie it to a lineage event
corrupted_run_id = emit_lineage_event("quality_gate_corrupted_run", "START")

corrupted_all_passed = corrupted_check.success

print(f"\nCorrupted run validation result: {'PASS' if corrupted_all_passed else 'FAIL'}")

emit_lineage_event(
    "quality_gate_corrupted_run",
    "COMPLETE" if corrupted_all_passed else "FAIL",
    corrupted_run_id,
    facets={"reason": "invalid language value detected" if not corrupted_all_passed else "all checks passed"}
)
# Out:
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.901657+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate_corrupted_run", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "f0573469-2d3e-4bd0-8792-71669fa0c882"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.901657+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate_corrupted_run", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "f0573469-2d3e-4bd0-8792-71669fa0c882"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# DEBUG:openlineage.client.client:OpenLineageClient will *try* to emit event b'{"eventTime": "2026-07-23T01:01:39.908376+00:00", "eventType": "FAIL", "inputs": [], "job": {"facets": {}, "name": "quality_gate_corrupted_run", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "f0573469-2d3e-4bd0-8792-71669fa0c882"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}'
# INFO:openlineage.client.transport.console:{"eventTime": "2026-07-23T01:01:39.908376+00:00", "eventType": "FAIL", "inputs": [], "job": {"facets": {}, "name": "quality_gate_corrupted_run", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "f0573469-2d3e-4bd0-8792-71669fa0c882"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"}
# DEBUG:openlineage.client.client:OpenLineage event successfully emitted.
# Corrupted run validation result: FAIL
# 'f0573469-2d3e-4bd0-8792-71669fa0c882'

# %% [markdown]
# # Stage 6-Airflow Orchestration
#
# This notebook presents the implementation of the Airflow Orchestration component for the SDAIA Books Platform.
#
# The implementation includes:
#
# - Building an Airflow DAG to orchestrate the complete data pipeline.
# - Defining task dependencies across the ingestion, lakehouse, quality gate, and RAG stages.
# - Ensuring that downstream tasks run only after upstream stages complete successfully.

# %%
# Install Apache Airflow
# !pip install apache-airflow -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.9/595.9 kB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.3/96.3 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.3/161.3 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 45.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.9/348.9 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 19.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 2.4.0 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.4.0 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# DEBUG:py4j.clientserver:Command to send: m
# d
# o41
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o57
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o156
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv

# %%
from airflow import DAG
from airflow.providers.standard.operators.empty import EmptyOperator
from airflow.providers.standard.operators.python import PythonOperator
from datetime import datetime
# Out:
# DEBUG:airflow.providers_manager:Initializing Providers Manager[config]
# DEBUG:airflow.providers_manager:Initializing Providers Manager[list]
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.standard.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-standard
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.common.compat.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-compat
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.common.io.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-io
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.common.sql.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-common-sql
# DEBUG:airflow._shared.providers_discovery.providers_discovery:Loading EntryPoint(name='provider_info', value='airflow.providers.smtp.get_provider_info:get_provider_info', group='apache_airflow_provider') from package apache-airflow-providers-smtp
# DEBUG:airflow.providers_manager:Initialization of Providers Manager[list] took 0.06 seconds
# DEBUG:airflow.providers_manager:Initialization of Providers Manager[config] took 0.06 seconds
# INFO:airflow.configuration:Reading the config from /root/airflow/airflow.cfg
# INFO:airflow.settings:Configured default timezone UTC
# DEBUG:airflow.settings:No airflow_local_settings to import.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/airflow/settings.py", line 769, in import_local_settings
#     import airflow_local_settings
# ModuleNotFoundError: No module named 'airflow_local_settings'

# %% [markdown]
# ## Write the DAG to a File
#
# Airflow 3.x requires a DAG to be loaded from a file (so it can be serialized)
# before it can actually be run. We write the complete DAG - including the real
# Quality Gate task - to a `.py` file in Airflow's dags folder.

# %%
# Make sure Airflow's home/dags directory exists BEFORE we write the DAG file
# (it is only auto-created once an airflow command like "airflow db migrate" runs,
# which otherwise happens later in this notebook - writing the file first caused
# FileNotFoundError: /root/airflow/dags/sdaia_books_dag.py)
# !mkdir -p /root/airflow/dags

# %%
# %%writefile /root/airflow/dags/sdaia_books_dag.py
from airflow import DAG
from airflow.providers.standard.operators.empty import EmptyOperator
from airflow.providers.standard.operators.python import PythonOperator
from datetime import datetime, timezone
import json, uuid

from openlineage.client import OpenLineageClient
from openlineage.client.transport.console import ConsoleConfig, ConsoleTransport
from openlineage.client.run import RunEvent, RunState, Run, Job

ol_client = OpenLineageClient(transport=ConsoleTransport(ConsoleConfig()))

def emit_lineage_event(job_name, event_type, run_id=None, facets=None):
    run_id = run_id or str(uuid.uuid4())
    event = RunEvent(
        eventType=getattr(RunState, event_type),
        eventTime=datetime.now(timezone.utc).isoformat(),
        run=Run(runId=run_id),
        job=Job(namespace="sdaia-books-platform", name=job_name),
        producer="sdaia-books-platform-pipeline",
    )
    ol_client.emit(event)
    return run_id

dag = DAG(
    dag_id="sdaia_books_pipeline",
    description="Orchestrates the SDAIA Books Platform pipeline",
    start_date=datetime(2026, 1, 1),
    schedule="@daily",
    catchup=False,
)

start = EmptyOperator(task_id="start", dag=dag)
data_ingestion = EmptyOperator(task_id="data_ingestion", dag=dag)
delta_lakehouse = EmptyOperator(task_id="delta_lakehouse", dag=dag)

def quality_gate_check(**context):
    """
    Real Quality Gate task: reads the Great Expectations result from disk
    (written earlier in the main notebook), and emits real OpenLineage events.
    Raises an exception on failure so Airflow halts downstream tasks.
    """
    with open("/content/quality_gate_result.json") as f:
        result = json.load(f)

    run_id = emit_lineage_event("quality_gate", "START")

    if not result["all_passed"]:
        emit_lineage_event("quality_gate", "FAIL", run_id,
                            facets={"reason": "one or more Great Expectations checks failed"})
        raise ValueError("Quality Gate failed: data did not pass validation checks.")

    emit_lineage_event("quality_gate", "COMPLETE", run_id,
                        facets={"checks_passed": result["checks_passed"]})
    print("Quality Gate passed. Downstream tasks may proceed.")
    return "quality_gate_passed"

quality_gate = PythonOperator(
    task_id="quality_gate",
    python_callable=quality_gate_check,
    dag=dag,
)

rag_pipeline = EmptyOperator(task_id="rag_pipeline", dag=dag)
end = EmptyOperator(task_id="end", dag=dag)

start >> data_ingestion >> delta_lakehouse >> quality_gate >> rag_pipeline >> end
# Out:
# Writing /root/airflow/dags/sdaia_books_dag.py

# %% [markdown]
# ## Proof of Execution: Success and Failure Paths
#
# We run the DAG twice using the `airflow dags test` command: once with the
# real (valid) data, where all tasks complete, and once with corrupted data,
# where the Quality Gate fails and downstream tasks (`rag_pipeline`, `end`)
# never run.

# %%
# Ensure Airflow's metadata database exists
# !airflow db migrate
# Out:
# 2026-07-23T01:02:33.517542Z [info     ] Performing upgrade to the metadata database [airflow.cli.commands.db_command] loc=db_command.py:134 url=sqlite:////root/airflow/airflow.db
# 2026-07-23T01:02:34.667886Z [info     ] setup plugin alembic.autogenerate.schemas [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:34.668345Z [info     ] setup plugin alembic.autogenerate.tables [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:34.668628Z [info     ] setup plugin alembic.autogenerate.types [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:34.669019Z [info     ] setup plugin alembic.autogenerate.constraints [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:34.669240Z [info     ] setup plugin alembic.autogenerate.defaults [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:34.669519Z [info     ] setup plugin alembic.autogenerate.comments [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:34.794441Z [info     ] Context impl SQLiteImpl.       [alembic.runtime.migration] loc=migration.py:210
# 2026-07-23T01:02:34.794848Z [info     ] Will assume non-transactional DDL. [alembic.runtime.migration] loc=migration.py:213
# 2026-07-23T01:02:37.570056Z [info     ] Context impl SQLiteImpl.       [alembic.runtime.migration] loc=migration.py:210
# 2026-07-23T01:02:37.570411Z [info     ] Will assume non-transactional DDL. [alembic.runtime.migration] loc=migration.py:213
# 2026-07-23T01:02:37.573186Z [info     ] Creating Airflow database tables from the ORM [airflow.utils.db] loc=db.py:749
# 2026-07-23T01:02:37.573571Z [info     ] Creating global lock context   [airflow.utils.db] loc=db.py:730
# 2026-07-23T01:02:37.573867Z [info     ] Pool status: Pool size: 5  Connections in pool: 0 Current Overflow: -4 Current Checked out connections: 1 [airflow.utils.db] loc=db.py:733
# 2026-07-23T01:02:37.574192Z [info     ] Creating metadata              [airflow.utils.db] loc=db.py:735
# 2026-07-23T01:02:38.673133Z [info     ] Getting alembic config         [airflow.utils.db] loc=db.py:738
# 2026-07-23T01:02:38.674852Z [info     ] Stamping migration head        [airflow.utils.db] loc=db.py:741
# 2026-07-23T01:02:38.678531Z [info     ] Context impl SQLiteImpl.       [alembic.runtime.migration] loc=migration.py:210
# 2026-07-23T01:02:38.678829Z [info     ] Will assume non-transactional DDL. [alembic.runtime.migration] loc=migration.py:213
# 2026-07-23T01:02:38.774930Z [info     ] Running stamp_revision  -> d2f4e1b3c5a7 [alembic.runtime.migration] loc=migration.py:621
# 2026-07-23T01:02:38.783752Z [info     ] Airflow database tables created [airflow.utils.db] loc=db.py:744
# 2026-07-23T01:02:38.882943Z [info     ] Database migration done!       [airflow.cli.commands.db_command] loc=db_command.py:152

# %%
import json

# Ensure the result file reflects the real (valid) Quality Gate outcome
with open('/content/quality_gate_result.json', 'w') as f:
    json.dump({
        "all_passed": True,
        "checks_passed": len(all_checks),
        "total_checks": len(all_checks)
    }, f)

print("=== RUN 1: Valid data ===")
# !airflow dags test sdaia_books_pipeline 2026-01-01
# Out:
# === RUN 1: Valid data ===
# 2026-07-23T01:02:51.117660Z [info     ] setup plugin alembic.autogenerate.schemas [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:51.118066Z [info     ] setup plugin alembic.autogenerate.tables [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:51.118268Z [info     ] setup plugin alembic.autogenerate.types [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:51.118424Z [info     ] setup plugin alembic.autogenerate.constraints [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:51.118567Z [info     ] setup plugin alembic.autogenerate.defaults [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:51.118770Z [info     ] setup plugin alembic.autogenerate.comments [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:02:51.235805Z [info     ] DAG bundles loaded: dags-folder, example_dags, apache-airflow-providers-common-sql-example-dags, apache-airflow-providers-standard-example-dags [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:271
# 2026-07-23T01:02:51.239284Z [info     ] Added new DAG bundle dags-folder to the database [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:337
# 2026-07-23T01:02:51.239913Z [info     ] Added new DAG bundle example_dags to the database [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:337
# 2026-07-23T01:02:51.240348Z [info     ] Added new DAG bundle apache-airflow-providers-common-sql-example-dags to the database [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:337
# 2026-07-23T01:02:51.240768Z [info     ] Added new DAG bundle apache-airflow-providers-standard-example-dags to the database [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:337
# 2026-07-23T01:02:51.253975Z [info     ] Filling up the DagBag from /root/airflow/dags [airflow.dag_processing.dagbag.BundleDagBag] loc=dagbag.py:460
# 2026-07-23T01:02:52.128184Z [info     ] OpenLineageClient will use `console` transport [openlineage.client.client] loc=client.py:136
# 2026-07-23T01:02:52.269614Z [info     ] Bulk-writing dags to db        [airflow.serialization.definitions.dag] count=1 loc=dag.py:210
# 2026-07-23T01:02:52.359784Z [info     ] Creating ORM DAG for sdaia_books_pipeline [airflow.dag_processing.collection] loc=collection.py:102
# 2026-07-23T01:02:52.375129Z [info     ] Getting latest run for non-partitioned Dag [airflow.dag_processing.collection] dag_id=sdaia_books_pipeline loc=collection.py:200
# 2026-07-23T01:02:52.437886Z [info     ] no latest run found            [airflow.dag_processing.collection] dag_id=sdaia_books_pipeline loc=collection.py:210
# 2026-07-23T01:02:52.580158Z [info     ] get next_dagrun_info_v2        [airflow.serialization.definitions.dag] last_automated_run_info=None loc=dag.py:445 next_info=DagRunInfo(run_after=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC')), data_interval=DataInterval(start=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC')), end=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC'))), partition_date=None, partition_key=None)
# 2026-07-23T01:02:52.590908Z [info     ] setting next dagrun info       [airflow.models.dag] loc=dag.py:848 next_dagrun='2026-07-23 00:00:00+00:00' next_dagrun_create_after='2026-07-23 00:00:00+00:00' next_dagrun_data_interval_end='2026-07-23 00:00:00+00:00' next_dagrun_data_interval_start='2026-07-23 00:00:00+00:00' next_dagrun_partition_date=None next_dagrun_partition_key=None
# 2026-07-23T01:02:52.843281Z [info     ] DAG bundles loaded: dags-folder, example_dags, apache-airflow-providers-common-sql-example-dags, apache-airflow-providers-standard-example-dags [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:271
# 2026-07-23T01:02:52.888307Z [info     ] Filling up the DagBag from /root/airflow/dags [airflow.dag_processing.dagbag.BundleDagBag] loc=dagbag.py:460
# 2026-07-23T01:02:52.899055Z [info     ] OpenLineageClient will use `console` transport [openlineage.client.client] loc=client.py:136
# 2026-07-23T01:02:52.915536Z [info     ] Bulk-writing dags to db        [airflow.serialization.definitions.dag] count=1 loc=dag.py:210
# 2026-07-23T01:02:52.921113Z [info     ] Getting latest run for non-partitioned Dag [airflow.dag_processing.collection] dag_id=sdaia_books_pipeline loc=collection.py:200
# 2026-07-23T01:02:52.923130Z [info     ] no latest run found            [airflow.dag_processing.collection] dag_id=sdaia_books_pipeline loc=collection.py:210
# 2026-07-23T01:02:52.940107Z [info     ] get next_dagrun_info_v2        [airflow.serialization.definitions.dag] last_automated_run_info=None loc=dag.py:445 next_info=DagRunInfo(run_after=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC')), data_interval=DataInterval(start=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC')), end=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC'))), partition_date=None, partition_key=None)
# 2026-07-23T01:02:52.940520Z [info     ] setting next dagrun info       [airflow.models.dag] loc=dag.py:848 next_dagrun='2026-07-23 00:00:00+00:00' next_dagrun_create_after='2026-07-23 00:00:00+00:00' next_dagrun_data_interval_end='2026-07-23 00:00:00+00:00' next_dagrun_data_interval_start='2026-07-23 00:00:00+00:00' next_dagrun_partition_date=None next_dagrun_partition_key=None
# 2026-07-23T01:02:52.997981Z [info     ] creating dag run               [airflow.serialization.definitions.dag] loc=dag.py:607 logical_date=DateTime(2026, 1, 1, 0, 0, 0, tzinfo=Timezone('UTC')) partition_key=None run_after=DateTime(2026, 7, 23, 1, 2, 52, 840795, tzinfo=Timezone('UTC')) run_id=manual__2026-07-23T01:02:52.840795+00:00
# 2026-07-23T01:02:53.214501Z [info     ] Created dag run.               [airflow.models.dagrun] dagrun=<DagRun sdaia_books_pipeline @ 2026-01-01 00:00:00+00:00: manual__2026-07-23T01:02:52.840795+00:00, state:running, queued_at: None. run_type: manual> loc=dagrun.py:2446
# 2026-07-23T01:02:53.905037Z [info     ] [DAG TEST] starting task_id=start map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:02:53.911180Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.start manual__2026-07-23T01:02:52.840795+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-2e8f-7faa-b3aa-4f884989b3d8> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:13.855973Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-4834-74b3-9c6e-b5536ceb93fe hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-2e8f-7faa-b3aa-4f884989b3d8
# 2026-07-23T01:03:13.860902Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-4834-74b3-9c6e-b5536ceb93fe loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-2e8f-7faa-b3aa-4f884989b3d8
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:start
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:13.912660Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:13.912923Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:13.981816Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-7ffa-72b8-988f-8fbfee6976a6 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-2e8f-7faa-b3aa-4f884989b3d8
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): start>
# 2026-07-23T01:03:14.000724Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:14.060948Z [info     ] [DAG TEST] end task task_id=start map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:14.109900Z [info     ] [DAG TEST] starting task_id=data_ingestion map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:14.110987Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.data_ingestion manual__2026-07-23T01:02:52.840795+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-2e90-7668-94c1-76429174fb3b> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:14.195842Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-80cd-700d-8e06-52bfa9a52292 hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-2e90-7668-94c1-76429174fb3b
# 2026-07-23T01:03:14.200068Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-80cd-700d-8e06-52bfa9a52292 loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-2e90-7668-94c1-76429174fb3b
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:data_ingestion
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:14.227427Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:14.229860Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:14.274638Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-8137-7ae4-a007-e98d5dceced4 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-2e90-7668-94c1-76429174fb3b
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): data_ingestion>
# 2026-07-23T01:03:14.291978Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:14.312177Z [info     ] [DAG TEST] end task task_id=data_ingestion map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:14.395440Z [info     ] [DAG TEST] starting task_id=delta_lakehouse map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:14.395809Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.delta_lakehouse manual__2026-07-23T01:02:52.840795+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-2e91-7efc-8e71-fad25304df8b> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:14.480417Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-81ef-78e1-af61-275b6192fe9c hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-2e91-7efc-8e71-fad25304df8b
# 2026-07-23T01:03:14.486874Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-81ef-78e1-af61-275b6192fe9c loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-2e91-7efc-8e71-fad25304df8b
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:delta_lakehouse
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:14.513947Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:14.514207Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:14.569429Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-8253-72c1-92a3-91227a215d65 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-2e91-7efc-8e71-fad25304df8b
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): delta_lakehouse>
# 2026-07-23T01:03:14.593943Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:14.618668Z [info     ] [DAG TEST] end task task_id=delta_lakehouse map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:14.659349Z [info     ] [DAG TEST] starting task_id=quality_gate map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:14.665820Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.quality_gate manual__2026-07-23T01:02:52.840795+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-2e92-7ed2-86b6-52ab1013e1c9> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:14.803775Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-82ff-7532-a4f6-61943e80aa0e hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-2e92-7ed2-86b6-52ab1013e1c9
# 2026-07-23T01:03:14.820093Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-82ff-7532-a4f6-61943e80aa0e loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-2e92-7ed2-86b6-52ab1013e1c9
# 2026-07-23T01:03:14.884941Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-83b9-7537-bc7e-d30948709f5f field_count=3 loc=task_instances.py:1005 ti_id=019f8c7f-2e92-7ed2-86b6-52ab1013e1c9
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:quality_gate
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:14.923661Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:14.931745Z [info     ] {"eventTime": "2026-07-23T01:03:14.930670+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "53c991b6-6482-4955-aa24-85910ae85289"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T01:03:14.932779Z [info     ] {"eventTime": "2026-07-23T01:03:14.932027+00:00", "eventType": "COMPLETE", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "53c991b6-6482-4955-aa24-85910ae85289"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# Quality Gate passed. Downstream tasks may proceed.
# 2026-07-23T01:03:14.933287Z [info     ] Done. Returned value was: quality_gate_passed [airflow.task.operators.airflow.providers.standard.operators.python.PythonOperator] loc=python.py:233
# 2026-07-23T01:03:14.933666Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:14.933922Z [info     ] Pushing xcom                   [task] loc=task_runner.py:2171 ti=RuntimeTaskInstance(id=UUID('019f8c7f-2e92-7ed2-86b6-52ab1013e1c9'), task_id='quality_gate', dag_id='sdaia_books_pipeline', run_id='manual__2026-07-23T01:02:52.840795+00:00', try_number=1, dag_version_id=UUID('019f8c7f-2d50-7038-aee8-d48d4160154c'), map_index=-1, hostname='8071a120a722', context_carrier=None, queue='default', task=<Task(PythonOperator): quality_gate>, max_tries=0, start_date=datetime.datetime(2026, 7, 23, 1, 3, 14, 683330, tzinfo=datetime.timezone.utc), end_date=None, state=<TaskInstanceState.RUNNING: 'running'>, is_mapped=False, rendered_map_index=None, sentry_integration='')
# 2026-07-23T01:03:15.017506Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-8424-7a0e-b50c-79923aec1864 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-2e92-7ed2-86b6-52ab1013e1c9
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(PythonOperator): quality_gate>
# 2026-07-23T01:03:15.029160Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:15.056176Z [info     ] [DAG TEST] end task task_id=quality_gate map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:15.076224Z [info     ] [DAG TEST] starting task_id=rag_pipeline map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:15.076575Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.rag_pipeline manual__2026-07-23T01:02:52.840795+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-2e93-7830-bc8d-01cef8d05f18> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:15.134217Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-8495-7147-8458-1a46e8853f50 hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-2e93-7830-bc8d-01cef8d05f18
# 2026-07-23T01:03:15.141621Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-8495-7147-8458-1a46e8853f50 loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-2e93-7830-bc8d-01cef8d05f18
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:rag_pipeline
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:15.172436Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:15.172688Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:15.193270Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-84e5-7973-9f83-66a322f64cbc loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-2e93-7830-bc8d-01cef8d05f18
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): rag_pipeline>
# 2026-07-23T01:03:15.206556Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:15.219310Z [info     ] [DAG TEST] end task task_id=rag_pipeline map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:15.248471Z [info     ] [DAG TEST] starting task_id=end map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:15.248840Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.end manual__2026-07-23T01:02:52.840795+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-2e94-759d-ae65-fef687b6ba66> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:15.283693Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-8539-7528-8319-c03b81f0d2cd hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-2e94-759d-ae65-fef687b6ba66
# 2026-07-23T01:03:15.285822Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-8539-7528-8319-c03b81f0d2cd loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-2e94-759d-ae65-fef687b6ba66
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:end
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:15.319489Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:15.325524Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:15.415007Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-857e-7eb6-9993-06f1006aada2 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-2e94-759d-ae65-fef687b6ba66
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): end>
# 2026-07-23T01:03:15.432688Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:15.455939Z [info     ] [DAG TEST] end task task_id=end map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:15.466827Z [info     ] Marking run <DagRun sdaia_books_pipeline @ 2026-01-01 00:00:00+00:00: manual__2026-07-23T01:02:52.840795+00:00, state:running, queued_at: None. run_type: manual> successful [airflow.models.dagrun.DagRun] loc=dagrun.py:1249
# Dag run in success state
# Dag run start:2026-01-01 00:00:00+00:00 end:2026-07-23 01:03:15.469675+00:00
# 2026-07-23T01:03:15.472873Z [info     ] DagRun Finished: dag_id=sdaia_books_pipeline, logical_date=2026-01-01 00:00:00+00:00, run_id=manual__2026-07-23T01:02:52.840795+00:00, run_start_date=2026-01-01 00:00:00+00:00, run_end_date=2026-07-23 01:03:15.469675+00:00, run_duration=17542995.469675, state=success, run_type=manual, data_interval_start=2026-01-01 00:00:00+00:00, data_interval_end=2026-01-01 00:00:00+00:00, [airflow.models.dagrun.DagRun] loc=dagrun.py:1315

# %%
import json

# Force the Quality Gate result file to reflect a FAILED outcome
with open('/content/quality_gate_result.json', 'w') as f:
    json.dump({
        "all_passed": False,
        "checks_passed": len(all_checks) - 1,
        "total_checks": len(all_checks)
    }, f)

print("=== RUN 2: Corrupted data ===")
# !airflow dags test sdaia_books_pipeline 2026-01-02

# Restore the real (valid) result file afterwards
with open('/content/quality_gate_result.json', 'w') as f:
    json.dump({
        "all_passed": bool(all_passed),
        "checks_passed": len(all_checks),
        "total_checks": len(all_checks)
    }, f)
# Out:
# === RUN 2: Corrupted data ===
# 2026-07-23T01:03:23.542385Z [info     ] setup plugin alembic.autogenerate.schemas [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:03:23.542784Z [info     ] setup plugin alembic.autogenerate.tables [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:03:23.542975Z [info     ] setup plugin alembic.autogenerate.types [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:03:23.543137Z [info     ] setup plugin alembic.autogenerate.constraints [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:03:23.543281Z [info     ] setup plugin alembic.autogenerate.defaults [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:03:23.543428Z [info     ] setup plugin alembic.autogenerate.comments [alembic.runtime.plugins] loc=plugins.py:37
# 2026-07-23T01:03:23.662144Z [info     ] DAG bundles loaded: dags-folder, example_dags, apache-airflow-providers-common-sql-example-dags, apache-airflow-providers-standard-example-dags [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:271
# 2026-07-23T01:03:23.676374Z [info     ] Filling up the DagBag from /root/airflow/dags [airflow.dag_processing.dagbag.BundleDagBag] loc=dagbag.py:460
# 2026-07-23T01:03:24.126101Z [info     ] OpenLineageClient will use `console` transport [openlineage.client.client] loc=client.py:136
# 2026-07-23T01:03:24.156500Z [info     ] Bulk-writing dags to db        [airflow.serialization.definitions.dag] count=1 loc=dag.py:210
# 2026-07-23T01:03:24.179222Z [info     ] Getting latest run for non-partitioned Dag [airflow.dag_processing.collection] dag_id=sdaia_books_pipeline loc=collection.py:200
# 2026-07-23T01:03:24.187718Z [info     ] no latest run found            [airflow.dag_processing.collection] dag_id=sdaia_books_pipeline loc=collection.py:210
# 2026-07-23T01:03:24.206265Z [info     ] get next_dagrun_info_v2        [airflow.serialization.definitions.dag] last_automated_run_info=None loc=dag.py:445 next_info=DagRunInfo(run_after=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC')), data_interval=DataInterval(start=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC')), end=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC'))), partition_date=None, partition_key=None)
# 2026-07-23T01:03:24.210876Z [info     ] setting next dagrun info       [airflow.models.dag] loc=dag.py:848 next_dagrun='2026-07-23 00:00:00+00:00' next_dagrun_create_after='2026-07-23 00:00:00+00:00' next_dagrun_data_interval_end='2026-07-23 00:00:00+00:00' next_dagrun_data_interval_start='2026-07-23 00:00:00+00:00' next_dagrun_partition_date=None next_dagrun_partition_key=None
# 2026-07-23T01:03:24.317420Z [info     ] DAG bundles loaded: dags-folder, example_dags, apache-airflow-providers-common-sql-example-dags, apache-airflow-providers-standard-example-dags [airflow.dag_processing.bundles.manager.DagBundlesManager] loc=manager.py:271
# 2026-07-23T01:03:24.326001Z [info     ] Filling up the DagBag from /root/airflow/dags [airflow.dag_processing.dagbag.BundleDagBag] loc=dagbag.py:460
# 2026-07-23T01:03:24.328296Z [info     ] OpenLineageClient will use `console` transport [openlineage.client.client] loc=client.py:136
# 2026-07-23T01:03:24.336788Z [info     ] Bulk-writing dags to db        [airflow.serialization.definitions.dag] count=1 loc=dag.py:210
# 2026-07-23T01:03:24.340962Z [info     ] Getting latest run for non-partitioned Dag [airflow.dag_processing.collection] dag_id=sdaia_books_pipeline loc=collection.py:200
# 2026-07-23T01:03:24.343025Z [info     ] no latest run found            [airflow.dag_processing.collection] dag_id=sdaia_books_pipeline loc=collection.py:210
# 2026-07-23T01:03:24.351630Z [info     ] get next_dagrun_info_v2        [airflow.serialization.definitions.dag] last_automated_run_info=None loc=dag.py:445 next_info=DagRunInfo(run_after=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC')), data_interval=DataInterval(start=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC')), end=DateTime(2026, 7, 23, 0, 0, 0, tzinfo=Timezone('UTC'))), partition_date=None, partition_key=None)
# 2026-07-23T01:03:24.352004Z [info     ] setting next dagrun info       [airflow.models.dag] loc=dag.py:848 next_dagrun='2026-07-23 00:00:00+00:00' next_dagrun_create_after='2026-07-23 00:00:00+00:00' next_dagrun_data_interval_end='2026-07-23 00:00:00+00:00' next_dagrun_data_interval_start='2026-07-23 00:00:00+00:00' next_dagrun_partition_date=None next_dagrun_partition_key=None
# 2026-07-23T01:03:24.385837Z [info     ] creating dag run               [airflow.serialization.definitions.dag] loc=dag.py:607 logical_date=DateTime(2026, 1, 2, 0, 0, 0, tzinfo=Timezone('UTC')) partition_key=None run_after=DateTime(2026, 7, 23, 1, 3, 24, 315656, tzinfo=Timezone('UTC')) run_id=manual__2026-07-23T01:03:24.315656+00:00
# 2026-07-23T01:03:24.517508Z [info     ] Created dag run.               [airflow.models.dagrun] dagrun=<DagRun sdaia_books_pipeline @ 2026-01-02 00:00:00+00:00: manual__2026-07-23T01:03:24.315656+00:00, state:running, queued_at: None. run_type: manual> loc=dagrun.py:2446
# 2026-07-23T01:03:24.815925Z [info     ] [DAG TEST] starting task_id=start map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:24.816558Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.start manual__2026-07-23T01:03:24.315656+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-a8fd-7342-b5a4-f47c55c47115> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:32.251241Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-b26b-784e-9a24-a600ce611ec8 hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-a8fd-7342-b5a4-f47c55c47115
# 2026-07-23T01:03:32.254824Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-b26b-784e-9a24-a600ce611ec8 loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-a8fd-7342-b5a4-f47c55c47115
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:start
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:32.286319Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:32.286563Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:32.315398Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c7bf-7f37-a91d-a6ced3fa3ebc loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-a8fd-7342-b5a4-f47c55c47115
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): start>
# 2026-07-23T01:03:32.326969Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:32.346466Z [info     ] [DAG TEST] end task task_id=start map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:32.365683Z [info     ] [DAG TEST] starting task_id=data_ingestion map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:32.366502Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.data_ingestion manual__2026-07-23T01:03:24.315656+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-a8fe-7efa-bd16-e123c9626bc1> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:32.388795Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c817-7155-b595-e2cc4c9bdd64 hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-a8fe-7efa-bd16-e123c9626bc1
# 2026-07-23T01:03:32.390364Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c817-7155-b595-e2cc4c9bdd64 loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-a8fe-7efa-bd16-e123c9626bc1
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:data_ingestion
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:32.405337Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:32.405568Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:32.423038Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c836-7703-bfe9-cdc15066979d loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-a8fe-7efa-bd16-e123c9626bc1
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): data_ingestion>
# 2026-07-23T01:03:32.433921Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:32.445069Z [info     ] [DAG TEST] end task task_id=data_ingestion map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:32.462679Z [info     ] [DAG TEST] starting task_id=delta_lakehouse map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:32.462972Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.delta_lakehouse manual__2026-07-23T01:03:24.315656+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-a8ff-72b6-aa40-5d5aa45647ed> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:32.486200Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c877-75a5-b936-a4262038a002 hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-a8ff-72b6-aa40-5d5aa45647ed
# 2026-07-23T01:03:32.488770Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c877-75a5-b936-a4262038a002 loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-a8ff-72b6-aa40-5d5aa45647ed
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:delta_lakehouse
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:32.505103Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:32.505315Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1577
# 2026-07-23T01:03:32.521514Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c89a-7f3f-a0b9-05d710405f42 loc=task_instances.py:484 new_state=success rows_affected=1 ti_id=019f8c7f-a8ff-72b6-aa40-5d5aa45647ed
# Task instance in success state
#  Previous state of the Task instance: TaskInstanceState.RUNNING
# Task operator:<Task(EmptyOperator): delta_lakehouse>
# 2026-07-23T01:03:32.531909Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:32.542775Z [info     ] [DAG TEST] end task task_id=delta_lakehouse map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:32.559663Z [info     ] [DAG TEST] starting task_id=quality_gate map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1501
# 2026-07-23T01:03:32.560100Z [info     ] [DAG TEST] running task <TaskInstance: sdaia_books_pipeline.quality_gate manual__2026-07-23T01:03:24.315656+00:00 [TaskInstanceState.SCHEDULED] ti_id=019f8c7f-a900-76a8-b579-f3a1b1d3d4f0> [airflow.sdk.definitions.dag] loc=dag.py:1504
# 2026-07-23T01:03:32.580641Z [info     ] Task started                   [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c8d7-71ed-a53c-23d0dbec18d8 hostname=8071a120a722 loc=task_instances.py:231 previous_state=queued ti_id=019f8c7f-a900-76a8-b579-f3a1b1d3d4f0
# 2026-07-23T01:03:32.582083Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c8d7-71ed-a53c-23d0dbec18d8 loc=task_instances.py:259 rows_affected=1 ti_id=019f8c7f-a900-76a8-b579-f3a1b1d3d4f0
# 2026-07-23T01:03:32.608873Z [info     ] Updating RenderedTaskInstanceFields [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c8f7-7046-8e5a-9af5352491db field_count=3 loc=task_instances.py:1005 ti_id=019f8c7f-a900-76a8-b579-f3a1b1d3d4f0
# Task instance is in running state
#  Previous state of the Task instance: TaskInstanceState.QUEUED
# Current task name:quality_gate
# Dag name:sdaia_books_pipeline
# 2026-07-23T01:03:32.630739Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2107
# 2026-07-23T01:03:32.633316Z [info     ] {"eventTime": "2026-07-23T01:03:32.632708+00:00", "eventType": "START", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "60696f4b-0f94-4042-a038-1f3aed50c379"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T01:03:32.633948Z [info     ] {"eventTime": "2026-07-23T01:03:32.633511+00:00", "eventType": "FAIL", "inputs": [], "job": {"facets": {}, "name": "quality_gate", "namespace": "sdaia-books-platform"}, "outputs": [], "producer": "sdaia-books-platform-pipeline", "run": {"facets": {"tags": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.51.0/client/python", "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/TagsRunFacet.json#/$defs/TagsRunFacet", "tags": [{"key": "openlineage_client_version", "source": "OPENLINEAGE_CLIENT", "value": "1.51.0"}]}}, "runId": "60696f4b-0f94-4042-a038-1f3aed50c379"}, "schemaURL": "https://openlineage.io/spec/1-0-5/OpenLineage.json#/definitions/RunEvent"} [openlineage.client.transport.console] loc=console.py:30
# 2026-07-23T01:03:32.634171Z [error    ] Task failed with exception     [task] loc=task_runner.py:1673
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/execution_time/task_runner.py", line 1576, in run
#     result = _execute_task(context=context, ti=ti, log=log)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/execution_time/task_runner.py", line 189, in wrapper
#     return f(*inner_args, **inner_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/execution_time/task_runner.py", line 2125, in _execute_task
#     result = ctx.run(execute, context=context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/bases/operator.py", line 445, in wrapper
#     return func(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/providers/standard/operators/python.py", line 231, in execute
#     return_value = self.execute_callable()
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/providers/standard/operators/python.py", line 254, in execute_callable
#     return runner.run(*self.op_args, **self.op_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/airflow/sdk/execution_time/callback_runner.py", line 97, in run
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/airflow/dags/sdaia_books_dag.py", line 51, in quality_gate_check
#     raise ValueError("Quality Gate failed: data did not pass validation checks.")
# ValueError: Quality Gate failed: data did not pass validation checks.
# 2026-07-23T01:03:32.636098Z [info     ] ::group::Post Execute          [task] loc=task_runner.py:1674
# Task instance in failure state
# Task start
# Task:<Task(PythonOperator): quality_gate>
# Failure caused by Quality Gate failed: data did not pass validation checks.
# 2026-07-23T01:03:32.639903Z [info     ] ::endgroup::                   [task] loc=task_runner.py:2270
# 2026-07-23T01:03:32.656836Z [info     ] Task instance state updated    [airflow.api_fastapi.execution_api.routes.task_instances] correlation_id=019f8c7f-c920-776c-ab8a-92652fa5227a loc=task_instances.py:484 new_state=failed rows_affected=1 ti_id=019f8c7f-a900-76a8-b579-f3a1b1d3d4f0
# 2026-07-23T01:03:32.689201Z [info     ] [DAG TEST] end task task_id=quality_gate map_index=-1 [airflow.sdk.definitions.dag] loc=dag.py:1563
# 2026-07-23T01:03:32.708041Z [warning  ] No tasks to run. unrunnable tasks: {<TaskInstance: sdaia_books_pipeline.end manual__2026-07-23T01:03:24.315656+00:00 [None] ti_id=019f8c7f-a902-7930-83ff-5ecdcfc379ec>} [airflow.sdk.definitions.dag] loc=dag.py:1424
# 2026-07-23T01:03:33.731526Z [info     ] Marking run <DagRun sdaia_books_pipeline @ 2026-01-02 00:00:00+00:00: manual__2026-07-23T01:03:24.315656+00:00, state:running, queued_at: None. run_type: manual> failed [airflow.models.dagrun.DagRun] loc=dagrun.py:1219
# Dag run  in failure state
# Dag information:sdaia_books_pipeline Run id: manual__2026-07-23T01:03:24.315656+00:00 Run type: manual
# Failed with message: task_failure
# 2026-07-23T01:03:33.732764Z [info     ] DagRun Finished: dag_id=sdaia_books_pipeline, logical_date=2026-01-02 00:00:00+00:00, run_id=manual__2026-07-23T01:03:24.315656+00:00, run_start_date=2026-01-02 00:00:00+00:00, run_end_date=2026-07-23 01:03:33.731785+00:00, run_duration=17456613.731785, state=failed, run_type=manual, data_interval_start=2026-01-02 00:00:00+00:00, data_interval_end=2026-01-02 00:00:00+00:00, [airflow.models.dagrun.DagRun] loc=dagrun.py:1315
# DagRun failed
